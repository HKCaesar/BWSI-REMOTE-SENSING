# %% [markdown]
# # Introduction to Pandas
#
# Pandas is a package built on top of numpy which incorporates many additional features which make it more convenient for data analysis. One main addition is the inclusion of row and column labels, which make pandas function much like spreadsheet software. It also includes tools for much more complex computations than regular numpy allows

# %%
import pandas as pd
import numpy as np
# by default, pandas only shows the beginning and end of a large dataframe
# You can choose how many rows and columns to show.
# If you want to see all of the rows, set the respective value to None
pd.options.display.max_rows = 100 
pd.options.display.max_columns = 50

# %% [markdown]
# ## Importing data
# There are a lot of built-in functions for importing data to pandas, for example, from files, database, and web sources. For a full list of the supported methods, see [the documentation on pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html).
#
# In this example, we're going to load data formatted as a csv from a website URL. In particular, it is a direct link to a file hosted in our course github repository.
#
# The data we're loading is a simplified pokedex which includes the number, name, base stats, types, abilities, and colors of each pokemon. We'll be using this data to explore the functionality of pandas.
#
# The primary class of pandas is the DataFrame, which functions like a spreadsheet (like in excel). It allows for named rows and columns. Data types between two different columns can vary, but entries within the same column should have the same type.

# %%
# URL for data hosted online
pokedex_url = 'https://raw.githubusercontent.com/bwsi-remote-sensing-2020/01-Intro-to-python/master/pokedex.csv' 
pokedex_df = pd.read_csv(pokedex_url, index_col='Index') # create a dataframe from a csv, set the column titled "Index" as the row labels

# %%
# in our case, the cloned repository includes the pokedex file in the folder, 
# so we could equivalently use the filename instead of a URL
pokedex_df = pd.read_csv('pokedex.csv', index_col='Index')

# %%
# We'll do some cleanup to deal with empty values
pokedex_df = pokedex_df.fillna('') # fill in the NaN values with empty string 
pokedex_df # prints out the dataframe
# Out:
#                    Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total  \
# Index
# 1.0              Bulbasaur   45   49   49     65     65     45    318
# 2.0                Ivysaur   60   62   63     80     80     60    405
# 3.0               Venusaur   80   82   83    100    100     80    525
# 4.0             Charmander   39   52   43     60     50     65    309
# 5.0             Charmeleon   58   64   58     80     65     80    405
# 6.0              Charizard   78   84   78    109     85    100    534
# 7.0               Squirtle   44   48   65     60     54     43    314
# 8.0              Wartortle   59   63   80     65     80     58    405
# 9.0              Blastoise   79   83  100     85    105     78    530
# 10.0              Caterpie   45   30   35     20     20     45    195
# 11.0               Metapod   50   20   55     25     25     30    205
# 12.0            Butterfree   60   45   50     80     80     70    385
# 13.0                Weedle   40   35   30     20     20     50    195
# 14.0                Kakuna   45   25   50     25     25     35    205
# 15.0              Beedrill   65   80   40     40     80     75    380
# 16.0                Pidgey   40   45   40     35     35     56    251
# 17.0             Pidgeotto   63   60   55     50     50     71    349
# 18.0               Pidgeot   83   80   75     70     70     91    469
# 19.0               Rattata   30   56   35     25     35     72    253
# 20.0              Raticate   55   81   60     50     70     97    413
# 21.0               Spearow   40   60   30     31     31     70    262
# 22.0                Fearow   65   90   65     61     61    100    442
# 23.0                 Ekans   30   60   44     40     54     55    283
# 24.0                 Arbok   60   85   69     65     79     80    438
# 26.0               Pikachu   35   55   30     50     40     90    300
# 27.0                Raichu   60   90   55     90     80    100    475
# 28.0             Sandshrew   50   75   85     20     30     40    300
# 29.0             Sandslash   75  100  110     45     55     65    450
# 30.0              Nidoran♀   55   47   52     40     40     41    275
# 31.0              Nidorina   70   62   67     55     55     56    365
# 32.0             Nidoqueen   90   82   87     75     85     76    495
# 33.0              Nidoran♂   46   57   40     40     40     50    273
# 34.0              Nidorino   61   72   57     55     55     65    365
# 35.0              Nidoking   81   92   77     85     75     85    495
# 37.0              Clefairy   70   45   48     60     65     35    323
# 38.0              Clefable   95   70   73     85     90     60    473
# 39.0                Vulpix   38   41   40     50     65     65    299
# 40.0             Ninetales   73   76   75     81    100    100    505
# 42.0            Jigglypuff  115   45   20     45     25     20    270
# 43.0            Wigglytuff  140   70   45     75     50     45    425
# 44.0                 Zubat   40   45   35     30     40     55    245
# 45.0                Golbat   75   80   70     65     75     90    455
# 47.0                Oddish   45   50   55     75     65     30    320
# 48.0                 Gloom   60   65   70     85     75     40    395
# 49.0             Vileplume   75   80   85    100     90     50    480
# 51.0                 Paras   35   70   55     45     55     25    285
# 52.0              Parasect   60   95   80     60     80     30    405
# 53.0               Venonat   60   55   50     40     55     45    305
# 54.0              Venomoth   70   65   60     90     75     90    450
# 55.0               Diglett   10   55   25     35     45     95    265
# 56.0               Dugtrio   35   80   50     50     70    120    405
# 57.0                Meowth   40   45   35     40     40     90    290
# 58.0               Persian   65   70   60     65     65    115    440
# 59.0               Psyduck   50   52   48     65     50     55    320
# 60.0               Golduck   80   82   78     95     80     85    500
# 61.0                Mankey   40   80   35     35     45     70    305
# 62.0              Primeape   65  105   60     60     70     95    455
# 63.0             Growlithe   55   70   45     70     50     60    350
# 64.0              Arcanine   90  110   80    100     80     95    555
# 65.0               Poliwag   40   50   40     40     40     90    300
# 66.0             Poliwhirl   65   65   65     50     50     90    385
# 67.0             Poliwrath   90   85   95     70     90     70    500
# 69.0                  Abra   25   20   15    105     55     90    310
# 70.0               Kadabra   40   35   30    120     70    105    400
# 71.0              Alakazam   55   50   45    135     85    120    490
# 72.0                Machop   70   80   50     35     35     35    305
# 73.0               Machoke   80  100   70     50     60     45    405
# 74.0               Machamp   90  130   80     65     85     55    505
# 75.0            Bellsprout   50   75   35     70     30     40    300
# 76.0            Weepinbell   65   90   50     85     45     55    390
# 77.0            Victreebel   80  105   65    100     60     70    480
# 78.0             Tentacool   40   40   35     50    100     70    335
# 79.0            Tentacruel   80   70   65     80    120    100    515
# 80.0               Geodude   40   80  100     30     30     20    300
# 81.0              Graveler   55   95  115     45     45     35    390
# 82.0                 Golem   80  110  130     55     65     45    485
# 83.0                Ponyta   50   85   55     65     65     90    410
# 84.0              Rapidash   65  100   70     80     80    105    500
# 85.0              Slowpoke   90   65   65     40     40     15    315
# 86.0               Slowbro   95   75  110    100     80     30    490
# 88.0             Magnemite   25   35   70     95     55     45    325
# 89.0              Magneton   50   60   95    120     70     70    465
# 91.0            Farfetch'd   52   65   55     58     62     60    352
# 92.0                 Doduo   35   85   45     35     35     75    310
# 93.0                Dodrio   60  110   70     60     60    100    460
# 94.0                  Seel   65   45   55     45     70     45    325
# 95.0               Dewgong   90   70   80     70     95     70    475
# 96.0                Grimer   80   80   50     40     50     25    325
# 97.0                   Muk  105  105   75     65    100     50    500
# 98.0              Shellder   30   65  100     45     25     40    305
# 99.0              Cloyster   50   90  180     85     45     70    520
# 100.0               Gastly   30   35   30    100     35     80    310
# 101.0              Haunter   45   50   45    115     55     95    405
# 102.0               Gengar   60   65   60    130     75    110    500
# 103.0                 Onix   35   45  160     30     45     70    385
# 105.0              Drowzee   60   48   45     43     90     42    328
# 106.0                Hypno   85   73   70     73    115     67    483
# 107.0               Krabby   30  105   90     25     25     50    325
# 108.0              Kingler   55  130  115     50     50     75    475
# 109.0              Voltorb   40   30   50     55     55    100    330
# 110.0            Electrode   60   50   70     80     80    140    480
# 111.0            Exeggcute   60   40   80     60     45     40    325
# 112.0            Exeggutor   95   95   85    125     65     55    520
# 113.0               Cubone   50   50   95     40     50     35    320
# 114.0              Marowak   60   80  110     50     80     45    425
# 116.0            Hitmonlee   50  120   53     35    110     87    455
# 117.0           Hitmonchan   50  105   79     35    110     76    455
# 119.0            Lickitung   90   55   75     60     75     30    385
# 121.0              Koffing   40   65   95     60     45     35    340
# 122.0              Weezing   65   90  120     85     70     60    490
# 123.0              Rhyhorn   80   85   95     30     30     25    345
# 124.0               Rhydon  105  130  120     45     45     40    485
# 127.0              Chansey  250    5    5     35    105     50    450
# 129.0              Tangela   65   55  115    100     40     60    435
# 131.0           Kangaskhan  105   95   80     40     80     90    490
# 132.0               Horsea   30   40   70     70     25     60    295
# 133.0               Seadra   55   65   95     95     45     85    440
# 135.0              Goldeen   45   67   60     35     50     63    320
# 136.0              Seaking   80   92   65     65     80     68    450
# 137.0               Staryu   30   45   55     70     55     85    340
# 138.0              Starmie   60   75   85    100     85    115    520
# 140.0             Mr. Mime   40   45   65    100    120     90    460
# 141.0              Scyther   70  110   80     55     80    105    500
# 144.0                 Jynx   65   50   35    115     95     95    455
# 146.0           Electabuzz   65   83   57     95     85    105    490
# 149.0               Magmar   65   95   57    100     85     93    495
# 151.0               Pinsir   65  125  100     55     70     85    500
# 152.0               Tauros   75  100   95     40     70    110    490
# 153.0             Magikarp   20   10   55     15     20     80    200
# 154.0             Gyarados   95  125   79     60    100     81    540
# 155.0               Lapras  130   85   80     85     95     60    535
# 156.0                Ditto   48   48   48     48     48     48    288
# 157.0                Eevee   55   55   50     45     65     55    325
# 158.0             Vaporeon  130   65   60    110     95     65    525
# 159.0              Jolteon   65   65   60    110     95    130    525
# 160.0              Flareon   65  130   60     95    110     65    525
# 165.0              Porygon   65   60   70     85     75     40    395
# 168.0              Omanyte   35   40  100     90     55     35    355
# 169.0              Omastar   70   60  125    115     70     55    495
# 170.0               Kabuto   30   80   90     55     45     55    355
# 171.0             Kabutops   60  115  105     65     70     80    495
# 172.0           Aerodactyl   80  105   65     60     75    130    515
# 174.0              Snorlax  160  110   65     65    110     30    540
# 175.0             Articuno   90   85  100     95    125     85    580
# 176.0               Zapdos   90   90   85    125     90    100    580
# 177.0              Moltres   90  100   90    125     85     90    580
# 178.0              Dratini   41   64   45     50     50     50    300
# 179.0            Dragonair   61   84   65     70     70     70    420
# 180.0            Dragonite   91  134   95    100    100     80    600
# 181.0               Mewtwo  106  110   90    154     90    130    680
# 182.0                  Mew  100  100  100    100    100    100    600
# 183.0            Chikorita   45   49   65     49     65     45    318
# 184.0              Bayleef   60   62   80     63     80     69    414
# 185.0             Meganium   80   82  100     83    100     80    525
# 186.0            Cyndaquil   39   52   43     60     50     65    309
# 187.0              Quilava   58   64   58     80     65     80    405
# 188.0           Typhlosion   78   84   78    109     85    100    534
# 189.0             Totodile   50   65   64     44     48     43    314
# 190.0             Croconaw   65   80   80     59     63     58    405
# 191.0           Feraligatr   85  105  100     79     83     78    530
# 192.0              Sentret   35   46   34     35     45     20    215
# 193.0               Furret   85   76   64     45     55     90    415
# 194.0             Hoothoot   60   30   30     36     56     50    262
# 195.0              Noctowl  100   50   50     76     96     70    442
# 196.0               Ledyba   40   20   30     40     80     55    265
# 197.0               Ledian   55   35   50     55    110     85    390
# 198.0             Spinarak   40   60   40     40     40     30    250
# 199.0              Ariados   70   90   70     60     60     40    390
# 46.0                Crobat   85   90   80     70     80    130    535
# 200.0             Chinchou   75   38   38     56     56     67    330
# 201.0              Lanturn  125   58   58     76     76     67    460
# 25.0                 Pichu   20   40   15     35     35     60    205
# 36.0                Cleffa   50   25   28     45     55     15    218
# 41.0             Igglybuff   90   30   15     40     20     15    210
# 202.0               Togepi   35   20   65     40     65     20    245
# 203.0              Togetic   55   40   85     80    105     40    405
# 205.0                 Natu   40   50   45     70     45     70    320
# 206.0                 Xatu   65   75   70     95     70     95    470
# 207.0               Mareep   55   40   40     65     45     35    280
# 208.0              Flaaffy   70   55   55     80     60     45    365
# 209.0             Ampharos   90   75   75    115     90     55    500
# 50.0             Bellossom   75   80   85     90    100     50    480
# 211.0               Marill   70   20   50     20     50     40    250
# 212.0            Azumarill  100   50   80     50     80     50    410
# 214.0            Sudowoodo   70  100  115     30     65     30    410
# 68.0              Politoed   90   75   75     90    100     70    500
# 215.0               Hoppip   35   35   40     35     55     50    250
# 216.0             Skiploom   55   45   50     45     65     80    340
# 217.0             Jumpluff   75   55   70     55     85    110    450
# 218.0                Aipom   55   70   55     40     55     85    360
# 220.0              Sunkern   30   30   30     30     30     30    180
# 221.0             Sunflora   75   75   55    105     85     30    425
# 222.0                Yanma   65   65   45     75     45     95    390
# 224.0               Wooper   55   45   45     25     25     15    210
# 225.0             Quagsire   95   85   85     65     65     35    430
# 161.0               Espeon   65   65   60    130     95    110    525
# 162.0              Umbreon   95   65  110     60    130     65    525
# 226.0              Murkrow   60   85   42     85     42     91    405
# 87.0              Slowking   95   75   80    100    110     30    490
# 228.0           Misdreavus   60   60   60     85     85     85    435
# 230.0                Unown   48   72   48     72     48     48    336
# 232.0            Wobbuffet  190   33   58     33     58     33    405
# 233.0            Girafarig   70   80   65     90     65     85    455
# 234.0               Pineco   50   65   90     35     35     15    290
# 235.0           Forretress   75   90  140     60     60     40    465
# 236.0            Dunsparce  100   70   70     65     65     45    415
# 237.0               Gligar   65   75  105     35     65     85    430
# 104.0              Steelix   75   85  200     55     65     30    510
# 239.0             Snubbull   60   80   50     40     40     30    300
# 240.0             Granbull   90  120   75     60     60     45    450
# 241.0             Qwilfish   65   95   75     55     55     85    430
# 142.0               Scizor   70  130  100     55     80     65    500
# 242.0              Shuckle   20   10  230     10    230      5    505
# 243.0            Heracross   80  125   75     40     95     85    500
# 244.0              Sneasel   55   95   55     35     75    115    430
# 246.0            Teddiursa   60   80   50     50     50     40    330
# 247.0             Ursaring   90  130   75     75     75     55    500
# 248.0               Slugma   40   40   40     70     40     20    250
# 249.0             Magcargo   50   50  120     80     80     30    410
# 250.0               Swinub   50   50   40     30     30     50    250
# 251.0            Piloswine  100  100   80     60     60     50    450
# 253.0              Corsola   55   55   85     65     85     35    380
# 254.0             Remoraid   35   65   35     65     35     65    300
# 255.0            Octillery   75  105   75    105     75     45    480
# 256.0             Delibird   45   55   45     65     45     75    330
# 258.0              Mantine   65   40   70     80    140     70    465
# 259.0             Skarmory   65   80  140     40     70     70    465
# 260.0             Houndour   45   60   30     80     50     65    330
# 261.0             Houndoom   75   90   50    110     80     95    500
# 134.0              Kingdra   75   95   95     95     95     85    540
# 262.0               Phanpy   90   60   60     40     40     40    330
# 263.0              Donphan   90  120  120     60     60     50    500
# 166.0             Porygon2   85   80   90    105     95     60    515
# 264.0             Stantler   73   95   62     85     65     85    465
# 265.0             Smeargle   55   20   35     20     45     75    250
# 115.0              Tyrogue   35   35   35     35     35     35    210
# 118.0            Hitmontop   50   95   95     35    110     70    455
# 143.0             Smoochum   45   30   15     85     65     65    305
# 145.0               Elekid   45   63   37     65     55     95    360
# 148.0                Magby   45   75   37     70     55     83    365
# 266.0              Miltank   95   80  105     40     70    100    490
# 128.0              Blissey  255   10   10     75    135     55    540
# 267.0               Raikou   90   85   75    115    100    115    580
# 268.0                Entei  115  115   85     90     75    100    580
# 269.0              Suicune  100   75  115     90    115     85    580
# 270.0             Larvitar   50   64   50     45     50     41    300
# 271.0              Pupitar   70   84   70     65     70     51    410
# 272.0            Tyranitar  100  134  110     95    100     61    600
# 273.0                Lugia  106   90  130     90    154    110    680
# 274.0                Ho-oh  106  130   90    110    154     90    680
# 275.0               Celebi  100  100  100    100    100    100    600
# 276.0              Treecko   40   45   35     65     55     70    310
# 277.0              Grovyle   50   65   45     85     65     95    405
# 278.0             Sceptile   70   85   65    105     85    120    530
# 279.0              Torchic   45   60   40     70     50     45    310
# 280.0            Combusken   60   85   60     85     60     55    405
# 281.0             Blaziken   80  120   70    110     70     80    530
# 282.0               Mudkip   50   70   50     50     50     40    310
# 283.0            Marshtomp   70   85   70     60     70     50    405
# 284.0             Swampert  100  110   90     85     90     60    535
# 285.0            Poochyena   35   55   35     30     30     35    220
# 286.0            Mightyena   70   90   70     60     60     70    420
# 287.0            Zigzagoon   38   30   41     30     41     60    240
# 288.0              Linoone   78   70   61     50     61    100    420
# 289.0              Wurmple   45   45   35     20     30     20    195
# 290.0              Silcoon   50   35   55     25     25     15    205
# 291.0            Beautifly   60   70   50     90     50     65    385
# 292.0              Cascoon   50   35   55     25     25     15    205
# 293.0               Dustox   60   50   70     50     90     65    385
# 294.0                Lotad   40   30   30     40     50     30    220
# 295.0               Lombre   60   50   50     60     70     50    340
# 296.0             Ludicolo   80   70   70     90    100     70    480
# 297.0               Seedot   40   40   50     30     30     30    220
# 298.0              Nuzleaf   70   70   40     60     40     60    340
# 299.0              Shiftry   90  100   60     90     60     80    480
# 300.0              Taillow   40   55   30     30     30     85    270
# 301.0              Swellow   60   85   60     50     50    125    430
# 302.0              Wingull   40   30   30     55     30     85    270
# 303.0             Pelipper   60   50  100     85     70     65    430
# 304.0                Ralts   28   25   25     45     35     40    198
# 305.0               Kirlia   38   35   35     65     55     50    278
# 306.0            Gardevoir   68   65   65    125    115     80    518
# 308.0              Surskit   40   30   32     50     52     65    269
# 309.0           Masquerain   70   60   62     80     82     60    414
# 310.0            Shroomish   60   40   60     40     60     35    295
# 311.0              Breloom   60  130   80     60     60     70    460
# 312.0              Slakoth   60   60   60     35     35     30    280
# 313.0             Vigoroth   80   80   80     55     55     90    440
# 314.0              Slaking  150  160  100     95     65    100    670
# 315.0              Nincada   31   45   90     30     30     40    266
# 316.0              Ninjask   61   90   45     50     50    160    456
# 317.0             Shedinja    1   90   45     30     30     40    236
# 318.0              Whismur   64   51   23     51     23     28    240
# 319.0              Loudred   84   71   43     71     43     48    360
# 320.0              Exploud  104   91   63     91     63     68    480
# 321.0             Makuhita   72   60   30     20     30     25    237
# 322.0             Hariyama  144  120   60     40     60     50    474
# 210.0              Azurill   50   20   40     20     40     20    190
# 323.0             Nosepass   30   45  135     45     90     30    375
# 325.0               Skitty   50   45   45     35     35     50    260
# 326.0             Delcatty   70   65   65     55     55     70    380
# 327.0              Sableye   50   75   75     65     65     50    380
# 328.0               Mawile   50   85   85     55     55     50    380
# 329.0                 Aron   50   70  100     40     40     30    330
# 330.0               Lairon   60   90  140     50     50     40    430
# 331.0               Aggron   70  110  180     60     60     50    530
# 332.0             Meditite   30   40   55     40     55     60    280
# 333.0             Medicham   60   60   75     60     75     80    410
# 334.0            Electrike   40   45   40     65     40     65    295
# 335.0            Manectric   70   75   60    105     60    105    475
# 336.0               Plusle   60   50   40     85     75     95    405
# 337.0                Minun   60   40   50     75     85     95    405
# 338.0              Volbeat   65   73   55     47     75     85    400
# 339.0             Illumise   65   47   55     73     75     85    400
# 341.0              Roselia   50   60   45    100     80     65    400
# 343.0               Gulpin   70   43   53     43     53     40    302
# 344.0               Swalot  100   73   83     73     83     55    467
# 345.0             Carvanha   45   90   20     65     20     65    305
# 346.0             Sharpedo   70  120   40     95     40     95    460
# 347.0              Wailmer  130   70   35     70     35     60    400
# 348.0              Wailord  170   90   45     90     45     60    500
# 349.0                Numel   60   60   40     65     45     35    305
# 350.0             Camerupt   70  100   70    105     75     40    460
# 351.0              Torkoal   70   85  140     85     70     20    470
# 352.0               Spoink   60   25   35     70     80     60    330
# 353.0              Grumpig   80   45   65     90    110     80    470
# 354.0               Spinda   60   60   60     60     60     60    360
# 355.0             Trapinch   45  100   45     45     45     10    290
# 356.0              Vibrava   50   70   50     50     50     70    340
# 357.0               Flygon   80  100   80     80     80    100    520
# 358.0               Cacnea   50   85   40     85     40     35    335
# 359.0             Cacturne   70  115   60    115     60     55    475
# 360.0               Swablu   45   40   60     40     75     50    310
# 361.0              Altaria   75   70   90     70    105     80    490
# 362.0             Zangoose   73  115   60     60     60     90    458
# 363.0              Seviper   73  100   60    100     60     65    458
# 364.0             Lunatone   70   55   65     95     85     70    440
# 365.0              Solrock   70   95   85     55     65     70    440
# 366.0             Barboach   50   48   43     46     41     60    288
# 367.0             Whiscash  110   78   73     76     71     60    468
# 368.0             Corphish   43   80   65     50     35     35    308
# 369.0            Crawdaunt   63  120   85     90     55     55    468
# 370.0               Baltoy   40   40   55     40     70     55    300
# 371.0              Claydol   60   70  105     70    120     75    500
# 372.0               Lileep   66   41   77     61     87     23    355
# 373.0              Cradily   86   81   97     81    107     43    495
# 374.0              Anorith   45   95   50     40     50     75    355
# 375.0              Armaldo   75  125  100     70     80     45    495
# 376.0               Feebas   20   15   20     10     55     80    200
# 377.0              Milotic   95   60   79    100    125     81    540
# 378.0             Castform   70   70   70     70     70     70    420
# 379.0              Kecleon   60   90   70     60    120     40    440
# 380.0              Shuppet   44   75   35     63     33     45    295
# 381.0              Banette   64  115   65     83     63     65    455
# 382.0              Duskull   20   40   90     30     90     25    295
# 383.0             Dusclops   40   70  130     60    130     25    455
# 385.0              Tropius   99   68   83     72     87     51    460
# 387.0             Chimecho   65   50   70     95     80     65    425
# 388.0                Absol   65  130   60     75     60     75    465
# 231.0               Wynaut   95   23   48     23     48     23    260
# 389.0              Snorunt   50   50   50     50     50     50    300
# 390.0               Glalie   80   80   80     80     80     80    480
# 392.0               Spheal   70   40   50     55     50     25    290
# 393.0               Sealeo   90   60   70     75     70     45    410
# 394.0              Walrein  110   80   90     95     90     65    530
# 395.0             Clamperl   35   64   85     74     55     32    345
# 396.0              Huntail   55  104  105     94     75     52    485
# 397.0             Gorebyss   55   84  105    114     75     52    485
# 398.0            Relicanth  100   90  130     45     65     55    485
# 399.0              Luvdisc   43   30   55     40     65     97    330
# 400.0                Bagon   45   75   60     40     30     50    300
# 401.0              Shelgon   65   95  100     60     50     50    420
# 402.0            Salamence   95  135   80    110     80    100    600
# 403.0               Beldum   40   55   80     35     60     30    300
# 404.0               Metang   60   75  100     55     80     50    420
# 405.0            Metagross   80  135  130     95     90     70    600
# 406.0             Regirock   80  100  200     50    100     50    580
# 407.0               Regice   80   50  100    100    200     50    580
# 408.0            Registeel   80   75  150     75    150     50    580
# 409.0               Latias   80   80   90    110    130    110    600
# 410.0               Latios   80   90   80    130    110    110    600
# 411.0               Kyogre  100  100   90    150    140     90    670
# 412.0              Groudon  100  150  140    100     90     90    670
# 413.0             Rayquaza  105  150   90    150     90     95    680
# 414.0              Jirachi  100  100  100    100    100    100    600
# 415.0           Deoxys (N)   50  150   50    150     50    150    600
# 415.1           Deoxys (A)   50  180   20    180     20    150    600
# 415.2           Deoxys (D)   50   70  160     70    160     90    600
# 415.3           Deoxys (S)   50   95   90     95     90    180    600
# 464.0               Gabite   68   90   65     50     55     82    410
# 465.0             Garchomp  108  130   95     80     85    102    600
# 173.0             Munchlax  135   85   40     40     85      5    390
# 466.0                Riolu   40   70   40     35     40     60    285
# 467.0              Lucario   70  110   70    115     70     90    525
# 468.0           Hippopotas   68   72   78     38     42     32    330
# 469.0            Hippowdon  108  112  118     68     72     47    525
# 470.0              Skorupi   40   50   90     30     55     65    330
# 471.0              Drapion   70   90  110     60     75     95    500
# 472.0             Croagunk   48   61   40     61     40     50    300
# 473.0            Toxicroak   83  106   65     86     65     85    490
# 474.0            Carnivine   74  100   72     90     72     46    454
# 475.0              Finneon   49   49   56     49     61     66    330
# 476.0             Lumineon   69   69   76     69     86     91    460
# 257.0              Mantyke   45   20   50     60    120     50    345
# 477.0               Snover   60   62   50     62     60     40    334
# 478.0            Abomasnow   90   92   75     92     85     60    494
# 245.0              Weavile   70  120   65     45     85    125    510
# 90.0             Magnezone   70   70  115    130     90     60    535
# 120.0           Lickilicky  110   85   95     80     95     50    515
# 125.0            Rhyperior  115  140  130     55     55     40    535
# 130.0            Tangrowth  100  100  125    110     50     50    535
# 147.0           Electivire   75  123   67     95     85     95    540
# 150.0            Magmortar   75   95   67    125     95     83    540
# 204.0             Togekiss   85   50   95    120    115     80    545
# 223.0              Yanmega   86   76   86    116     56     95    515
# 163.0              Leafeon   65  110  130     60     65     95    525
# 164.0              Glaceon   65   60  110    130     95     65    525
# 238.0              Gliscor   75   95  125     45     75     95    510
# 252.0            Mamoswine  110  130   80     70     60     80    530
# 167.0            Porygon-Z   85   80   70    135     75     90    535
# 307.0              Gallade   68  125   65     65    115     80    518
# 324.0            Probopass   60   55  145     75    150     40    525
# 384.0             Dusknoir   45  100  135     65    135     45    525
# 391.0             Froslass   70   80   70     80     70    110    480
# 479.0                Rotom   50   50   77     95     77     91    440
# 479.1         Rotom (Heat)   50   65  107    105    107     86    520
# 479.2         Rotom (Wash)   50   65  107    105    107     86    520
# 479.3        Rotom (Frost)   50   65  107    105    107     86    520
# 479.4         Rotom (Spin)   50   65  107    105    107     86    520
# 479.5          Rotom (Cut)   50   65  107    105    107     86    520
# 480.0                 Uxie   75   75  130     75    130     95    580
# 481.0              Mesprit   80  105  105    105    105     80    580
# 482.0                Azelf   75  125   70    125     70    115    580
# 483.0               Dialga  100  120  120    150    100     90    680
# 484.0               Palkia   90  120  100    150    120    100    680
# 485.0              Heatran   91   90  106    130    106     77    600
# 486.0            Regigigas  110  160  110     80    110    100    670
# 487.0             Giratina  150  100  120    100    120     90    680
# 487.1         Giratina (O)  150  120  100    120    100     90    680
# 488.0            Cresselia  120   70  120     75    130     85    600
# 489.0               Phione   80   80   80     80     80     80    480
# 490.0              Manaphy  100  100  100    100    100    100    600
# 491.0              Darkrai   70   90   90    135     90    125    600
# 492.0              Shaymin  100  100  100    100    100    100    600
# 492.1          Shaymin (S)  100  103   75    120     75    127    600
# 493.0               Arceus  120  120  120    120    120    120    720
# 494.0              Victini  100  100  100    100    100    100    600
# 495.0                Snivy   45   45   55     45     55     63    308
# 734.0                      Adaptability   Brown
# 735.0                      Adaptability   Brown
# 736.0                                      Gray
# 737.0                                     Green
# 738.0                                      Blue
# 739.0                       Anger Point  Purple
# 740.0                       Anger Point   White
# 741.0                                       Red
# 742.0                        Sweet Veil  Yellow
# 743.0                        Sweet Veil  Yellow
# 744.0                         Steadfast   Brown
# 745.0                         Steadfast
# 745.1                          No Guard   Brown
# 746.0                                      Blue
# 746.1                                      Blue
# 747.0                       Regenerator    Blue
# 748.0                       Regenerator    Blue
# 749.0                       Inner Focus   Brown
# 750.0                       Inner Focus   Brown
# 751.0                      Water Absorb   Green
# 752.0                      Water Absorb   Green
# 753.0                          Contrary    Pink
# 754.0                          Contrary    Pink
# 755.0                         Rain Dish  Purple
# 756.0                         Rain Dish  Purple
# 757.0                         Oblivious   Black
# 758.0                         Oblivious   Black
# 759.0                        Cute Charm    Pink
# 760.0                           Unnerve    Pink
# 761.0                        Sweet Veil  Purple
# 762.0                        Sweet Veil  Purple
# 763.0                        Sweet Veil  Purple
# 764.0                      Natural Cure   Green
# 765.0                                     White
# 766.0                                     White
# 767.0                                      Gray
# 768.0                                      Gray
# 769.0                         Sand Veil   Brown
# 770.0                         Sand Veil   Brown
# 771.0                           Unaware   Black
# 772.0                                      Gray
# 773.0                                      Gray
# 774.0                                     Brown
# 774.1                                      Pink
# 775.0                                      Blue
# 776.0                                       Red
# 777.0                            Sturdy    Gray
# 778.0                                    Yellow
# 779.0                       Wonder Skin    Pink
# 780.0                        Cloud Nine   White
# 781.0                                     Green
# 782.0                          Overcoat    Gray
# 783.0                          Overcoat    Gray
# 784.0                          Overcoat    Gray
# 785.0                                    Yellow
# 786.0                                      Pink
# 787.0                                       Red
# 788.0                                    Purple
# 789.0                                      Blue
# 790.0                                      Blue
# 791.0                                     White
# 792.0                                    Purple
# 793.0                                     White
# 794.0                                       Red
# 795.0                                     White
# 796.0                                     Black
# 797.0                                     Green
# 798.0                                     White
# 799.0                                     Black
# 800.0                                     Black
# 801.0                                      Gray
# 802.0                                      Gray

# %% [markdown]
# ## Indexing
# Like numpy, you can index a dataframe to select elements or subsets of entries. There are a number of ways to index pandas dataframes. The two following methods are recommended:
# `.loc[]` and `.iloc[]`

# %% [markdown]
# ### .loc[ ] name-based indexing
# The first way, using `.loc[a,b]` indexes based on the __values__ of the row index and column names. This allows us to get entries where the row index value equals `a` and the column name equals `b`.

# %%
# Get the entry for index value 745.1 - Lycanroc (midnight)
pokedex_df.loc[745.1]
# Out:
# Pokemon           Lycanroc (midnight)
# HP                                 85
# Atk                               115
# Def                                75
# SpAtk                              55
# SpDef                              75
# Speed                              82
# Total                             487
# Type I                           Rock
# Type II
# Ability I                    Keen Eye
# Ability II              Vital Spirit
# Hidden Ability               No Guard
# Color                           Brown
# Name: 745.1, dtype: object

# %%
# You can get specific column values for a single entry
pokedex_df.loc[250,['Pokemon','Type I','Type II']]
# Out:
# Pokemon    Swinub
# Type I        Ice
# Type II    Ground
# Name: 250.0, dtype: object

# %%
# you can use the : notation to slice multiple rows and columns
pokedex_df.loc[690:700,'Pokemon':'Total']
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 690.0      Skrelp   50   60   60     60     60     30    320
# 691.0    Dragalge   65   75   90     97    123     44    494
# 692.0   Clauncher   50   53   62     58     63     44    330
# 693.0   Clawitzer   71   73   88    120     89     59    500
# 694.0  Helioptile   44   38   33     61     43     70    289
# 695.0   Heliolisk   62   55   52    109     94    109    481
# 696.0      Tyrunt   58   89   77     45     45     48    362
# 697.0   Tyrantrum   82  121  119     69     59     71    521
# 698.0      Amaura   77   59   50     67     63     46    362
# 699.0     Aurorus  123   77   72     99     92     58    521
# 700.0     Sylveon   95   65   65    110    130     60    525

# %%
# Similarly to numpy, you can use the : notation without indices on a side to mean "from beginning" or "to end"
pokedex_df.loc[:10,"Ability I":]
# Out:
#          Ability I Ability II Hidden Ability  Color
# Index
# 1.0       Overgrow               Chlorophyll  Green
# 2.0       Overgrow               Chlorophyll  Green
# 3.0       Overgrow               Chlorophyll  Green
# 4.0          Blaze               Solar Power    Red
# 5.0          Blaze               Solar Power    Red
# 6.0          Blaze               Solar Power    Red
# 7.0        Torrent                 Rain Dish   Blue
# 8.0        Torrent                 Rain Dish   Blue
# 9.0        Torrent                 Rain Dish   Blue
# 10.0   Shield Dust                  Run Away  Green

# %%
# and : by itself gives all of the entries in that dimension
pokedex_df.loc[:,'Pokemon'].head(10) #just return top 10 entries
# Out:
# Index
# 1.0      Bulbasaur
# 2.0        Ivysaur
# 3.0       Venusaur
# 4.0     Charmander
# 5.0     Charmeleon
# 6.0      Charizard
# 7.0       Squirtle
# 8.0      Wartortle
# 9.0      Blastoise
# 10.0      Caterpie
# Name: Pokemon, dtype: object

# %% [markdown]
# ### .iloc[ ] integer indexing
#
# The second way, using `.iloc[i,j]` uses the numpy-style integer indices to get a value. In this case, iloc takes integer values from 0 to the number of entries in that dimension.
#
# Like numpy, `.iloc[i,j]` gives the entry at the $i^{th}$ row and $j^{th}$ column.

# %%
pokedex_df.iloc[100] # gets 101st row (recall python counts from 0)
# Out:
# Pokemon            Electrode
# HP                        60
# Atk                       50
# Def                       70
# SpAtk                     80
# SpDef                     80
# Speed                    140
# Total                    480
# Type I              Electric
# Type II
# Ability I         Soundproof
# Ability II            Static
# Hidden Ability     Aftermath
# Color                    Red
# Name: 110.0, dtype: object

# %%
# The : style indexing also works for iloc
pokedex_df.iloc[25:30, 0:8]
# Out:
#          Pokemon  HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 27.0      Raichu  60   90   55     90     80    100    475
# 28.0   Sandshrew  50   75   85     20     30     40    300
# 29.0   Sandslash  75  100  110     45     55     65    450
# 30.0    Nidoran♀  55   47   52     40     40     41    275
# 31.0    Nidorina  70   62   67     55     55     56    365

# %% [markdown]
# ## Changing index column
# You can change the index column of the dataframe with `.set_index()` or reset it to default numerical indexing with `.reset_index()`.
#
# Note however, that these operations create a __copy__ of the original dataframe, and do not change the dataframe "in place" (i.e. doesn't change the original object)

# %%
# reset index to be default numerical index
reindexed_pokedex = pokedex_df.reset_index()
reindexed_pokedex.head()
# Out:
#    Index     Pokemon  HP  Atk  Def  SpAtk  SpDef  Speed  Total Type I Type II  \
# 0    1.0   Bulbasaur  45   49   49     65     65     45    318  Grass  Poison
# 1    2.0     Ivysaur  60   62   63     80     80     60    405  Grass  Poison
# 2    3.0    Venusaur  80   82   83    100    100     80    525  Grass  Poison
# 3    4.0  Charmander  39   52   43     60     50     65    309   Fire     NaN
# 4    5.0  Charmeleon  58   64   58     80     65     80    405   Fire     NaN
#
#   Ability I Ability II Hidden Ability  Color
# 0  Overgrow        NaN    Chlorophyll  Green
# 1  Overgrow        NaN    Chlorophyll  Green
# 2  Overgrow        NaN    Chlorophyll  Green
# 3     Blaze        NaN    Solar Power    Red
# 4     Blaze        NaN    Solar Power    Red

# %%
# Change the index to the Pokemon name column
pokedex_indexed_by_name = pokedex_df.reset_index().set_index('Pokemon')
pokedex_indexed_by_name
# Out:
#             Index   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Pokemon
# Bulbasaur     1.0   45   49   49     65     65     45    318     Grass
# Ivysaur       2.0   60   62   63     80     80     60    405     Grass
# Venusaur      3.0   80   82   83    100    100     80    525     Grass
# Charmander    4.0   39   52   43     60     50     65    309      Fire
# Charmeleon    5.0   58   64   58     80     65     80    405      Fire
# ...           ...  ...  ...  ...    ...    ...    ...    ...       ...
# Kartana     798.0   59  181  131     59     31    109    570     Grass
# Guzzlord    799.0  223  101   53     97     53     43    570      Dark
# Necrozma    800.0   97  107  101    127     89     79    600   Psychic
# Magearna    801.0   80   95  115    130    115     65    600     Steel
# Marshadow   802.0   90  125   80     90     90    125    600  Fighting
#
#            Type II    Ability I Ability II Hidden Ability  Color
# Pokemon
# Bulbasaur   Poison     Overgrow        NaN    Chlorophyll  Green
# Ivysaur     Poison     Overgrow        NaN    Chlorophyll  Green
# Venusaur    Poison     Overgrow        NaN    Chlorophyll  Green
# Charmander     NaN        Blaze        NaN    Solar Power    Red
# Charmeleon     NaN        Blaze        NaN    Solar Power    Red
# ...            ...          ...        ...            ...    ...
# Kartana      Steel  Beast Boost        NaN            NaN  White
# Guzzlord    Dragon  Beast Boost        NaN            NaN  Black
# Necrozma       NaN  Prism Armor        NaN            NaN  Black
# Magearna     Fairy   Soul-Heart        NaN            NaN   Gray
# Marshadow    Ghost   Technician        NaN            NaN   Gray
#
# [820 rows x 14 columns]

# %%
# note that the original dataframe was not affected
pokedex_df

# %% [markdown]
# ## Logical indexing
# You can test conditionals on a column, for example, testing if the value of the column is greater than a value. What's returned is a boolean column of the same size, with a value of `True` wherever it is true, and `False` otherwise. (This can similarly be done in numpy).

# %%
pokedex_df['Total'] > 520

# %% [markdown]
# If you take that boolean column and use it to index the dataframe, you can get all of the entries that satisfy that condition.

# %%
pokedex_df.loc[pokedex_df['Total']>=680] # all of the pokemon with total base stats greater than 500
# Out:
#             Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total   Type I  \
# Index
# 181.0        Mewtwo  106  110   90    154     90    130    680  Psychic
# 273.0         Lugia  106   90  130     90    154    110    680  Psychic
# 274.0         Ho-oh  106  130   90    110    154     90    680     Fire
# 413.0      Rayquaza  105  150   90    150     90     95    680   Dragon
# 483.0        Dialga  100  120  120    150    100     90    680    Steel
# 484.0        Palkia   90  120  100    150    120    100    680    Water
# 487.0      Giratina  150  100  120    100    120     90    680    Ghost
# 487.1  Giratina (O)  150  120  100    120    100     90    680    Ghost
# 493.0        Arceus  120  120  120    120    120    120    720   Normal
# 643.0      Reshiram  100  120  100    150    120     90    680   Dragon
# 644.0        Zekrom  100  150  120    120    100     90    680   Dragon
# 716.0       Xerneas  126  131   95    131     98     99    680    Fairy
# 717.0       Yveltal  126  131   95    131     98     99    680     Dark
# 720.0     Hoopa (U)   80  160   60    170    130     80    680  Psychic
# 791.0      Solgaleo  137  137  107    113     89     97    680  Psychic
# 792.0        Lunala  137  113   89    137    107     97    680  Psychic
#
#         Type II        Ability I Ability II Hidden Ability   Color
# Index
# 181.0       NaN         Pressure        NaN        Unnerve  Purple
# 273.0    Flying         Pressure        NaN     Multiscale   White
# 274.0    Flying         Pressure        NaN    Regenerator     Red
# 413.0    Flying         Air Lock        NaN            NaN   Green
# 483.0    Dragon         Pressure        NaN      Telepathy   White
# 484.0    Dragon         Pressure        NaN      Telepathy  Purple
# 487.0    Dragon         Pressure        NaN      Telepathy   Black
# 487.1    Dragon         Levitate        NaN            NaN   Black
# 493.0       NaN        Multitype        NaN            NaN    Gray
# 643.0      Fire       Turboblaze        NaN            NaN   White
# 644.0  Electric         Teravolt        NaN            NaN   Black
# 716.0       NaN       Fairy Aura        NaN            NaN    Blue
# 717.0    Flying        Dark Aura        NaN            NaN     Red
# 720.0      Dark         Magician        NaN            NaN  Purple
# 791.0     Steel  Full Metal Body        NaN            NaN   White
# 792.0     Ghost    Shadow Shield        NaN            NaN  Purple

# %%
# Get all of the pokemon of a given color
pokedex_df.loc[pokedex_df['Color']=='Black']

# %% [markdown]
# ### Compound boolean queries
# You can use boolean operations (OR, AND, NOT) to combine conditions
#
# We will look for pokemon with specific types to demonstrate compound queries

# %% [markdown]
# ### OR queries
# In the following example, we query for all pokemon who have at least part "Dragon" typing.
#
# The vertical line | represents the element-wise "OR" operation. "OR" operations require either or both statements on either side of the operation to be true.
#
# Thus, the below query
#
# ```query = (pokedex_df['Type I']=='Dragon') | (pokedex_df['Type II']=='Dragon')```
#
# asks, for each row, if 'Type I' is equal to "Dragon" OR 'Type II' is equal to "Dragon"

# %%
query = (pokedex_df['Type I']=='Dragon') | (pokedex_df['Type II']=='Dragon')
pokedex_df.loc[query] # Get all of the entries corresponding to the above query

# %%
(pokedex_df['Type I']=='Dragon').all()

# %% [markdown]
# ### AND queries
# The ampersand `&` character represents the element-wise boolean operation "AND". In order for an "AND" statement to be true, both conditions on either side of the operation must be true.
#
# We can combine boolean operations to construct complex queries: for example, getting all pokemon who are both Dragon and Flying types. The query below looks for pokemon who are EITHER (Primary Type "Flying" AND Secondary Type "Dragon") OR (Primary Type "Dragon" AND Secondary Type "Flying")
#
# Note that parentheses should be used to group operations so that the order of operations is clear

# %%
# you can use the backslash operator \ to continue code on the next line
query = ((pokedex_df['Type I']=='Flying') & (pokedex_df['Type II']=='Dragon'))\
        | ((pokedex_df['Type I']=='Dragon') & (pokedex_df['Type II']=='Flying'))
pokedex_df.loc[query]

# %% [markdown]
# ### NOT queries
# There are two ways to do negation. Consider the following query for selecting all pokemon who are Fire type, but not Flying
#
# ```
# query = ((pokedex_df['Type I']=='Fire') & ~(pokedex_df['Type II']=='Flying'))\
#         | ((pokedex_df['Type I']!='Flying') & (pokedex_df['Type II']=='Fire'))
# ```
#
# The first way to do negation is with the tilde ~ symbol, which negates the subsequent boolean statement:
# We use this in `~(pokedex_df['Type II']=='Flying')`.
# The parentheses determine order of operations. First we find all entries where their secondary type is "Flying"
# Then the tilde in front negates that statement, flipping all True values to False, and vice versa
#
# The second way to do negation is using the != notation, which represents "not equal to"
# We use this in `(pokedex_df['Type I']!='Flying')`
# This finds all entries where their primary type is not equal to "Flying"

# %%
query = ((pokedex_df['Type I']=='Fire') & ~(pokedex_df['Type II']=='Flying'))\
        | ((pokedex_df['Type I']!='Flying') & (pokedex_df['Type II']=='Fire'))

pokedex_df.loc[query]
# Out:
#               Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Index
# 4.0        Charmander   39   52   43     60     50     65    309      Fire
# 5.0        Charmeleon   58   64   58     80     65     80    405      Fire
# 39.0           Vulpix   38   41   40     50     65     65    299      Fire
# 40.0        Ninetales   73   76   75     81    100    100    505      Fire
# 63.0        Growlithe   55   70   45     70     50     60    350      Fire
# 64.0         Arcanine   90  110   80    100     80     95    555      Fire
# 83.0           Ponyta   50   85   55     65     65     90    410      Fire
# 84.0         Rapidash   65  100   70     80     80    105    500      Fire
# 149.0          Magmar   65   95   57    100     85     93    495      Fire
# 160.0         Flareon   65  130   60     95    110     65    525      Fire
# 186.0       Cyndaquil   39   52   43     60     50     65    309      Fire
# 187.0         Quilava   58   64   58     80     65     80    405      Fire
# 188.0      Typhlosion   78   84   78    109     85    100    534      Fire
# 248.0          Slugma   40   40   40     70     40     20    250      Fire
# 249.0        Magcargo   50   50  120     80     80     30    410      Fire
# 260.0        Houndour   45   60   30     80     50     65    330      Dark
# 261.0        Houndoom   75   90   50    110     80     95    500      Dark
# 148.0           Magby   45   75   37     70     55     83    365      Fire
# 268.0           Entei  115  115   85     90     75    100    580      Fire
# 279.0         Torchic   45   60   40     70     50     45    310      Fire
# 280.0       Combusken   60   85   60     85     60     55    405      Fire
# 281.0        Blaziken   80  120   70    110     70     80    530      Fire
# 349.0           Numel   60   60   40     65     45     35    305      Fire
# 350.0        Camerupt   70  100   70    105     75     40    460      Fire
# 351.0         Torkoal   70   85  140     85     70     20    470      Fire
# 419.0        Chimchar   44   58   44     58     44     61    309      Fire
# 420.0        Monferno   64   78   52     78     52     81    405      Fire
# 421.0       Infernape   76  104   71    104     71    108    534      Fire
# 150.0       Magmortar   75   95   67    125     95     83    540      Fire
# 479.1    Rotom (Heat)   50   65  107    105    107     86    520  Electric
# 485.0         Heatran   91   90  106    130    106     77    600      Fire
# 494.0         Victini  100  100  100    100    100    100    600   Psychic
# 498.0           Tepig   65   63   45     45     45     45    308      Fire
# 499.0         Pignite   90   93   55     70     55     55    418      Fire
# 500.0          Emboar  110  123   65    100     65     65    528      Fire
# 513.0         Pansear   50   53   48     53     48     64    316      Fire
# 514.0        Simisear   75   98   63     98     63    101    498      Fire
# 554.0        Darumaka   70   90   45     15     45     50    315      Fire
# 555.0      Darmanitan  105  140   55     30     55     95    480      Fire
# 555.1  Darmanitan (Z)  105   30  105    140    105     55    540      Fire
# 607.0         Litwick   50   30   55     65     55     20    275     Ghost
# 608.0         Lampent   60   40   60     95     60     55    370     Ghost
# 609.0      Chandelure   60   55   90    145     90     80    520     Ghost
# 631.0         Heatmor   85   97   66    105     66     65    484      Fire
# 636.0        Larvesta   55   85   55     50     55     60    360       Bug
# 637.0       Volcarona   85   60   65    135    105    100    550       Bug
# 643.0        Reshiram  100  120  100    150    120     90    680    Dragon
# 653.0        Fennekin   40   45   40     62     60     60    307      Fire
# 654.0         Braixen   59   59   58     90     70     73    409      Fire
# 655.0         Delphox   75   69   72    114    100    104    534      Fire
# 667.0          Litleo   62   50   58     73     54     72    369      Fire
# 668.0          Pyroar   86   68   72    109     66    106    507      Fire
# 721.0       Volcanion   80  110  120    130     90     70    600      Fire
# 725.0          Litten   45   65   40     60     40     70    320      Fire
# 726.0        Torracat   65   85   50     80     50     90    420      Fire
# 727.0      Incineroar   95  115   90     80     90     60    530      Fire
# 757.0        Salandit   48   44   40     71     40     77    320    Poison
# 758.0        Salazzle   68   64   60    111     60    117    480    Poison
# 776.0      Turtonator   60   78  135     91     85     36    485      Fire
#
#         Type II     Ability I  Ability II Hidden Ability   Color
# Index
# 4.0         NaN         Blaze         NaN    Solar Power     Red
# 5.0         NaN         Blaze         NaN    Solar Power     Red
# 39.0        NaN    Flash Fire         NaN        Drought   Brown
# 40.0        NaN    Flash Fire         NaN        Drought  Yellow
# 63.0        NaN    Intimidate  Flash Fire      Justified   Brown
# 64.0        NaN    Intimidate  Flash Fire      Justified   Brown
# 83.0        NaN      Run Away  Flash Fire     Flame Body  Yellow
# 84.0        NaN      Run Away  Flash Fire     Flame Body  Yellow
# 149.0       NaN    Flame Body         NaN   Vital Spirit     Red
# 160.0       NaN    Flash Fire         NaN           Guts     Red
# 186.0       NaN         Blaze         NaN     Flash Fire  Yellow
# 187.0       NaN         Blaze         NaN     Flash Fire  Yellow
# 188.0       NaN         Blaze         NaN     Flash Fire  Yellow
# 248.0       NaN   Magma Armor  Flame Body     Weak Armor     Red
# 249.0      Rock   Magma Armor  Flame Body     Weak Armor     Red
# 260.0      Fire    Early Bird  Flash Fire        Unnerve   Black
# 261.0      Fire    Early Bird  Flash Fire        Unnerve   Black
# 148.0       NaN    Flame Body         NaN   Vital Spirit     Red
# 268.0       NaN      Pressure         NaN     Flash Fire   Brown
# 279.0       NaN         Blaze         NaN    Speed Boost     Red
# 280.0  Fighting         Blaze         NaN    Speed Boost     Red
# 281.0  Fighting         Blaze         NaN    Speed Boost     Red
# 349.0    Ground     Oblivious      Simple      Own Tempo  Yellow
# 350.0    Ground   Magma Armor  Solid Rock    Anger Point     Red
# 351.0       NaN   White Smoke         NaN    Shell Armor   Brown
# 419.0       NaN         Blaze         NaN      Iron Fist   Brown
# 420.0  Fighting         Blaze         NaN      Iron Fist   Brown
# 421.0  Fighting         Blaze         NaN      Iron Fist   Brown
# 150.0       NaN    Flame Body         NaN   Vital Spirit     Red
# 479.1      Fire      Levitate         NaN            NaN     Red
# 485.0     Steel    Flash Fire         NaN     Flame Body   Brown
# 494.0      Fire  Victory Star         NaN            NaN  Yellow
# 498.0       NaN         Blaze         NaN      Thick Fat     Red
# 499.0  Fighting         Blaze         NaN      Thick Fat     Red
# 500.0  Fighting         Blaze         NaN       Reckless     Red
# 513.0       NaN      Gluttony         NaN          Blaze     Red
# 514.0       NaN      Gluttony         NaN          Blaze     Red
# 554.0       NaN        Hustle         NaN    Inner Focus     Red
# 555.0       NaN   Sheer Force         NaN       Zen Mode     Red
# 555.1   Psychic           NaN         NaN       Zen Mode     Red
# 607.0      Fire    Flash Fire  Flame Body     Shadow Tag   White
# 608.0      Fire    Flash Fire  Flame Body     Shadow Tag   Black
# 609.0      Fire    Flash Fire  Flame Body     Shadow Tag   Black
# 631.0       NaN      Gluttony  Flash Fire    White Smoke     Red
# 636.0      Fire    Flame Body         NaN          Swarm   White
# 637.0      Fire    Flame Body         NaN          Swarm   White
# 643.0      Fire    Turboblaze         NaN            NaN   White
# 653.0       NaN         Blaze         NaN       Magician     Red
# 654.0       NaN         Blaze         NaN       Magician     Red
# 655.0   Psychic         Blaze         NaN       Magician     Red
# 667.0    Normal       Rivalry     Unnerve          Moxie   Brown
# 668.0    Normal       Rivalry     Unnerve          Moxie   Brown
# 721.0     Water  Water Absorb         NaN            NaN   Brown
# 725.0       NaN        Blaze   Intimidate            NaN     Red
# 726.0       NaN        Blaze   Intimidate            NaN     Red
# 727.0      Dark        Blaze   Intimidate            NaN     Red
# 757.0      Fire    Corrosion    Oblivious      Oblivious   Black
# 758.0      Fire    Corrosion    Oblivious      Oblivious   Black
# 776.0    Dragon   Shell Armor         NaN            NaN     Red

# %%
pokedex_df.loc[pokedex_df['Atk']>100 & pokedex_df['HP']>60]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4338d65a9b6a> in <module>
# ----> 1 pokedex_df.loc[pokedex_df['Atk']>100 & pokedex_df['HP']>60]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
## Sorting
Dataframes can be sorted by value

# %%
pokedex_df.sort_values('Pokemon', ascending=False) # Sort by name descending

# %%
# You can sort by multiple columns
pokedex_df.sort_values(['Type I','Type II', 'Total'], ascending=False) # Sort by type combination, then stats descending

# %% [markdown]
# ## Adding columns, rows, and changing values
# You can add another column like:
# ```
# dataframe['NewColumnName'] = value
# ```
# `value` can be a single value, an array of the same size as the index of `dataframe`, a pandas `Series`, or a dictionary mapping `index: value` for entries in the dataframe index

# %%
pokedex_df['Nickname'] = None
pokedex_df
# Out:
#                    Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total  \
# Index
# 1.0              Bulbasaur   45   49   49     65     65     45    318
# 2.0                Ivysaur   60   62   63     80     80     60    405
# 3.0               Venusaur   80   82   83    100    100     80    525
# 4.0             Charmander   39   52   43     60     50     65    309
# 5.0             Charmeleon   58   64   58     80     65     80    405
# 6.0              Charizard   78   84   78    109     85    100    534
# 7.0               Squirtle   44   48   65     60     54     43    314
# 8.0              Wartortle   59   63   80     65     80     58    405
# 9.0              Blastoise   79   83  100     85    105     78    530
# 10.0              Caterpie   45   30   35     20     20     45    195
# 11.0               Metapod   50   20   55     25     25     30    205
# 12.0            Butterfree   60   45   50     80     80     70    385
# 13.0                Weedle   40   35   30     20     20     50    195
# 14.0                Kakuna   45   25   50     25     25     35    205
# 15.0              Beedrill   65   80   40     40     80     75    380
# 16.0                Pidgey   40   45   40     35     35     56    251
# 17.0             Pidgeotto   63   60   55     50     50     71    349
# 18.0               Pidgeot   83   80   75     70     70     91    469
# 19.0               Rattata   30   56   35     25     35     72    253
# 20.0              Raticate   55   81   60     50     70     97    413
# 21.0               Spearow   40   60   30     31     31     70    262
# 22.0                Fearow   65   90   65     61     61    100    442
# 23.0                 Ekans   30   60   44     40     54     55    283
# 24.0                 Arbok   60   85   69     65     79     80    438
# 26.0               Pikachu   35   55   30     50     40     90    300
# 27.0                Raichu   60   90   55     90     80    100    475
# 28.0             Sandshrew   50   75   85     20     30     40    300
# 29.0             Sandslash   75  100  110     45     55     65    450
# 30.0              Nidoran♀   55   47   52     40     40     41    275
# 31.0              Nidorina   70   62   67     55     55     56    365
# 32.0             Nidoqueen   90   82   87     75     85     76    495
# 33.0              Nidoran♂   46   57   40     40     40     50    273
# 34.0              Nidorino   61   72   57     55     55     65    365
# 35.0              Nidoking   81   92   77     85     75     85    495
# 37.0              Clefairy   70   45   48     60     65     35    323
# 38.0              Clefable   95   70   73     85     90     60    473
# 39.0                Vulpix   38   41   40     50     65     65    299
# 40.0             Ninetales   73   76   75     81    100    100    505
# 42.0            Jigglypuff  115   45   20     45     25     20    270
# 43.0            Wigglytuff  140   70   45     75     50     45    425
# 44.0                 Zubat   40   45   35     30     40     55    245
# 45.0                Golbat   75   80   70     65     75     90    455
# 47.0                Oddish   45   50   55     75     65     30    320
# 48.0                 Gloom   60   65   70     85     75     40    395
# 49.0             Vileplume   75   80   85    100     90     50    480
# 51.0                 Paras   35   70   55     45     55     25    285
# 52.0              Parasect   60   95   80     60     80     30    405
# 53.0               Venonat   60   55   50     40     55     45    305
# 54.0              Venomoth   70   65   60     90     75     90    450
# 55.0               Diglett   10   55   25     35     45     95    265
# 56.0               Dugtrio   35   80   50     50     70    120    405
# 57.0                Meowth   40   45   35     40     40     90    290
# 58.0               Persian   65   70   60     65     65    115    440
# 59.0               Psyduck   50   52   48     65     50     55    320
# 60.0               Golduck   80   82   78     95     80     85    500
# 61.0                Mankey   40   80   35     35     45     70    305
# 62.0              Primeape   65  105   60     60     70     95    455
# 63.0             Growlithe   55   70   45     70     50     60    350
# 64.0              Arcanine   90  110   80    100     80     95    555
# 65.0               Poliwag   40   50   40     40     40     90    300
# 66.0             Poliwhirl   65   65   65     50     50     90    385
# 67.0             Poliwrath   90   85   95     70     90     70    500
# 69.0                  Abra   25   20   15    105     55     90    310
# 70.0               Kadabra   40   35   30    120     70    105    400
# 71.0              Alakazam   55   50   45    135     85    120    490
# 72.0                Machop   70   80   50     35     35     35    305
# 73.0               Machoke   80  100   70     50     60     45    405
# 74.0               Machamp   90  130   80     65     85     55    505
# 75.0            Bellsprout   50   75   35     70     30     40    300
# 76.0            Weepinbell   65   90   50     85     45     55    390
# 77.0            Victreebel   80  105   65    100     60     70    480
# 78.0             Tentacool   40   40   35     50    100     70    335
# 79.0            Tentacruel   80   70   65     80    120    100    515
# 80.0               Geodude   40   80  100     30     30     20    300
# 81.0              Graveler   55   95  115     45     45     35    390
# 82.0                 Golem   80  110  130     55     65     45    485
# 83.0                Ponyta   50   85   55     65     65     90    410
# 84.0              Rapidash   65  100   70     80     80    105    500
# 85.0              Slowpoke   90   65   65     40     40     15    315
# 86.0               Slowbro   95   75  110    100     80     30    490
# 88.0             Magnemite   25   35   70     95     55     45    325
# 89.0              Magneton   50   60   95    120     70     70    465
# 91.0            Farfetch'd   52   65   55     58     62     60    352
# 92.0                 Doduo   35   85   45     35     35     75    310
# 93.0                Dodrio   60  110   70     60     60    100    460
# 94.0                  Seel   65   45   55     45     70     45    325
# 95.0               Dewgong   90   70   80     70     95     70    475
# 96.0                Grimer   80   80   50     40     50     25    325
# 97.0                   Muk  105  105   75     65    100     50    500
# 98.0              Shellder   30   65  100     45     25     40    305
# 99.0              Cloyster   50   90  180     85     45     70    520
# 100.0               Gastly   30   35   30    100     35     80    310
# 101.0              Haunter   45   50   45    115     55     95    405
# 102.0               Gengar   60   65   60    130     75    110    500
# 103.0                 Onix   35   45  160     30     45     70    385
# 105.0              Drowzee   60   48   45     43     90     42    328
# 106.0                Hypno   85   73   70     73    115     67    483
# 107.0               Krabby   30  105   90     25     25     50    325
# 108.0              Kingler   55  130  115     50     50     75    475
# 109.0              Voltorb   40   30   50     55     55    100    330
# 110.0            Electrode   60   50   70     80     80    140    480
# 111.0            Exeggcute   60   40   80     60     45     40    325
# 112.0            Exeggutor   95   95   85    125     65     55    520
# 113.0               Cubone   50   50   95     40     50     35    320
# 114.0              Marowak   60   80  110     50     80     45    425
# 116.0            Hitmonlee   50  120   53     35    110     87    455
# 117.0           Hitmonchan   50  105   79     35    110     76    455
# 119.0            Lickitung   90   55   75     60     75     30    385
# 121.0              Koffing   40   65   95     60     45     35    340
# 122.0              Weezing   65   90  120     85     70     60    490
# 123.0              Rhyhorn   80   85   95     30     30     25    345
# 124.0               Rhydon  105  130  120     45     45     40    485
# 127.0              Chansey  250    5    5     35    105     50    450
# 129.0              Tangela   65   55  115    100     40     60    435
# 131.0           Kangaskhan  105   95   80     40     80     90    490
# 132.0               Horsea   30   40   70     70     25     60    295
# 133.0               Seadra   55   65   95     95     45     85    440
# 135.0              Goldeen   45   67   60     35     50     63    320
# 136.0              Seaking   80   92   65     65     80     68    450
# 137.0               Staryu   30   45   55     70     55     85    340
# 138.0              Starmie   60   75   85    100     85    115    520
# 140.0             Mr. Mime   40   45   65    100    120     90    460
# 141.0              Scyther   70  110   80     55     80    105    500
# 144.0                 Jynx   65   50   35    115     95     95    455
# 146.0           Electabuzz   65   83   57     95     85    105    490
# 149.0               Magmar   65   95   57    100     85     93    495
# 151.0               Pinsir   65  125  100     55     70     85    500
# 152.0               Tauros   75  100   95     40     70    110    490
# 153.0             Magikarp   20   10   55     15     20     80    200
# 154.0             Gyarados   95  125   79     60    100     81    540
# 155.0               Lapras  130   85   80     85     95     60    535
# 156.0                Ditto   48   48   48     48     48     48    288
# 157.0                Eevee   55   55   50     45     65     55    325
# 158.0             Vaporeon  130   65   60    110     95     65    525
# 159.0              Jolteon   65   65   60    110     95    130    525
# 160.0              Flareon   65  130   60     95    110     65    525
# 165.0              Porygon   65   60   70     85     75     40    395
# 168.0              Omanyte   35   40  100     90     55     35    355
# 169.0              Omastar   70   60  125    115     70     55    495
# 170.0               Kabuto   30   80   90     55     45     55    355
# 171.0             Kabutops   60  115  105     65     70     80    495
# 172.0           Aerodactyl   80  105   65     60     75    130    515
# 174.0              Snorlax  160  110   65     65    110     30    540
# 175.0             Articuno   90   85  100     95    125     85    580
# 176.0               Zapdos   90   90   85    125     90    100    580
# 177.0              Moltres   90  100   90    125     85     90    580
# 178.0              Dratini   41   64   45     50     50     50    300
# 179.0            Dragonair   61   84   65     70     70     70    420
# 180.0            Dragonite   91  134   95    100    100     80    600
# 181.0               Mewtwo  106  110   90    154     90    130    680
# 182.0                  Mew  100  100  100    100    100    100    600
# 183.0            Chikorita   45   49   65     49     65     45    318
# 184.0              Bayleef   60   62   80     63     80     69    414
# 185.0             Meganium   80   82  100     83    100     80    525
# 186.0            Cyndaquil   39   52   43     60     50     65    309
# 187.0              Quilava   58   64   58     80     65     80    405
# 188.0           Typhlosion   78   84   78    109     85    100    534
# 189.0             Totodile   50   65   64     44     48     43    314
# 190.0             Croconaw   65   80   80     59     63     58    405
# 191.0           Feraligatr   85  105  100     79     83     78    530
# 192.0              Sentret   35   46   34     35     45     20    215
# 193.0               Furret   85   76   64     45     55     90    415
# 194.0             Hoothoot   60   30   30     36     56     50    262
# 195.0              Noctowl  100   50   50     76     96     70    442
# 196.0               Ledyba   40   20   30     40     80     55    265
# 197.0               Ledian   55   35   50     55    110     85    390
# 198.0             Spinarak   40   60   40     40     40     30    250
# 199.0              Ariados   70   90   70     60     60     40    390
# 46.0                Crobat   85   90   80     70     80    130    535
# 200.0             Chinchou   75   38   38     56     56     67    330
# 201.0              Lanturn  125   58   58     76     76     67    460
# 25.0                 Pichu   20   40   15     35     35     60    205
# 36.0                Cleffa   50   25   28     45     55     15    218
# 41.0             Igglybuff   90   30   15     40     20     15    210
# 202.0               Togepi   35   20   65     40     65     20    245
# 203.0              Togetic   55   40   85     80    105     40    405
# 205.0                 Natu   40   50   45     70     45     70    320
# 206.0                 Xatu   65   75   70     95     70     95    470
# 207.0               Mareep   55   40   40     65     45     35    280
# 208.0              Flaaffy   70   55   55     80     60     45    365
# 209.0             Ampharos   90   75   75    115     90     55    500
# 50.0             Bellossom   75   80   85     90    100     50    480
# 211.0               Marill   70   20   50     20     50     40    250
# 212.0            Azumarill  100   50   80     50     80     50    410
# 214.0            Sudowoodo   70  100  115     30     65     30    410
# 68.0              Politoed   90   75   75     90    100     70    500
# 215.0               Hoppip   35   35   40     35     55     50    250
# 216.0             Skiploom   55   45   50     45     65     80    340
# 217.0             Jumpluff   75   55   70     55     85    110    450
# 218.0                Aipom   55   70   55     40     55     85    360
# 220.0              Sunkern   30   30   30     30     30     30    180
# 221.0             Sunflora   75   75   55    105     85     30    425
# 222.0                Yanma   65   65   45     75     45     95    390
# 224.0               Wooper   55   45   45     25     25     15    210
# 225.0             Quagsire   95   85   85     65     65     35    430
# 161.0               Espeon   65   65   60    130     95    110    525
# 162.0              Umbreon   95   65  110     60    130     65    525
# 226.0              Murkrow   60   85   42     85     42     91    405
# 87.0              Slowking   95   75   80    100    110     30    490
# 228.0           Misdreavus   60   60   60     85     85     85    435
# 230.0                Unown   48   72   48     72     48     48    336
# 232.0            Wobbuffet  190   33   58     33     58     33    405
# 233.0            Girafarig   70   80   65     90     65     85    455
# 234.0               Pineco   50   65   90     35     35     15    290
# 235.0           Forretress   75   90  140     60     60     40    465
# 236.0            Dunsparce  100   70   70     65     65     45    415
# 237.0               Gligar   65   75  105     35     65     85    430
# 104.0              Steelix   75   85  200     55     65     30    510
# 239.0             Snubbull   60   80   50     40     40     30    300
# 240.0             Granbull   90  120   75     60     60     45    450
# 241.0             Qwilfish   65   95   75     55     55     85    430
# 142.0               Scizor   70  130  100     55     80     65    500
# 242.0              Shuckle   20   10  230     10    230      5    505
# 243.0            Heracross   80  125   75     40     95     85    500
# 244.0              Sneasel   55   95   55     35     75    115    430
# 246.0            Teddiursa   60   80   50     50     50     40    330
# 247.0             Ursaring   90  130   75     75     75     55    500
# 248.0               Slugma   40   40   40     70     40     20    250
# 249.0             Magcargo   50   50  120     80     80     30    410
# 250.0               Swinub   50   50   40     30     30     50    250
# 251.0            Piloswine  100  100   80     60     60     50    450
# 253.0              Corsola   55   55   85     65     85     35    380
# 254.0             Remoraid   35   65   35     65     35     65    300
# 255.0            Octillery   75  105   75    105     75     45    480
# 256.0             Delibird   45   55   45     65     45     75    330
# 258.0              Mantine   65   40   70     80    140     70    465
# 259.0             Skarmory   65   80  140     40     70     70    465
# 260.0             Houndour   45   60   30     80     50     65    330
# 261.0             Houndoom   75   90   50    110     80     95    500
# 134.0              Kingdra   75   95   95     95     95     85    540
# 262.0               Phanpy   90   60   60     40     40     40    330
# 263.0              Donphan   90  120  120     60     60     50    500
# 166.0             Porygon2   85   80   90    105     95     60    515
# 264.0             Stantler   73   95   62     85     65     85    465
# 265.0             Smeargle   55   20   35     20     45     75    250
# 115.0              Tyrogue   35   35   35     35     35     35    210
# 118.0            Hitmontop   50   95   95     35    110     70    455
# 143.0             Smoochum   45   30   15     85     65     65    305
# 145.0               Elekid   45   63   37     65     55     95    360
# 148.0                Magby   45   75   37     70     55     83    365
# 266.0              Miltank   95   80  105     40     70    100    490
# 128.0              Blissey  255   10   10     75    135     55    540
# 267.0               Raikou   90   85   75    115    100    115    580
# 268.0                Entei  115  115   85     90     75    100    580
# 269.0              Suicune  100   75  115     90    115     85    580
# 270.0             Larvitar   50   64   50     45     50     41    300
# 271.0              Pupitar   70   84   70     65     70     51    410
# 272.0            Tyranitar  100  134  110     95    100     61    600
# 334.0            Electrike   40   45   40     65     40     65    295
# 335.0            Manectric   70   75   60    105     60    105    475
# 336.0               Plusle   60   50   40     85     75     95    405
# 337.0                Minun   60   40   50     75     85     95    405
# 338.0              Volbeat   65   73   55     47     75     85    400
# 339.0             Illumise   65   47   55     73     75     85    400
# 341.0              Roselia   50   60   45    100     80     65    400
# 343.0               Gulpin   70   43   53     43     53     40    302
# 344.0               Swalot  100   73   83     73     83     55    467
# 345.0             Carvanha   45   90   20     65     20     65    305
# 346.0             Sharpedo   70  120   40     95     40     95    460
# 347.0              Wailmer  130   70   35     70     35     60    400
# 348.0              Wailord  170   90   45     90     45     60    500
# 349.0                Numel   60   60   40     65     45     35    305
# 350.0             Camerupt   70  100   70    105     75     40    460
# 351.0              Torkoal   70   85  140     85     70     20    470
# 352.0               Spoink   60   25   35     70     80     60    330
# 353.0              Grumpig   80   45   65     90    110     80    470
# 354.0               Spinda   60   60   60     60     60     60    360
# 355.0             Trapinch   45  100   45     45     45     10    290
# 356.0              Vibrava   50   70   50     50     50     70    340
# 357.0               Flygon   80  100   80     80     80    100    520
# 358.0               Cacnea   50   85   40     85     40     35    335
# 359.0             Cacturne   70  115   60    115     60     55    475
# 360.0               Swablu   45   40   60     40     75     50    310
# 361.0              Altaria   75   70   90     70    105     80    490
# 362.0             Zangoose   73  115   60     60     60     90    458
# 363.0              Seviper   73  100   60    100     60     65    458
# 364.0             Lunatone   70   55   65     95     85     70    440
# 365.0              Solrock   70   95   85     55     65     70    440
# 366.0             Barboach   50   48   43     46     41     60    288
# 367.0             Whiscash  110   78   73     76     71     60    468
# 368.0             Corphish   43   80   65     50     35     35    308
# 369.0            Crawdaunt   63  120   85     90     55     55    468
# 370.0               Baltoy   40   40   55     40     70     55    300
# 371.0              Claydol   60   70  105     70    120     75    500
# 372.0               Lileep   66   41   77     61     87     23    355
# 373.0              Cradily   86   81   97     81    107     43    495
# 374.0              Anorith   45   95   50     40     50     75    355
# 375.0              Armaldo   75  125  100     70     80     45    495
# 376.0               Feebas   20   15   20     10     55     80    200
# 377.0              Milotic   95   60   79    100    125     81    540
# 378.0             Castform   70   70   70     70     70     70    420
# 379.0              Kecleon   60   90   70     60    120     40    440
# 380.0              Shuppet   44   75   35     63     33     45    295
# 381.0              Banette   64  115   65     83     63     65    455
# 382.0              Duskull   20   40   90     30     90     25    295
# 383.0             Dusclops   40   70  130     60    130     25    455
# 385.0              Tropius   99   68   83     72     87     51    460
# 387.0             Chimecho   65   50   70     95     80     65    425
# 388.0                Absol   65  130   60     75     60     75    465
# 231.0               Wynaut   95   23   48     23     48     23    260
# 389.0              Snorunt   50   50   50     50     50     50    300
# 390.0               Glalie   80   80   80     80     80     80    480
# 392.0               Spheal   70   40   50     55     50     25    290
# 393.0               Sealeo   90   60   70     75     70     45    410
# 394.0              Walrein  110   80   90     95     90     65    530
# 395.0             Clamperl   35   64   85     74     55     32    345
# 396.0              Huntail   55  104  105     94     75     52    485
# 397.0             Gorebyss   55   84  105    114     75     52    485
# 398.0            Relicanth  100   90  130     45     65     55    485
# 399.0              Luvdisc   43   30   55     40     65     97    330
# 400.0                Bagon   45   75   60     40     30     50    300
# 401.0              Shelgon   65   95  100     60     50     50    420
# 402.0            Salamence   95  135   80    110     80    100    600
# 403.0               Beldum   40   55   80     35     60     30    300
# 404.0               Metang   60   75  100     55     80     50    420
# 405.0            Metagross   80  135  130     95     90     70    600
# 406.0             Regirock   80  100  200     50    100     50    580
# 407.0               Regice   80   50  100    100    200     50    580
# 408.0            Registeel   80   75  150     75    150     50    580
# 409.0               Latias   80   80   90    110    130    110    600
# 410.0               Latios   80   90   80    130    110    110    600
# 411.0               Kyogre  100  100   90    150    140     90    670
# 412.0              Groudon  100  150  140    100     90     90    670
# 413.0             Rayquaza  105  150   90    150     90     95    680
# 414.0              Jirachi  100  100  100    100    100    100    600
# 415.0           Deoxys (N)   50  150   50    150     50    150    600
# 415.1           Deoxys (A)   50  180   20    180     20    150    600
# 415.2           Deoxys (D)   50   70  160     70    160     90    600
# 415.3           Deoxys (S)   50   95   90     95     90    180    600
# 416.0              Turtwig   55   68   64     45     55     31    318
# 417.0               Grotle   75   89   85     55     65     36    405
# 418.0             Torterra   95  109  105     75     85     56    525
# 419.0             Chimchar   44   58   44     58     44     61    309
# 420.0             Monferno   64   78   52     78     52     81    405
# 421.0            Infernape   76  104   71    104     71    108    534
# 422.0               Piplup   53   51   53     61     56     40    314
# 423.0             Prinplup   64   66   68     81     76     50    405
# 424.0             Empoleon   84   86   88    111    101     60    530
# 425.0               Starly   40   55   30     30     30     60    245
# 426.0             Staravia   55   75   50     40     40     80    340
# 427.0            Staraptor   85  120   70     50     50    100    475
# 428.0               Bidoof   59   45   40     35     40     31    250
# 429.0              Bibarel   79   85   60     60     71     55    410
# 430.0            Kricketot   37   25   41     25     41     25    194
# 431.0           Kricketune   77   85   51     55     51     65    384
# 432.0                Shinx   45   65   34     40     34     45    263
# 433.0                Luxio   60   85   49     60     49     60    363
# 434.0               Luxray   80  120   79     95     79     70    523
# 340.0                Budew   40   30   35     50     70     55    280
# 342.0             Roserade   60   70   55    125    105     90    505
# 435.0             Cranidos   67  125   40     30     30     58    350
# 436.0            Rampardos   97  165   60     65     50     58    495
# 437.0             Shieldon   30   42  118     42     88     30    350
# 438.0            Bastiodon   60   52  168     47    138     30    495
# 439.0                Burmy   40   29   45     29     45     36    224
# 440.0         Wormadam (P)   60   59   85     79    105     36    424
# 440.1         Wormadam (S)   60   79  105     59     85     36    424
# 440.2         Wormadam (T)   60   69   95     69     95     36    424
# 441.0               Mothim   70   94   50     94     50     66    424
# 442.0               Combee   30   30   42     30     42     70    244
# 443.0            Vespiquen   70   80  102     80    102     40    474
# 444.0            Pachirisu   60   45   70     45     90     95    405
# 445.0               Buizel   55   65   35     60     30     85    330
# 446.0             Floatzel   85  105   55     85     50    115    495
# 447.0              Cherubi   45   35   45     62     53     35    275
# 448.0              Cherrim   70   60   70     87     78     85    450
# 449.0              Shellos   76   48   48     57     62     34    325
# 450.0            Gastrodon  111   83   68     92     82     39    475
# 479.4         Rotom (Spin)   50   65  107    105    107     86    520
# 479.5          Rotom (Cut)   50   65  107    105    107     86    520
# 480.0                 Uxie   75   75  130     75    130     95    580
# 481.0              Mesprit   80  105  105    105    105     80    580
# 482.0                Azelf   75  125   70    125     70    115    580
# 483.0               Dialga  100  120  120    150    100     90    680
# 484.0               Palkia   90  120  100    150    120    100    680
# 485.0              Heatran   91   90  106    130    106     77    600
# 486.0            Regigigas  110  160  110     80    110    100    670
# 487.0             Giratina  150  100  120    100    120     90    680
# 487.1         Giratina (O)  150  120  100    120    100     90    680
# 488.0            Cresselia  120   70  120     75    130     85    600
# 489.0               Phione   80   80   80     80     80     80    480
# 490.0              Manaphy  100  100  100    100    100    100    600
# 491.0              Darkrai   70   90   90    135     90    125    600
# 492.0              Shaymin  100  100  100    100    100    100    600
# 492.1          Shaymin (S)  100  103   75    120     75    127    600
# 493.0               Arceus  120  120  120    120    120    120    720
# 494.0              Victini  100  100  100    100    100    100    600
# 495.0                Snivy   45   45   55     45     55     63    308
# 496.0              Servine   60   60   75     60     75     83    413
# 497.0            Serperior   75   75   95     75     95    113    528
# 498.0                Tepig   65   63   45     45     45     45    308
# 499.0              Pignite   90   93   55     70     55     55    418
# 500.0               Emboar  110  123   65    100     65     65    528
# 501.0             Oshawott   55   55   45     63     45     45    308
# 502.0               Dewott   75   75   60     83     60     60    413
# 503.0             Samurott   95  100   85    108     70     70    528
# 504.0               Patrat   45   55   39     35     39     42    255
# 505.0              Watchog   60   85   69     60     69     77    420
# 506.0             Lillipup   45   60   45     25     45     55    275
# 507.0              Herdier   65   80   65     35     65     60    370
# 508.0            Stoutland   85  100   90     45     90     80    490
# 509.0             Purrloin   41   50   37     50     37     66    281
# 510.0              Liepard   64   88   50     88     50    106    446
# 511.0              Pansage   50   53   48     53     48     64    316
# 512.0             Simisage   75   98   63     98     63    101    498
# 513.0              Pansear   50   53   48     53     48     64    316
# 514.0             Simisear   75   98   63     98     63    101    498
# 515.0              Panpour   50   53   48     53     48     64    316
# 516.0             Simipour   75   98   63     98     63    101    498
# 517.0                Munna   76   25   45     67     55     24    292
# 518.0             Musharna  116   55   85    107     95     29    487
# 519.0               Pidove   50   55   50     36     30     43    264
# 520.0            Tranquill   62   77   62     50     42     65    358
# 521.0             Unfezant   80  105   80     65     55     93    478
# 522.0              Blitzle   45   60   32     50     32     76    295
# 523.0            Zebstrika   75  100   63     80     63    116    497
# 524.0           Roggenrola   55   75   85     25     25     15    280
# 525.0              Boldore   70  105  105     50     40     20    390
# 526.0             Gigalith   85  135  130     60     70     25    505
# 527.0               Woobat   55   45   43     55     43     72    313
# 528.0              Swoobat   67   57   55     77     55    114    425
# 529.0              Drilbur   60   85   40     30     45     68    328
# 530.0            Excadrill  110  135   60     50     65     88    508
# 531.0               Audino  103   60   86     60     86     50    445
# 532.0              Timburr   75   80   55     25     35     35    305
# 533.0              Gurdurr   85  105   85     40     50     40    405
# 534.0           Conkeldurr  105  140   95     55     65     45    505
# 535.0              Tympole   50   50   40     50     40     64    294
# 129.0     Tangela  65   55  115    100     40     60    435  Grass
#
#          Ability I  Ability II Hidden Ability Color Nickname
# Index
# 4.0          Blaze                Solar Power   Red     Abby
# 129.0  Chlorophyll  Leaf Guard    Regenerator  Blue    Terry

# %% [markdown]
# ## Combining Dataframes
# ### Appending

# %% [markdown]
# Some of you may have noticed that the pokedex file only includes Generations 1-7 of pokemon. Let's add the pokemon from Gen 8. The file `pokedex_gen8.csv` contains the pokedex entries for all of the pokemon that show up in the 8th generation of games (Sword/Shield).

# %%
# you can add another dataframe on to the end using append()
gen8_pokedex_df = pd.read_csv('pokedex_gen8.csv') # create a dataframe with new entries

# %%
appended_pokedex_df = pokedex_df.append(gen8_pokedex_df, ignore_index=True, sort=False) # the sort=False keyword prevents the columns from being reordered alphabetically
appended_pokedex_df = appended_pokedex_df.fillna('').drop_duplicates() # some cleanup operations, replace NaN with emptry strings, and drop duplicate rows
appended_pokedex_df
# Out:
#          Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed Total    Type I Type II  \
# 0      Bulbasaur   45   49   49     65     65     45   318     Grass  Poison
# 1        Ivysaur   60   62   63     80     80     60   405     Grass  Poison
# 2       Venusaur   80   82   83    100    100     80   525     Grass  Poison
# 3     Charmander   39   52   43     60     50     65   309      Fire
# 4     Charmeleon   58   64   58     80     65     80   405      Fire
# ...          ...  ...  ...  ...    ...    ...    ...   ...       ...     ...
# 1215    Drakloak   68   80   50     60     50    102          dragon   ghost
# 1216   Dragapult   88  120   75    100     75    142          dragon   ghost
# 1217      Zacian   92  130  115     80    115    138           fairy
# 1218   Zamazenta   92  130  115     80    115    138        fighting
# 1219   Eternatus  140   85   95    145     95    130          poison  dragon
#
#              Ability I   Ability II Hidden Ability  Color  \
# 0             Overgrow                 Chlorophyll  Green
# 1             Overgrow                 Chlorophyll  Green
# 2             Overgrow                 Chlorophyll  Green
# 3                Blaze                 Solar Power    Red
# 4                Blaze                 Solar Power    Red
# ...                ...          ...            ...    ...
# 1215        Clear Body  Infiltrator    Cursed Body
# 1216        Clear Body  Infiltrator    Cursed Body
# 1217    Intrepid Sword
# 1218  Dauntless Shield
# 1219          Pressure
#
#      Galar Pokedex Number Weight_kg Height_m Weight_lbs Height_ft Cap_Rate  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...       ...      ...        ...       ...      ...
# 1215                  396        11      1.4       24.3     4.583       45
# 1216                  397        50        3      110.2     9.833       45
# 1217                  398       110      2.8      242.5     9.167       10
# 1218                  399       210      2.9        463       9.5       10
# 1219                  400       950       20     2094.4    65.583      255
#
#      Egg_Steps     Classification
# 0
# 1
# 2
# 3
# 4
# ...        ...                ...
# 1215     10240  Caretaker Pokémon
# 1216     10240    Stealth Pokémon
# 1217     30720    Warrior Pokémon
# 1218     30720    Warrior Pokémon
# 1219     30720   Gigantic Pokémon
#
# [1220 rows x 22 columns]

# %% [markdown]
# However, you may notice that some pokemon show up twice in the combined dataframe, and since the entries in `gen8_pokedex_df` includes different columns, `remove_duplicates` does not see those entries as duplicates.
#
# To remedy this, we can index both dataframes by the name of the pokemon and use the [`combine_first`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.combine_first.html#pandas.DataFrame.combine_first) function to fill in the null values of one dataframe with the corresponding values in the other.

# %%
gen8_pokedex_indexed_by_name = gen8_pokedex_df.reset_index().set_index('Pokemon')
combined_pokedex_df = pokedex_indexed_by_name.combine_first(gen8_pokedex_indexed_by_name)
combined_pokedex_df
# Out:
#                Ability I   Ability II    Atk  Cap_Rate        Classification  \
# Pokemon
# Abomasnow   Snow Warning          NaN   92.0      60.0  Frosted Tree Pokémon
# Abra         Synchronize  Inner Focus   20.0       NaN                   NaN
# Absol           Pressure   Super Luck  130.0       NaN                   NaN
# Accelgor       Hydration  Sticky Hold   70.0      75.0     Shell Out Pokémon
# Aegislash  Stance Change          NaN   50.0      45.0   Royal Sword Pokémon
# ...                  ...          ...    ...       ...                   ...
# Zoroark         Illusion          NaN  105.0       NaN                   NaN
# Zorua           Illusion          NaN   65.0       NaN                   NaN
# Zubat        Inner Focus          NaN   45.0       NaN                   NaN
# Zweilous          Hustle          NaN   85.0      45.0       Hostile Pokémon
# Zygarde       Aura Break          NaN  100.0       NaN                   NaN
#
#             Color    Def  Egg_Steps  Galar Pokedex Number     HP  Height_ft  \
# Pokemon
# Abomasnow   White   75.0     5120.0                  97.0   90.0      7.250
# Abra        Brown   15.0        NaN                   NaN   25.0        NaN
# Absol       White   60.0        NaN                   NaN   65.0        NaN
# Accelgor      Red   40.0     3840.0                 276.0   80.0      2.583
# Aegislash   Brown  150.0     5120.0                 332.0   60.0      5.583
# ...           ...    ...        ...                   ...    ...        ...
# Zoroark      Gray   60.0        NaN                   NaN   60.0        NaN
# Zorua        Gray   40.0        NaN                   NaN   40.0        NaN
# Zubat      Purple   35.0        NaN                   NaN   40.0        NaN
# Zweilous     Blue   70.0    10240.0                 387.0   72.0      4.583
# Zygarde     Green  121.0        NaN                   NaN  108.0        NaN
#
#            Height_m Hidden Ability  Index  SpAtk  SpDef  Speed  Total  \
# Pokemon
# Abomasnow       2.2     Soundproof  478.0   92.0   85.0   60.0  494.0
# Abra            NaN    Magic Guard   69.0  105.0   55.0   90.0  310.0
# Absol           NaN      Justified  388.0   75.0   60.0   75.0  465.0
# Accelgor        0.8       Unburden  617.0  100.0   60.0  145.0  495.0
# Aegislash       1.7            NaN  681.0   50.0  150.0   60.0  520.0
# ...             ...            ...    ...    ...    ...    ...    ...
# Zoroark         NaN            NaN  571.0  120.0   60.0  105.0  510.0
# Zorua           NaN            NaN  570.0   80.0   40.0   65.0  330.0
# Zubat           NaN    Infiltrator   44.0   30.0   40.0   55.0  245.0
# Zweilous        1.4            NaN  634.0   65.0   70.0   58.0  420.0
# Zygarde         NaN            NaN  718.0   81.0   95.0   95.0  600.0
#
#             Type I Type II  Weight_kg  Weight_lbs  index
# Pokemon
# Abomasnow      Ice   Grass      135.5       298.7   96.0
# Abra       Psychic     NaN        NaN         NaN    NaN
# Absol         Dark     NaN        NaN         NaN    NaN
# Accelgor       Bug     NaN       25.3        55.8  275.0
# Aegislash    Steel   Ghost       53.0       116.8  331.0
# ...            ...     ...        ...         ...    ...
# Zoroark       Dark     NaN        NaN         NaN    NaN
# Zorua         Dark     NaN        NaN         NaN    NaN
# Zubat       Poison  Flying        NaN         NaN    NaN
# Zweilous      Dark  Dragon       50.0       110.2  386.0
# Zygarde     Dragon  Ground        NaN         NaN    NaN
#
# [909 rows x 23 columns]

# %% [markdown]
# ### Merges and Joins
# A more advanced way to join dataframes is using the `merge` or `join` operations.
#
# For those who have worked with SQL-style databases before, you may be familiar with `merge` and `join` operations. They are done to combine two tables or dataframes which share values in certain columns. This allows us to look up entries in another dataframe using the values of our current dataframe.
#
# In this example, we will use `merge` to get the stats for a team of pokemon. This dataframe will just contain the names and nicknames of the pokemon that we want on our team. After we perform a merge, we will get a dataframe with the respective statistics for the pokemon we've chosen.

# %%
# feel free to replace the names of pokemon with ones you want on your team
team_df = pd.DataFrame({'my pokemon':['Bulbasaur','Squirtle','Charmander'],
                       'nickname':['leafygurl','h2woah','toaster']})
team_df
# Out:
#    my pokemon   nickname
# 0   Bulbasaur  leafygurl
# 1    Squirtle     h2woah
# 2  Charmander    toaster

# %% [markdown]
# There are four merge/join types in `pandas`:
# - (INNER) JOIN: Returns records that have matching values in both tables
# - (LEFT) JOIN: Returns all records from the left table, and the matched records from the right table
# - (RIGHT) JOIN: Returns all records from the right table, and the matched records from the left table
# - (OUTER) JOIN: Returns all records when there is a match in either left or right table
#
#
#  ![inner join illustration, venn diagram with intersection colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_innerjoin.gif)
#   ![left join illustration, venn diagram with full left circle colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_leftjoin.gif)
#   ![right join illustration, venn diagram with full right circle colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_rightjoin.gif)
#   ![outer join illustration, venn diagram with union of two circles colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_fulljoin.gif)
#
# The information that we need in order to perform a merge is:
# - what dataframes to merge
# - what kind of merge/join (inner/left/right/outer)
# - what columns to merge on in each dataframe
#
# Knowing this, let's look at the function signature of merge for a dataframe

# %%
# you can use the question mark symbol ? to examine the function signature
pokedex_df.merge?
# Out:
# Signature:
# pokedex_df.merge(
#     right,
#     how='inner',
#     on=None,
#     left_on=None,
#     right_on=None,
#     left_index=False,
#     right_index=False,
#     sort=False,
#     suffixes=('_x', '_y'),
#     copy=True,
#     indicator=False,
#     validate=None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
#
# Parameters
# ----------
# right : DataFrame or named Series
#     Object to merge with.
# how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#     Type of merge to be performed.
#
#     * left: use only keys from left frame, similar to a SQL left outer join;
#       preserve key order.
#     * right: use only keys from right frame, similar to a SQL right outer join;
#       preserve key order.
#     * outer: use union of keys from both frames, similar to a SQL full outer
#       join; sort keys lexicographically.
#     * inner: use intersection of keys from both frames, similar to a SQL inner
#       join; preserve the order of the left keys.
# on : label or list
#     Column or index level names to join on. These must be found in both
#     DataFrames. If `on` is None and not merging on indexes then this defaults
#     to the intersection of the columns in both DataFrames.
# left_on : label or list, or array-like
#     Column or index level names to join on in the left DataFrame. Can also
#     be an array or list of arrays of the length of the left DataFrame.
#     These arrays are treated as if they are columns.
# right_on : label or list, or array-like
#     Column or index level names to join on in the right DataFrame. Can also
#     be an array or list of arrays of the length of the right DataFrame.
#     These arrays are treated as if they are columns.
# left_index : bool, default False
#     Use the index from the left DataFrame as the join key(s). If it is a
#     MultiIndex, the number of keys in the other DataFrame (either the index
#     or a number of columns) must match the number of levels.
# right_index : bool, default False
#     Use the index from the right DataFrame as the join key. Same caveats as
#     left_index.
# sort : bool, default False
#     Sort the join keys lexicographically in the result DataFrame. If False,
#     the order of the join keys depends on the join type (how keyword).
# suffixes : tuple of (str, str), default ('_x', '_y')
#     Suffix to apply to overlapping column names in the left and right
#     side, respectively. To raise an exception on overlapping columns use
#     (False, False).
# copy : bool, default True
#     If False, avoid copy if possible.
# indicator : bool or str, default False
#     If True, adds a column to output DataFrame called "_merge" with
#     information on the source of each row.
#     If string, column with information on source of each row will be added to
#     output DataFrame, and column will be named value of string.
#     Information column is Categorical-type and takes on a value of "left_only"
#     for observations whose merge key only appears in 'left' DataFrame,
#     "right_only" for observations whose merge key only appears in 'right'
#     DataFrame, and "both" if the observation's merge key is found in both.
#
# validate : str, optional
#     If specified, checks if merge is of specified type.
#
#     * "one_to_one" or "1:1": check if merge keys are unique in both
#       left and right datasets.
#     * "one_to_many" or "1:m": check if merge keys are unique in left
#       dataset.
#     * "many_to_one" or "m:1": check if merge keys are unique in right
#       dataset.
#     * "many_to_many" or "m:m": allowed, but does not result in checks.
#
#     .. versionadded:: 0.21.0
#
# Returns
# -------
# DataFrame
#     A DataFrame of the two merged objects.
#
# See Also
# --------
# merge_ordered : Merge with optional filling/interpolation.
# merge_asof : Merge on nearest keys.
# DataFrame.join : Similar method using indices.
#
# Notes
# -----
# Support for specifying index levels as the `on`, `left_on`, and
# `right_on` parameters was added in version 0.23.0
# Support for merging named Series objects was added in version 0.24.0
#
# Examples
# --------
#
# >>> df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
# ...                     'value': [1, 2, 3, 5]})
# >>> df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
# ...                     'value': [5, 6, 7, 8]})
# >>> df1
#     lkey value
# 0   foo      1
# 1   bar      2
# 2   baz      3
# 3   foo      5
# >>> df2
#     rkey value
# 0   foo      5
# 1   bar      6
# 2   baz      7
# 3   foo      8
#
# Merge df1 and df2 on the lkey and rkey columns. The value columns have
# the default suffixes, _x and _y, appended.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey')
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7
#
# Merge DataFrames df1 and df2 with specified left and right suffixes
# appended to any overlapping columns.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey',
# ...           suffixes=('_left', '_right'))
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7
#
# Merge DataFrames df1 and df2, but raise an exception if the DataFrames have
# any overlapping columns.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=(False, False))
# Traceback (most recent call last):
# ...
# ValueError: columns overlap but no suffix specified:
#     Index(['value'], dtype='object')
# File:      /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py
# Type:      method

# %% [markdown]
# The answers to the following questions to get the team dataframe with stats are:
#
# **what dataframes to merge?**
# `team_df` and `combined_pokedex_df`
#
# **what kind of merge/join (inner/left/right/outer)?**
# inner or left
#
# **what columns to merge on in each dataframe**
# for `team_df`, the column is `my pokemon`, for `combined_pokedex_df`, it is the index.

# %%
team_with_stats = team_df.merge(combined_pokedex_df, how='inner',
                               left_on='my pokemon', right_index=True)
team_with_stats
# Out:
#    my pokemon   nickname Ability I Ability II   Atk  Cap_Rate  Classification  \
# 0   Bulbasaur  leafygurl  Overgrow             49.0       NaN             NaN
# 1    Squirtle     h2woah   Torrent             48.0       NaN             NaN
# 2  Charmander    toaster     Blaze             52.0      45.0  Lizard Pokémon
#
#    Color   Def  Egg_Steps  Galar Pokedex Number    HP  Height_ft  Height_m  \
# 0  Green  49.0        NaN                   NaN  45.0        NaN       NaN
# 1   Blue  65.0        NaN                   NaN  44.0        NaN       NaN
# 2    Red  43.0     5120.0                 378.0  39.0        2.0       0.6
#
#   Hidden Ability  Index  SpAtk  SpDef  Speed  Total Type I Type II  Weight_kg  \
# 0    Chlorophyll    1.0   65.0   65.0   45.0  318.0  Grass  Poison        NaN
# 1      Rain Dish    7.0   60.0   54.0   43.0  314.0  Water                NaN
# 2    Solar Power    4.0   60.0   50.0   65.0  309.0   Fire                8.5
#
#    Weight_lbs  index
# 0         NaN    NaN
# 1         NaN    NaN
# 2        18.7  377.0

# %%
# we can select specific columns from the dataframe
team_with_stats.loc[:,['my pokemon','nickname','Total']]
# Out:
#    my pokemon   nickname  Total
# 0   Bulbasaur  leafygurl  318.0
# 1    Squirtle     h2woah  314.0
# 2  Charmander    toaster  309.0

# %% [markdown]
# ### Exercise
# Put together a team of pokemon by editing `team_df` and performing a `merge`. Remember that you can only have 6 pokemon on a team at once.

# %%
team_df = pd.DataFrame({'my pokemon':['Lunala','Yveltal','Xerneas', 'Zekrom','Arceus', 'Giratina'],
                       'nickname':['Luny','Talest','Toaster','Zark','Archy','Giga']})
team_with_stats = team_df.merge(combined_pokedex_df, how='inner',
                               left_on='my pokemon', right_index=True)
team_with_stats.loc[:,['my pokemon','nickname','Total']]
# Out:
#   my pokemon nickname  Total
# 0     Lunala     Luny  680.0
# 1    Yveltal   Talest  680.0
# 2    Xerneas  Toaster  680.0
# 3     Zekrom     Zark  680.0
# 4     Arceus    Archy  720.0
# 5   Giratina     Giga  680.0

# %% [markdown]
# ## Calculations and operations
# There are various ways to do math to the dataframes

# %% [markdown]
# ### Column operations
# You can perform basic math element-wise between columns, such as addition, subtraction, multiplication, and division.
#
# Note that the `gen8_pokedex_df` does not contain a `Total` stats column, so currently the gen8 pokemon have `NaN` in that column. We can fix that, because `Total` is generated as the sum of the respective `HP` `Atk` `Def` `SpAtk` `SpDef` and `Speed`. We can add the entire columns at once, without having to loop over each entry. Pandas supports vectorized operations behind the scenes.

# %%
# these are the entries missing 'Total' stats
combined_pokedex_df.loc[combined_pokedex_df['Total'].isnull()]
# Out:
#                     Ability I      Ability II    Atk  Cap_Rate  \
# Pokemon
# Alcremie           Sweet Veil             NaN   60.0     100.0
# Appletun                Ripen        Gluttony   85.0      45.0
# Applin                  Ripen        Gluttony   40.0     255.0
# Arctovish        Water Absorb        Ice Body   90.0      45.0
# Arctozolt         Volt Absorb          Static  100.0      45.0
# Arrokuda           Swift Swim             NaN   63.0     255.0
# Barraskewda        Swift Swim             NaN  123.0      60.0
# Blipbug                 Swarm    Compoundeyes   20.0     255.0
# Boltund            Strong Jaw             NaN   90.0      45.0
# Carkol           Steam Engine      Flame Body   60.0     120.0
# Centiskorch        Flash Fire     White Smoke  115.0      75.0
# Chewtle            Strong Jaw     Shell Armor   64.0     255.0
# Cinderace               Blaze             NaN  116.0      45.0
# Clobbopus              Limber             NaN   68.0     180.0
# Coalossal        Steam Engine      Flame Body   80.0      45.0
# Copperajah        Sheer Force             NaN  130.0      90.0
# Corviknight          Pressure         Unnerve   87.0      45.0
# Corvisquire          Keen Eye         Unnerve   67.0     120.0
# Cramorant        Gulp Missile             NaN   85.0      45.0
# Cufant            Sheer Force             NaN   80.0     190.0
# Cursola            Weak Armor             NaN   95.0      30.0
# Dottler                 Swarm    Compoundeyes   35.0     120.0
# Dracovish        Water Absorb      Strong Jaw   90.0      45.0
# Dracozolt         Volt Absorb          Hustle  100.0      45.0
# Dragapult          Clear Body     Infiltrator  120.0      45.0
# Drakloak           Clear Body     Infiltrator   80.0      45.0
# Drednaw            Strong Jaw     Shell Armor  115.0      75.0
# Dreepy             Clear Body     Infiltrator   60.0      45.0
# Drizzile              Torrent             NaN   60.0      45.0
# Dubwool                Fluffy       Steadfast   80.0     127.0
# Duraludon         Light Metal     Heavy Metal   95.0      45.0
# Eiscue               Ice Face             NaN   80.0      60.0
# Eldegoss          Cotton Down     Regenerator   50.0      75.0
# Eternatus            Pressure             NaN   85.0     255.0
# Falinks          Battle Armor             NaN  100.0      45.0
# Farfetchd           Steadfast             NaN   95.0      45.0
# Flapple                 Ripen        Gluttony  110.0      45.0
# Frosmoth          Shield Dust             NaN   65.0      75.0
# Gossifleur        Cotton Down     Regenerator   40.0     190.0
# Grapploct              Limber             NaN  118.0      45.0
# Greedent          Cheek Pouch             NaN   95.0      90.0
# Grimmsnarl          Prankster           Frisk  120.0      45.0
# Grookey              Overgrow             NaN   65.0      45.0
# Hakamoo           Bulletproof      Soundproof   75.0      45.0
# Hatenna                Healer    Anticipation   30.0     235.0
# Hatterene              Healer    Anticipation   90.0      45.0
# Hattrem                Healer    Anticipation   40.0     120.0
# Impidimp            Prankster           Frisk   45.0     255.0
# Indeedee          Inner Focus     Synchronize   65.0      30.0
# Inteleon              Torrent             NaN   85.0      45.0
# Jangmoo           Bulletproof      Soundproof   55.0      45.0
# Kommoo            Bulletproof      Soundproof  110.0      45.0
# Milcery            Sweet Veil             NaN   40.0     200.0
# MimeJr             Soundproof          Filter   25.0     145.0
# Morgrem             Prankster           Frisk   60.0     120.0
# Morpeko         Hunger Switch             NaN   95.0     180.0
# MrMime           Vital Spirit  Screen Cleaner   65.0      45.0
# MrRime           Tangled Feet  Screen Cleaner   85.0      45.0
# Nickit               Run Away        Unburden   28.0     255.0
# Obstagoon            Reckless            Guts   90.0      45.0
# Orbeetle                Swarm           Frisk   45.0      45.0
# Perrserker       Battle Armor     Tough Claws  110.0      90.0
# Pincurchin      Lightning Rod             NaN  101.0      75.0
# Polteageist        Weak Armor             NaN   65.0      60.0
# Raboot                  Blaze             NaN   86.0      45.0
# Rillaboom            Overgrow             NaN  125.0      45.0
# Rolycoly         Steam Engine       Heatproof   40.0     255.0
# Rookidee             Keen Eye         Unnerve   47.0     255.0
# Runerigus    Wandering Spirit             NaN   95.0      90.0
# Sandaconda          Sand Spit       Shed Skin  107.0     120.0
# Scorbunny               Blaze             NaN   71.0      45.0
# Silicobra           Sand Spit       Shed Skin   57.0     255.0
# Sinistea           Weak Armor             NaN   45.0     120.0
# Sirfetchd           Steadfast             NaN  135.0      45.0
# Sizzlipede         Flash Fire     White Smoke   65.0     190.0
# Skwovet           Cheek Pouch             NaN   55.0     255.0
# Snom              Shield Dust             NaN   25.0     190.0
# Sobble                Torrent             NaN   40.0      45.0
# Stonjourner        Power Spot             NaN  125.0      60.0
# Thievul              Run Away        Unburden   58.0     127.0
# Thwackey             Overgrow             NaN   85.0      45.0
# Toxel                 Rattled          Static   38.0      75.0
# Toxtricity          Punk Rock            Plus   98.0      45.0
# TypeNull         Battle Armor             NaN   95.0       3.0
# Wishiwashi          Schooling             NaN   20.0      60.0
# Wooloo                 Fluffy        Run Away   40.0     255.0
# Yamper             Ball Fetch             NaN   45.0     255.0
# Zacian         Intrepid Sword             NaN  130.0      10.0
# Zamazenta    Dauntless Shield             NaN  130.0      10.0
#
#                    Classification Color    Def  Egg_Steps  \
# Pokemon
# Alcremie            Cream Pokémon   NaN   75.0     5120.0
# Appletun     Apple Nectar Pokémon   NaN   80.0     5120.0
# Applin         Apple Core Pokémon   NaN   80.0     5120.0
# Arctovish          Fossil Pokémon   NaN  100.0     8960.0
# Arctozolt          Fossil Pokémon   NaN   90.0     8960.0
# Arrokuda             Rush Pokémon   NaN   40.0     5120.0
# Barraskewda        Skewer Pokémon   NaN   60.0     5120.0
# Blipbug             Larva Pokémon   NaN   20.0     3840.0
# Boltund               Dog Pokémon   NaN   60.0     5120.0
# Carkol               Coal Pokémon   NaN   90.0     3840.0
# Centiskorch      Radiator Pokémon   NaN   65.0     5120.0
# Chewtle          Snapping Pokémon   NaN   50.0     5120.0
# Cinderace         Striker Pokémon   NaN   75.0     5120.0
# Clobbopus         Tantrum Pokémon   NaN   60.0     6400.0
# Coalossal            Coal Pokémon   NaN  120.0     3840.0
# Copperajah     Copperderm Pokémon   NaN   69.0     6400.0
# Corviknight         Raven Pokémon   NaN  105.0     3840.0
# Corvisquire         Raven Pokémon   NaN   55.0     3840.0
# Cramorant            Gulp Pokémon   NaN   55.0     5120.0
# Cufant         Copperderm Pokémon   NaN   49.0     6400.0
# Cursola             Coral Pokémon   NaN   50.0     5120.0
# Dottler            Radome Pokémon   NaN   80.0     3840.0
# Dracovish          Fossil Pokémon   NaN  100.0     8960.0
# Dracozolt          Fossil Pokémon   NaN   90.0     8960.0
# Dragapult         Stealth Pokémon   NaN   75.0    10240.0
# Skwovet            Cheeky Pokémon   NaN   55.0     5120.0
# Snom                 Worm Pokémon   NaN   35.0     5120.0
# Sobble       Water Lizard Pokémon   NaN   40.0     5120.0
# Stonjourner      Big Rock Pokémon   NaN  135.0     6400.0
# Thievul               Fox Pokémon   NaN   58.0     3840.0
# Thwackey             Beat Pokémon   NaN   70.0     5120.0
# Toxel                Baby Pokémon   NaN   35.0     6400.0
# Toxtricity           Punk Pokémon   NaN   70.0     6400.0
# TypeNull        Synthetic Pokémon   NaN   95.0    30720.0
# Wishiwashi      Small Fry Pokémon   NaN   20.0     3840.0
# Wooloo              Sheep Pokémon   NaN   55.0     3840.0
# Yamper              Puppy Pokémon   NaN   50.0     5120.0
# Zacian            Warrior Pokémon   NaN  115.0    30720.0
# Zamazenta         Warrior Pokémon   NaN  115.0    30720.0
#
#              Galar Pokedex Number     HP  Height_ft  Height_m  Hidden Ability  \
# Pokemon
# Alcremie                    186.0   65.0      1.000       0.3      Aroma Veil
# Appletun                    207.0  110.0      1.333       0.4       Thick Fat
# Applin                      205.0   40.0      0.667       0.2     Bulletproof
# Arctovish                   377.0   90.0      6.583       2.0      Slush Rush
# Arctozolt                   375.0   90.0      7.583       2.3      Slush Rush
# Arrokuda                    180.0   41.0      1.667       0.5  Propeller Tail
# Barraskewda                 181.0   61.0      4.250       1.3  Propeller Tail
# Blipbug                      10.0   25.0      1.333       0.4       Telepathy
# Boltund                      47.0   69.0      3.250       1.0     Competitive
# Carkol                      162.0   80.0      3.583       1.1      Flash Fire
# Centiskorch                 160.0  100.0      9.833       3.0      Flame Body
# Chewtle                      42.0   50.0      1.000       0.3      Swift Swim
# Cinderace                     6.0   80.0      4.583       1.4          Libero
# Clobbopus                   351.0   50.0      2.000       0.6      Technician
# Coalossal                   163.0  110.0      9.167       2.8      Flash Fire
# Copperajah                  303.0  122.0      9.833       3.0     Heavy Metal
# Corviknight                  23.0   98.0      7.250       2.2    Mirror Armor
# Corvisquire                  22.0   68.0      2.583       0.8       Big Pecks
# Cramorant                   309.0   70.0      2.583       0.8             NaN
# Cufant                      302.0   72.0      3.917       1.2     Heavy Metal
# Cursola                     237.0   60.0      3.250       1.0     Perish Body
# Dottler                      11.0   50.0      1.333       0.4       Telepathy
# Dracovish                   376.0   90.0      7.583       2.3       Sand Rush
# Dracozolt                   374.0   90.0      5.917       1.8       Sand Rush
# Dragapult                   397.0   88.0      9.833       3.0     Cursed Body
# Drakloak                    396.0   68.0      4.583       1.4     Cursed Body
# Drednaw                      43.0   90.0      3.250       1.0      Swift Swim
# Dreepy                      395.0   28.0      1.667       0.5     Cursed Body
# Drizzile                      8.0   65.0      2.333       0.7          Sniper
# Dubwool                      35.0   72.0      4.250       1.3     Bulletproof
# Duraludon                   371.0   70.0      5.917       1.8        Stalwart
# Eiscue                      370.0   75.0      4.583       1.4             NaN
# Eldegoss                    127.0   60.0      1.667       0.5    Effect Spore
# Eternatus                   400.0  140.0     65.583      20.0             NaN
# Falinks                     345.0   65.0      9.833       3.0         Defiant
# Farfetchd                   218.0   52.0      2.583       0.8         Scrappy
# Zacian                      398.0   92.0      9.167       2.8             NaN
# Zamazenta                   399.0   92.0      9.500       2.9             NaN
#
#              Index  SpAtk  SpDef  Speed  Total    Type I   Type II  Weight_kg  \
# Pokemon
# Alcremie       NaN  110.0  121.0   64.0    NaN     fairy       NaN        0.5
# Appletun       NaN  100.0   80.0   30.0    NaN     grass    dragon       13.0
# Applin         NaN   40.0   40.0   20.0    NaN     grass    dragon        0.5
# Arctovish      NaN   80.0   90.0   55.0    NaN     water       ice      175.0
# Arctozolt      NaN   90.0   80.0   55.0    NaN  electric       ice      150.0
# Arrokuda       NaN   40.0   30.0   66.0    NaN     water       NaN        1.0
# Barraskewda    NaN   60.0   50.0  136.0    NaN     water       NaN       30.0
# Blipbug        NaN   25.0   45.0   45.0    NaN       bug       NaN        8.0
# Boltund        NaN   90.0   60.0  121.0    NaN  electric       NaN       34.0
# Carkol         NaN   60.0   70.0   50.0    NaN      rock      fire       78.0
# Centiskorch    NaN   90.0   90.0   65.0    NaN      fire       bug      120.0
# Chewtle        NaN   38.0   38.0   44.0    NaN     water       NaN        8.5
# Cinderace      NaN   65.0   75.0  119.0    NaN      fire       NaN       33.0
# Clobbopus      NaN   50.0   50.0   32.0    NaN  fighting       NaN        4.0
# Coalossal      NaN   80.0   90.0   30.0    NaN      rock      fire      310.5
# Copperajah     NaN   80.0   69.0   30.0    NaN     steel       NaN      650.0
# Corviknight    NaN   53.0   85.0   67.0    NaN    flying     steel       75.0
# Corvisquire    NaN   43.0   55.0   77.0    NaN    flying       NaN       16.0
# Cramorant      NaN   85.0   95.0   85.0    NaN    flying     water       18.0
# Cufant         NaN   40.0   49.0   40.0    NaN     steel       NaN      100.0
# Cursola        NaN  145.0  130.0   30.0    NaN     ghost       NaN        0.4
# Dottler        NaN   50.0   90.0   30.0    NaN       bug   psychic       19.5
# Dracovish      NaN   70.0   80.0   75.0    NaN     water    dragon      215.0
# Dracozolt      NaN   80.0   70.0   75.0    NaN  electric    dragon      190.0
# Dragapult      NaN  100.0   75.0  142.0    NaN    dragon     ghost       50.0
# Drakloak       NaN   60.0   50.0  102.0    NaN    dragon     ghost       11.0
# Drednaw        NaN   48.0   68.0   74.0    NaN     water      rock      115.5
# Dreepy         NaN   40.0   30.0   82.0    NaN    dragon     ghost        2.0
# Drizzile       NaN   95.0   55.0   90.0    NaN     water       NaN       11.5
# Dubwool        NaN   60.0   90.0   88.0    NaN    normal       NaN       43.0
# Duraludon      NaN  120.0   50.0   85.0    NaN     steel    dragon       40.0
# Eiscue         NaN   65.0   90.0   50.0    NaN       ice       NaN       89.0
# Eldegoss       NaN   80.0  120.0   60.0    NaN     grass       NaN        2.5
# Eternatus      NaN  145.0   95.0  130.0    NaN    poison    dragon      950.0
# Falinks        NaN   70.0   60.0   75.0    NaN  fighting       NaN       62.0
# Farfetchd      NaN   58.0   62.0   55.0    NaN  fighting       NaN       15.0
# Flapple        NaN   95.0   60.0   70.0    NaN     grass    dragon        1.0
# Frosmoth       NaN  125.0   90.0   65.0    NaN       ice       bug       42.0
# Gossifleur     NaN   40.0   60.0   10.0    NaN     grass       NaN        2.2
# Grapploct      NaN   70.0   80.0   42.0    NaN  fighting       NaN       39.0
# Greedent       NaN   55.0   75.0   20.0    NaN    normal       NaN        6.0
# Grimmsnarl     NaN   95.0   75.0   60.0    NaN      dark     fairy       61.0
# Grookey        NaN   40.0   40.0   65.0    NaN     grass       NaN        5.0
# Hakamoo        NaN   65.0   70.0   65.0    NaN    dragon  fighting       47.0
# Hatenna        NaN   56.0   53.0   39.0    NaN   psychic       NaN        3.4
# Hatterene      NaN  136.0  103.0   29.0    NaN   psychic     fairy        5.1
# Hattrem        NaN   86.0   73.0   49.0    NaN   psychic       NaN        4.8
# Impidimp       NaN   55.0   40.0   50.0    NaN      dark     fairy        5.5
# Indeedee       NaN  105.0   95.0   95.0    NaN   psychic    normal       28.0
# Inteleon       NaN  125.0   65.0  120.0    NaN     water       NaN       45.2
# Jangmoo        NaN   45.0   45.0   45.0    NaN    dragon       NaN       29.7
# Kommoo         NaN  100.0  105.0   85.0    NaN    dragon  fighting       78.2
# Milcery        NaN   50.0   61.0   34.0    NaN     fairy       NaN        0.3
# MimeJr         NaN   70.0   90.0   60.0    NaN   psychic     fairy       13.0
# Morgrem        NaN   75.0   55.0   70.0    NaN      dark     fairy       12.5
# Morpeko        NaN   70.0   58.0   97.0    NaN  electric      dark        3.0
# MrMime         NaN   90.0   90.0  100.0    NaN       ice   psychic       54.5
# MrRime         NaN  110.0  100.0   70.0    NaN       ice   psychic       58.2
# Nickit         NaN   47.0   52.0   50.0    NaN      dark       NaN        8.9
# Obstagoon      NaN   60.0   81.0   95.0    NaN      dark    normal       46.0
# Orbeetle       NaN   80.0  120.0   90.0    NaN       bug   psychic       40.8
# Perrserker     NaN   50.0   60.0   50.0    NaN     steel       NaN       28.0
# Pincurchin     NaN   91.0   85.0   15.0    NaN  electric       NaN        1.0
# Polteageist    NaN  134.0  114.0   70.0    NaN     ghost       NaN        0.4
# Raboot         NaN   55.0   60.0   94.0    NaN      fire       NaN        9.0
# Rillaboom      NaN   60.0   70.0   85.0    NaN     grass       NaN       90.0
# Rolycoly       NaN   40.0   50.0   30.0    NaN      rock       NaN       12.0
# Rookidee       NaN   33.0   35.0   57.0    NaN    flying       NaN        1.8
# Runerigus      NaN   50.0  105.0   30.0    NaN    ground     ghost       66.6
# Sandaconda     NaN   65.0   70.0   71.0    NaN    ground       NaN       65.5
# Scorbunny      NaN   40.0   40.0   69.0    NaN      fire       NaN        4.5
# Silicobra      NaN   35.0   50.0   46.0    NaN    ground       NaN        7.6
# Sinistea       NaN   74.0   54.0   50.0    NaN     ghost       NaN        0.2
# Sirfetchd      NaN   68.0   82.0   65.0    NaN  fighting       NaN      117.0
# Sizzlipede     NaN   50.0   50.0   45.0    NaN      fire       bug        1.0
# Skwovet        NaN   35.0   35.0   25.0    NaN    normal       NaN        2.5
# Snom           NaN   45.0   30.0   20.0    NaN       ice       bug        3.8
# Sobble         NaN   70.0   40.0   70.0    NaN     water       NaN        4.0
# Sinistea            0.4  334.0
# Sirfetchd         257.9  218.0
# Sizzlipede          2.2  158.0
# Skwovet             5.5   23.0
# Snom                8.4  348.0
# Sobble              8.8    6.0
# Stonjourner      1146.4  368.0
# Thievul            43.9   29.0
# Thwackey           30.9    1.0
# Toxel              24.3  309.0
# Toxtricity         88.2  310.0
# TypeNull          265.7  380.0
# Wishiwashi          0.7  154.0
# Wooloo             13.2   33.0
# Yamper             29.8   45.0
# Zacian            242.5  397.0
# Zamazenta         463.0  398.0

# %%
combined_pokedex_df['Total'] = combined_pokedex_df['HP']\
                               + combined_pokedex_df['Atk']\
                               + combined_pokedex_df['Def']\
                               + combined_pokedex_df['SpAtk']\
                               + combined_pokedex_df['SpDef']\
                               + combined_pokedex_df['Speed']\

# %%
pokedex_df['Total']/ pokedex_df['HP'] # computes the ratio between total stats and HP

# %% [markdown]
# ### Universal functions
# Universal functions can operate on entire dataframes or slices of dataframes. They return a dataframe copy with the same index as the original dataframe. Numpy universal functions can be applied to any numeric dataframe or slice.

# %%
np.log(10)

# %%
np.log(pokedex_df.loc[:,'HP':'Total'].astype(float), axis=0) # take natural log of all stats
# again, these functions operate on each element independently, and return a dataframe with the same index and size of input

# %% [markdown]
# ### .apply()
# You can apply an arbitrary function to each row or column using the `.apply()` function.
#
# If you pass the name of a function (e.g. np.mean, or the name of any function you've written), you can apply it to either each column, or each row using `.apply()`

# %%
pokedex_df.loc[:,'Atk':'Speed'].apply(np.mean) # applies the function np.mean() to each column

# %%
pokedex_df.loc[:,'Atk':'Speed'].apply(np.mean, axis=1) # if you wanted to apply it to each row instead, use the argument axis=1

# %% [markdown]
# The above example is actually a bit unnecessary. There are several built-in functions in dataframes, including a `.mean()` which has the same functionality.

# %%
pokedex_df.loc[:,'Atk':'Speed'].mean()

# %%
pokedex_df.loc[:,'Atk':'Speed'].mean(axis=1) #applies per row

# %% [markdown]
# Most [descriptive statistics](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats) (median, mode, standard deviation, count, quantile, etc) have built-in functions. Where `.apply()` really shines, however, is for applying custom functions.
#
# To show that functionality, let's take a sidebar and talk about lambda functions.

# %% [markdown]
# #### Lambda functions
# Sometimes you want to define a function, but you don't want to write the whole function declaration setup
# ```
# def functionname(inputs):
#   ...
#   return outputs
# ```
#
# In those situations, you can write lambda (also known as anonymous) functions. The syntax for a lambda function is:
#
# ```
# functionname = lambda x: operations_on_x
# ```
#
# For example, if you wanted to write a function that squares the input, you could write:

# %%
square_it = lambda x: x**2 # recall that ** is exponentiation in python, this function returns the square of the input
for num in range(10):
  print(square_it(num))

# %% [markdown]
# This is especially useful if some function takes another function as an argument, like panda's `.apply()`
#
# The typical usage of `.apply()` is:
#
# `dataframe_obj.apply(functionname)`, which calls `functionname` on each column of `dataframe_obj`
#
# However, you can replace `functionname` with a lambda function. In this example, we use the following lambda function:
#
# ```lambda col: [np.min(col), np.max(col)]```
#
# The word `col` represents the argument, and then to the right of the colon, we return a list with two elements: the minimum and maximum values of the column

# %%
stats_ranges = pokedex_df.loc[:,'HP':'Total'].apply(lambda col: [np.min(col), np.max(col)])
print(stats_ranges)
# Out:
# HP         [1, 255]
# Atk        [5, 181]
# Def        [5, 230]
# SpAtk     [10, 180]
# SpDef     [20, 230]
# Speed      [5, 180]
# Total    [175, 720]
# dtype: object

# %% [markdown]
# the above can be expanded into a dataframe:

# %%
pokedex_df.loc[:,'HP':'Total'].apply(lambda col: [np.min(col), np.mean(col), np.max(col)], result_type='expand')
# each respective row corresponds to the function applied to the column
# Out:
#           HP         Atk         Def       SpAtk       SpDef       Speed  \
# 0    1.00000    5.000000    5.000000   10.000000   20.000000    5.000000
# 1   68.60122   76.115854   71.919512   69.957317   70.370732   66.140244
# 2  255.00000  181.000000  230.000000  180.000000  230.000000  180.000000
#
#         Total
# 0  175.000000
# 1  423.104878
# 2  720.000000

# %%
# we can rename the rows to make it more interpretable. Also note the backslash \
# character allows a command to continue onto the next line, ignoring whitespace
pokedex_df.loc[:,'HP':'Total']\
          .apply(lambda col: [np.min(col), np.mean(col), np.max(col)], result_type='expand')\
          .rename({0:'min', 1:'mean', 2:'max'})
# Out:
#              HP         Atk         Def       SpAtk       SpDef       Speed  \
# min     1.00000    5.000000    5.000000   10.000000   20.000000    5.000000
# mean   68.60122   76.115854   71.919512   69.957317   70.370732   66.140244
# max   255.00000  181.000000  230.000000  180.000000  230.000000  180.000000
#
#            Total
# min   175.000000
# mean  423.104878
# max   720.000000

# %% [markdown]
# ### Groupby
# Dataframes can be grouped by column values, and operations can be applied to each group

# %%
# counts the number of pokemon of each type combination
pokedex_df.groupby(['Type I','Type II'])['Total'].count()
# Out:
# Type I    Type II
# Bug                   18
#           Electric     4
#           Fairy        2
#           Fighting     3
#           Fire         2
#           Flying      13
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      11
#           Rock         3
#           Steel        6
#           Water        3
# Dark                   9
#           Dragon       4
#           Fighting     2
#           Fire         2
#           Flying       5
#           Ghost        1
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon                12
#           Electric     1
#           Fighting     2
#           Fire         1
#           Flying       4
#           Ground       4
#           Ice          1
#           Psychic      2
# Electric              27
#           Fairy        2
#           Fire         1
#           Flying       4
#           Ghost        1
#           Grass        1
#           Ice          1
#           Normal       2
#           Steel        4
#           Water        1
# Fairy                 16
#           Flying       2
# Fighting              22
#           Dark         1
#           Flying       1
#           Ghost        1
#           Ice          1
#           Psychic      2
#           Steel        1
# Fire                  30
#           Dark         1
#           Dragon       1
#           Fighting     6
#           Flying       6
#           Ground       2
#           Normal       2
#           Psychic      2
#           Rock         1
#           Steel        1
#           Water        1
# Flying                 1
#           Dragon       2
# Ghost                  9
#           Dark         1
#           Dragon       2
#           Fairy        1
#           Fire         3
#           Flying       2
#           Grass        5
#           Ground       2
#           Poison       3
# Grass                 38
#           Dark         3
#           Fairy        5
#           Fighting     3
#           Flying       7
#           Ghost        1
#           Ground       1
#           Poison      14
#           Psychic      2
#           Steel        3
# Ground                15
#           Dark         3
#           Dragon       2
#           Electric     1
#           Flying       3
#           Ghost        2
#           Psychic      2
#           Rock         3
#           Steel        1
# Ice                   12
#           Flying       2
#           Ghost        1
#           Grass        2
#           Ground       3
#           Psychic      2
#           Water        3
# Normal                65
#           Dragon       1
#           Fairy        4
#           Fighting     3
#           Flying      26
#           Grass        2
#           Ground       1
#           Psychic      3
#           Water        1
# Poison                15
#           Bug          1
#           Dark         3
#           Dragon       1
#           Fighting     2
#           Fire         2
#           Flying       3
#           Ground       2
#           Water        3
# Psychic               38
#           Dark         1
#           Fairy        6
#           Fighting     1
#           Fire         1
#           Flying       6
#           Ghost        2
#           Grass        1
#           Steel        1
# Rock                  12
#           Bug          2
#           Dark         1
#           Dragon       2
#           Fairy        2
#           Fighting     1
#           Flying       5
#           Grass        2
#           Ground       6
#           Ice          2
#           Poison       1
#           Psychic      2
#           Steel        3
#           Water        6
# Steel                  4
#           Dragon       1
#           Fairy        3
#           Fighting     1
#           Flying       2
#           Ghost        3
#           Ground       1
#           Psychic      6
#           Rock         3
# Water                 62
#           Bug          2
#           Dark         4
#           Dragon       2
#           Electric     2
#           Fairy        4
#           Fighting     2
#           Flying       7
#           Ghost        2
#           Grass        3
#           Ground       9
#           Ice          3
#           Poison       3
#           Psychic      5
#           Rock         4
#           Steel        1
# Name: Total, dtype: int64

# %%
# gets the range of stats for each type combination
pokedex_df.groupby(['Type I','Type II'])['Total'].apply(lambda col: [np.min(col), np.max(col)])
# Out:
# Type I    Type II
# Bug                   [194, 500]
#           Electric    [319, 500]
#           Fairy       [304, 464]
#           Fighting    [500, 570]
#           Fire        [360, 550]
#           Flying      [244, 515]
#           Ghost       [236, 236]
#           Grass       [285, 490]
#           Ground      [266, 424]
#           Poison      [195, 475]
#           Rock        [325, 505]
#           Steel       [424, 600]
#           Water       [230, 530]
# Dark                  [220, 600]
#           Dragon      [300, 600]
#           Fighting    [348, 488]
#           Fire        [330, 500]
#           Flying      [370, 680]
#           Ghost       [380, 380]
#           Ice         [430, 510]
#           Psychic     [288, 482]
#           Steel       [340, 490]
# Dragon                [300, 600]
#           Electric    [680, 680]
#           Fighting    [420, 600]
#           Fire        [680, 680]
#           Flying      [490, 680]
#           Ground      [300, 600]
#           Ice         [660, 660]
#           Psychic     [600, 600]
# Electric              [205, 580]
#           Fairy       [431, 570]
#           Fire        [520, 520]
#           Flying      [428, 580]
#           Ghost       [440, 440]
#           Grass       [520, 520]
#           Ice         [520, 520]
#           Normal      [289, 481]
#           Steel       [325, 535]
#           Water       [520, 520]
# Fairy                 [218, 680]
#           Flying      [405, 545]
# Fighting              [210, 510]
#           Dark        [495, 495]
#           Flying      [500, 500]
#           Ghost       [600, 600]
#           Ice         [478, 478]
#           Psychic     [280, 410]
#           Steel       [525, 525]
# Fire                  [250, 580]
#           Dark        [530, 530]
#           Dragon      [485, 485]
#           Fighting    [405, 534]
#           Flying      [382, 680]
#           Ground      [305, 460]
#           Normal      [369, 507]
#           Psychic     [534, 540]
#           Rock        [410, 410]
#           Steel       [600, 600]
#           Water       [600, 600]
# Flying                [580, 580]
#           Dragon      [245, 535]
# Ghost                 [295, 525]
#           Dark        [485, 485]
#           Dragon      [680, 680]
#           Fairy       [476, 476]
#           Fire        [275, 520]
#           Flying      [348, 498]
#           Grass       [309, 517]
#           Ground      [320, 480]
#           Poison      [310, 500]
# Grass                 [180, 600]
#           Dark        [340, 480]
#           Fairy       [280, 570]
#           Fighting    [460, 580]
#           Flying      [250, 600]
#           Ghost       [530, 530]
#           Ground      [525, 525]
#           Poison      [280, 525]
#           Psychic     [325, 520]
#           Steel       [305, 570]
# Ground                [265, 670]
#           Dark        [292, 509]
#           Dragon      [340, 520]
#           Electric    [471, 471]
#           Flying      [430, 600]
#           Ghost       [303, 483]
#           Psychic     [300, 500]
#           Rock        [345, 535]
#           Steel       [508, 508]
# Ice                   [300, 580]
#           Flying      [330, 580]
#           Ghost       [480, 480]
#           Grass       [334, 494]
#           Ground      [250, 530]
#           Psychic     [305, 455]
#           Water       [290, 530]
# Normal                [215, 720]
#           Dragon      [485, 485]
#           Fairy       [190, 425]
#           Fighting    [340, 600]
#           Flying      [245, 510]
#           Grass       [335, 475]
#           Ground      [423, 423]
#           Psychic     [455, 600]
#           Water       [410, 410]
# Poison                [273, 500]
#           Bug         [330, 330]
#           Dark        [329, 500]
#           Dragon      [494, 494]
#           Fighting    [300, 490]
#           Fire        [320, 480]
#           Flying      [245, 535]
#           Ground      [495, 495]
#           Water       [305, 495]
# Psychic               [200, 680]
#           Dark        [680, 680]
#           Fairy       [198, 570]
#           Fighting    [518, 518]
#           Fire        [600, 600]
#           Flying      [313, 680]
#           Ghost       [600, 680]
#           Grass       [600, 600]
#           Steel       [680, 680]
# Rock                  [280, 580]
#           Bug         [355, 495]
#           Dark        [600, 600]
#           Dragon      [362, 521]
#           Fairy       [500, 600]
#           Fighting    [580, 580]
#           Flying      [401, 567]
#           Grass       [355, 495]
#           Ground      [300, 485]
#           Ice         [362, 521]
#           Poison      [570, 570]
#           Psychic     [440, 440]
#           Steel       [350, 525]
#           Water       [306, 500]
# Steel                 [300, 580]
#           Dragon      [680, 680]
#           Fairy       [380, 600]
#           Fighting    [580, 580]
#           Flying      [465, 570]
#           Ghost       [325, 520]
#           Ground      [510, 510]
#           Psychic     [300, 600]
#           Rock        [330, 530]
# Water                 [175, 670]
#           Bug         [269, 454]
#           Dark        [305, 530]
#           Dragon      [540, 680]
#           Electric    [330, 460]
#           Fairy       [250, 570]
#           Fighting    [500, 580]
#           Flying      [270, 540]
#           Ghost       [335, 480]
#           Grass       [220, 480]
#           Ground      [210, 535]
#           Ice         [475, 535]
#           Poison      [335, 515]
#           Psychic     [315, 520]
#           Rock        [355, 495]
#           Steel       [530, 530]
# Name: Total, dtype: object

# %%
pd.set_option('display.max_rows', None)
print(combined_pokedex_df.groupby(['Color','Type I',])['Atk/Def Balance'].apply(lambda col: [np.round(np.min(col),2) ,np.round(np.max(col),2), np.round(np.mean(col),2)]))
# Out:
# Color   Type I
# Black   Bug           [0.9, 1.8, 1.26]
#         Dark        [0.46, 2.02, 1.31]
#         Dragon         [1.2, 1.2, 1.2]
#         Electric    [1.27, 2.44, 1.76]
#         Ghost       [0.33, 1.91, 1.06]
#         Ground      [0.58, 0.58, 0.58]
#         Normal      [0.47, 2.19, 1.01]
#         Poison      [1.67, 1.85, 1.76]
#         Psychic      [0.88, 1.5, 1.27]
#         Steel          [1.0, 1.0, 1.0]
#         Water       [0.23, 0.23, 0.23]
# Blue    Bug         [0.42, 1.93, 1.04]
#         Dark         [0.8, 1.39, 0.99]
#         Dragon      [0.67, 1.38, 1.03]
#         Electric    [1.07, 1.56, 1.26]
#         Fairy       [1.34, 1.34, 1.34]
#         Fighting     [0.4, 1.64, 0.91]
#         Grass        [0.65, 2.5, 1.53]
#         Ground         [1.0, 1.0, 1.0]
#         Ice          [0.5, 1.37, 0.94]
#         Normal       [0.5, 1.65, 0.99]
#         Poison      [0.37, 1.52, 0.99]
#         Psychic     [0.22, 1.79, 1.04]
#         Rock         [0.86, 1.64, 1.2]
#         Steel       [0.58, 1.25, 0.89]
#         Water         [0.4, 2.8, 1.13]
# Brown   Bug          [0.79, 1.0, 0.93]
#         Dark        [0.58, 0.69, 0.64]
#         Dragon         [1.0, 1.0, 1.0]
#         Fighting    [0.32, 0.86, 0.59]
#         Fire        [0.77, 1.65, 1.32]
#         Ghost       [0.77, 1.56, 1.01]
#         Grass        [0.67, 1.5, 1.11]
#         Ground      [0.57, 1.44, 0.86]
#         Ice          [1.0, 1.17, 1.06]
#         Normal      [0.42, 1.46, 0.87]
#         Poison       [0.79, 1.0, 0.89]
#         Psychic     [1.32, 1.91, 1.63]
#         Rock        [0.22, 1.22, 0.76]
#         Steel       [0.33, 0.95, 0.73]
#         Water        [0.18, 2.0, 1.29]
# Gray    Bug         [0.51, 1.22, 0.78]
#         Dark           [1.0, 2.0, 1.5]
#         Dragon      [0.93, 1.44, 1.08]
#         Electric    [0.55, 1.73, 1.36]
#         Fighting     [0.71, 1.0, 0.85]
#         Ghost          [1.0, 1.0, 1.0]
#         Grass       [0.28, 0.47, 0.37]
#         Ground       [0.67, 1.0, 0.91]
#         Ice            [1.0, 1.0, 1.0]
#         Normal        [0.5, 1.2, 0.99]
#         Psychic     [1.05, 1.05, 1.05]
#         Rock        [0.33, 0.93, 0.62]
#         Steel        [0.5, 1.13, 0.85]
#         Water       [0.69, 1.86, 1.17]
# Green   Bug         [0.56, 2.07, 0.96]
#         Dragon      [0.75, 1.67, 1.02]
#         Electric    [1.62, 1.62, 1.62]
#         Fairy       [0.75, 0.75, 0.75]
#         Fighting    [1.17, 1.17, 1.17]
#         Flying      [1.56, 1.56, 1.56]
#         Ghost       [0.96, 0.96, 0.96]
#         Grass       [0.69, 2.33, 1.14]
#         Ground       [0.69, 1.0, 0.85]
#         Normal         [0.5, 0.5, 0.5]
#         Poison      [0.65, 0.81, 0.73]
#         Psychic       [1.0, 2.1, 1.59]
#         Rock        [0.76, 0.95, 0.87]
#         Steel       [0.28, 1.06, 0.67]
#         Water       [0.38, 1.45, 0.84]
# Pink    Electric    [1.33, 1.33, 1.33]
#         Fairy       [0.82, 1.11, 0.94]
#         Grass        [0.64, 1.43, 1.1]
#         Ice         [1.31, 1.31, 1.31]
#         Normal      [0.23, 2.22, 1.03]
#         Psychic     [0.78, 1.22, 1.01]
#         Rock        [0.67, 1.67, 1.17]
#         Water       [0.62, 1.52, 0.97]
# Purple  Bug         [0.73, 1.26, 1.03]
#         Dark         [1.0, 1.76, 1.37]
#         Dragon      [0.73, 0.73, 0.73]
#         Fairy          [1.0, 1.0, 1.0]
#         Fighting    [0.89, 1.58, 1.16]
#         Flying      [1.12, 1.21, 1.17]
#         Ghost       [0.85, 2.86, 1.65]
#         Grass        [0.51, 0.9, 0.78]
#         Ground       [0.54, 0.6, 0.57]
#         Normal       [0.71, 1.0, 0.87]
#         Poison      [0.55, 1.33, 0.92]
#         Psychic     [0.82, 1.71, 1.14]
#         Rock          [0.7, 0.8, 0.75]
#         Water       [0.57, 1.89, 1.18]
# Red     Bug          [0.5, 1.67, 0.88]
#         Dark         [0.39, 1.34, 0.9]
#         Dragon      [0.67, 0.85, 0.76]
#         Electric    [0.98, 1.23, 1.02]
#         Fighting     [0.35, 0.8, 0.58]
#         Fire        [0.33, 1.75, 1.21]
#         Grass        [0.89, 1.11, 1.0]
#         Ground      [0.93, 1.11, 1.02]
#         Ice         [1.21, 1.44, 1.33]
#         Normal       [0.76, 1.8, 1.18]
#         Psychic      [0.44, 9.0, 3.37]
#         Rock        [0.85, 1.17, 1.01]
#         Water        [0.7, 3.25, 1.33]
# White   Bug          [0.91, 3.7, 1.58]
#         Dark        [1.25, 1.25, 1.25]
#         Dragon       [1.2, 1.25, 1.23]
#         Electric     [0.5, 1.44, 1.08]
#         Fairy       [0.62, 1.13, 0.86]
#         Fighting    [0.67, 0.97, 0.88]
#         Ghost       [1.18, 1.18, 1.18]
#         Grass         [1.0, 1.9, 1.32]
#         Ice          [0.88, 1.5, 1.12]
#         Normal       [0.44, 1.48, 0.9]
#         Psychic      [0.57, 1.29, 1.0]
#         Rock        [0.97, 0.97, 0.97]
#         Steel          [1.5, 1.5, 1.5]
#         Water       [0.64, 1.83, 1.03]
# Yellow  Bug         [0.04, 1.88, 1.06]
#         Dark           [0.5, 0.5, 0.5]
#         Dragon      [0.86, 0.86, 0.86]
#         Electric    [0.88, 1.75, 1.21]
#         Fighting     [0.67, 1.1, 0.88]
#         Fire        [0.81, 1.47, 1.18]
#         Ghost        [0.48, 0.9, 0.69]
#         Grass        [1.0, 1.92, 1.39]
#         Ground      [0.67, 0.82, 0.74]
#         Normal       [0.8, 1.38, 1.04]
#         Psychic      [0.48, 1.3, 0.76]
#         Rock         [1.12, 1.72, 1.5]
#         Steel          [1.0, 1.0, 1.0]
#         Water       [1.21, 1.43, 1.32]
# Name: Atk/Def Balance, dtype: object

# %%
combined_pokedex_df['Atk/Def Balance'] = combined_pokedex_df['SpAtk']/combined_pokedex_df['SpDef']

# %%
print(combined_pokedex_df)
# Out:
#                              Ability I        Ability II    Atk  Cap_Rate  \
# Pokemon
# Abomasnow                 Snow Warning               NaN   92.0      60.0
# Abra                       Synchronize       Inner Focus   20.0       NaN
# Absol                         Pressure        Super Luck  130.0       NaN
# Accelgor                     Hydration       Sticky Hold   70.0      75.0
# Aegislash                Stance Change               NaN   50.0      45.0
# Aerodactyl                   Rock Head          Pressure  105.0       NaN
# Aggron                          Sturdy         Rock Head  110.0       NaN
# Aipom                         Run Away            Pickup   70.0       NaN
# Alakazam                   Synchronize       Inner Focus   50.0       NaN
# Alcremie                    Sweet Veil               NaN   60.0     100.0
# Alomomola                       Healer         Hydration   75.0       NaN
# Altaria                   Natural Cure               NaN   70.0       NaN
# Amaura                     Refrigerate               NaN   59.0       NaN
# Ambipom                     Technician            Pickup  100.0       NaN
# Amoonguss                 Effect Spore               NaN   85.0       NaN
# Ampharos                        Static               NaN   75.0       NaN
# Anorith                   Battle Armor               NaN   95.0       NaN
# Appletun                         Ripen          Gluttony   85.0      45.0
# Applin                           Ripen          Gluttony   40.0     255.0
# Araquanid                Water Bubble       Water Absorb   70.0     100.0
# Arbok                       Intimidate         Shed Skin   85.0       NaN
# Arcanine                    Intimidate        Flash Fire  110.0      75.0
# Arceus                       Multitype               NaN  120.0       NaN
# Archen                       Defeatist               NaN  112.0       NaN
# Archeops                     Defeatist               NaN  140.0       NaN
# Arctovish                 Water Absorb          Ice Body   90.0      45.0
# Arctozolt                  Volt Absorb            Static  100.0      45.0
# Ariados                          Swarm          Insomnia   90.0       NaN
# Armaldo                   Battle Armor               NaN  125.0       NaN
# Aromatisse                      Healer               NaN   72.0     140.0
# Aron                            Sturdy         Rock Head   70.0       NaN
# Arrokuda                    Swift Swim               NaN   63.0     255.0
# Articuno                      Pressure               NaN   85.0       NaN
# Audino                          Healer       Regenerator   60.0       NaN
# Aurorus                    Refrigerate               NaN   77.0       NaN
# Avalugg                      Own Tempo          Ice Body  117.0      55.0
# Axew                           Rivalry      Mold Breaker   87.0      75.0
# Azelf                         Levitate               NaN  125.0       NaN
# Azumarill                    Thick Fat        Huge Power   50.0       NaN
# Azurill                      Thick Fat        Huge Power   20.0       NaN
# Bagon                        Rock Head               NaN   75.0       NaN
# Baltoy                        Levitate               NaN   40.0     255.0
# Banette                       Insomnia             Frisk  115.0       NaN
# Barbaracle                      Sniper       Tough Claws  105.0      45.0
# Barboach                     Oblivious        Anticipate   48.0     190.0
# Barraskewda                 Swift Swim               NaN  123.0      60.0
# Basculin                      Reckless      Adaptability   92.0      25.0
# Bastiodon                       Sturdy               NaN   52.0       NaN
# Bayleef                       Overgrow               NaN   62.0       NaN
# Beartic                     Snow Cloak        Slush Rush  110.0      60.0
# Beautifly                        Swarm               NaN   70.0       NaN
# Beedrill                         Swarm               NaN   80.0       NaN
# Beheeyem                     Telepathy       Synchronize   75.0      90.0
# Beldum                      Clear Body               NaN   55.0       NaN
# Bellossom                  Chlorophyll               NaN   80.0      45.0
# Bellsprout                 Chlorophyll               NaN   75.0       NaN
# Bergmite                     Own Tempo          Ice Body   69.0     190.0
# Bewear                         Fluffy             Klutz   125.0      70.0
# Bibarel                         Simple           Unaware   85.0       NaN
# Bidoof                          Simple           Unaware   45.0       NaN
# Binacle                         Sniper       Tough Claws   52.0     120.0
# Bisharp                        Defiant       Inner Focus  125.0      45.0
# Blastoise                      Torrent               NaN   83.0       NaN
# Blaziken                         Blaze               NaN  120.0       NaN
# Blipbug                          Swarm      Compoundeyes   20.0     255.0
# Blissey                   Natural Cure      Serene Grace   10.0       NaN
# Blitzle                   Lightningrod       Motor Drive   60.0       NaN
# Boldore                         Sturdy        Weak Armor  105.0     120.0
# Boltund                     Strong Jaw               NaN   90.0      45.0
# Bonsly                          Sturdy         Rock Head   80.0     255.0
# Bouffalant                    Reckless        Sap Sipper  110.0       NaN
# Bounsweet                  Leaf Guard         Oblivious    30.0     235.0
# Braixen                          Blaze               NaN   59.0       NaN
# Braviary                      Keen Eye       Sheer Force  123.0      60.0
# Breloom                   Effect Spore       Poison Heal  130.0       NaN
# Brionne                       Torrent       Liquid Voice   69.0       NaN
# Bronzong                      Levitate         Heatproof   89.0      90.0
# Bronzor                       Levitate         Heatproof   24.0     255.0
# Bruxish                      Dazzling        Strong Jaw   105.0       NaN
# Budew                     Natural Cure      Poison Point   30.0     255.0
# Buizel                      Swift Swim               NaN   65.0       NaN
# Bulbasaur                     Overgrow               NaN   49.0       NaN
# Buneary                       Run Away             Klutz   66.0       NaN
# Bunnelby                        Pickup       Cheek Pouch   36.0     255.0
# Burmy                        Shed Skin               NaN   29.0       NaN
# Butterfree                Compoundeyes               NaN   45.0      45.0
# Buzzwole                   Beast Boost               NaN  139.0       NaN
# Cacnea                       Sand Veil               NaN   85.0       NaN
# Cacturne                     Sand Veil               NaN  115.0       NaN
# Camerupt                   Magma Armor        Solid Rock  100.0       NaN
# Carbink                     Clear Body               NaN   50.0       NaN
# Carkol                    Steam Engine        Flame Body   60.0     120.0
# Carnivine                     Levitate               NaN  100.0       NaN
# Carracosta                  Solid Rock            Sturdy  108.0       NaN
# Carvanha                    Rough Skin               NaN   90.0       NaN
# Cascoon                      Shed Skin               NaN   35.0       NaN
# Castform                      Forecast               NaN   70.0       NaN
# Caterpie                   Shield Dust               NaN   30.0     255.0
# Celebi                    Natural Cure               NaN  100.0       NaN
# Celesteela                 Beast Boost               NaN  101.0       NaN
# Centiskorch                 Flash Fire       White Smoke  115.0      75.0
# Chandelure                  Flash Fire        Flame Body   55.0      45.0
# Chansey                   Natural Cure      Serene Grace    5.0       NaN
# Charizard                        Blaze               NaN   84.0      45.0
# Charjabug                      Battery               NaN   82.0     120.0
# Charmander                       Blaze               NaN   52.0      45.0
# Charmeleon                       Blaze               NaN   64.0      45.0
# Chatot                        Keen Eye      Tangled Feet   65.0       NaN
# Cherrim                    Flower Gift               NaN   60.0      75.0
# Cherubi                    Chlorophyll               NaN   35.0     190.0
# Chesnaught                    Overgrow               NaN  107.0       NaN
# Chespin                       Overgrow               NaN   61.0       NaN
# Chewtle                     Strong Jaw       Shell Armor   64.0     255.0
# Chikorita                     Overgrow               NaN   49.0       NaN
# Chimchar                         Blaze               NaN   58.0       NaN
# Chimecho                      Levitate               NaN   50.0       NaN
# Chinchou                   Volt Absorb        Illuminate   38.0     190.0
# Chingling                     Levitate               NaN   30.0       NaN
# Cinccino                    Cute Charm        Technician   95.0      60.0
# Cinderace                        Blaze               NaN  116.0      45.0
# Clamperl                   Shell Armor               NaN   64.0       NaN
# Clauncher                Mega Launcher               NaN   53.0       NaN
# Clawitzer                Mega Launcher               NaN   73.0       NaN
# Claydol                       Levitate               NaN   70.0      90.0
# Clefable                    Cute Charm       Magic Guard   70.0      25.0
# Clefairy                    Cute Charm       Magic Guard   45.0     150.0
# Cleffa                      Cute Charm       Magic Guard   25.0     150.0
# Clobbopus                       Limber               NaN   68.0     180.0
# Cloyster                   Shell Armor        Skill Link   90.0      60.0
# Coalossal                 Steam Engine        Flame Body   80.0      45.0
# Cobalion                     Justified               NaN   90.0       NaN
# Cofagrigus                       Mummy               NaN   50.0      90.0
# Combee                    Honey Gather               NaN   30.0     120.0
# Combusken                        Blaze               NaN   85.0       NaN
# Comfey                    Flower Veil            Triage    52.0       NaN
# Conkeldurr                        Guts       Sheer Force  140.0      45.0
# Copperajah                 Sheer Force               NaN  130.0      90.0
# Corphish                  Hyper Cutter       Shell Armor   80.0     205.0
# Corsola                         Hustle      Natural Cure   55.0      60.0
# Corviknight                   Pressure           Unnerve   87.0      45.0
# Corvisquire                   Keen Eye           Unnerve   67.0     120.0
# Cosmoem                         Sturdy               NaN   29.0       NaN
# Cosmog                         Unaware               NaN   29.0       NaN
# Cottonee                     Prankster       Infiltrator   27.0     190.0
# Crabominable             Hyper Cutter         Iron Fist   132.0       NaN
# Crabrawler               Hyper Cutter         Iron Fist    82.0       NaN
# Cradily                   Suction Cups               NaN   81.0       NaN
# Cramorant                 Gulp Missile               NaN   85.0      45.0
# Cranidos                  Mold Breaker               NaN  125.0       NaN
# Crawdaunt                 Hyper Cutter       Shell Armor  120.0     155.0
# Cresselia                     Levitate               NaN   70.0       NaN
# Croagunk                    Anticipate          Dry Skin   61.0     140.0
# Crobat                     Inner Focus               NaN   90.0       NaN
# Croconaw                       Torrent               NaN   80.0       NaN
# Crustle                         Sturdy       Shell Armor   95.0      75.0
# Cryogonal                     Levitate               NaN   50.0       NaN
# Cubchoo                     Snow Cloak        Slush Rush   70.0     120.0
# Cubone                       Rock Head      Lightningrod   50.0       NaN
# Cufant                     Sheer Force               NaN   80.0     190.0
# Cursola                     Weak Armor               NaN   95.0      30.0
# Cutiefly                 Honey Gather       Shield Dust    45.0     190.0
# Cyndaquil                        Blaze               NaN   52.0       NaN
# Darkrai                     Bad Dreams               NaN   90.0       NaN
# Darmanitan                 Sheer Force               NaN  140.0      60.0
# Darmanitan (Z)                     NaN               NaN   30.0       NaN
# Dartrix                      Overgrow         Long Reach   75.0       NaN
# Darumaka                        Hustle               NaN   90.0     120.0
# Decidueye                    Overgrow         Long Reach  107.0       NaN
# Dedenne                    Cheek Pouch            Pickup   58.0       NaN
# Deerling                   Chlorophyll        Sap Sipper   60.0       NaN
# Deino                           Hustle               NaN   65.0      45.0
# Delcatty                    Cute Charm         Normalize   65.0       NaN
# Delibird                  Vital Spirit            Hustle   55.0      45.0
# Delphox                          Blaze               NaN   69.0       NaN
# Deoxys (A)                    Pressure               NaN  180.0       NaN
# Deoxys (D)                    Pressure               NaN   70.0       NaN
# Deoxys (N)                    Pressure               NaN  150.0       NaN
# Deoxys (S)                    Pressure               NaN   95.0       NaN
# Dewgong                      Thick Fat         Hydration   70.0       NaN
# Dewott                         Torrent               NaN   75.0       NaN
# Dewpider                 Water Bubble       Water Absorb   40.0     200.0
# Dhelmise                   Steelworker               NaN  131.0      25.0
# Dialga                        Pressure               NaN  120.0       NaN
# Diancie                     Clear Body               NaN  100.0       NaN
# Diggersby                       Pickup       Cheek Pouch   56.0     127.0
# Diglett                      Sand Veil        Arena Trap   55.0     255.0
# Ditto                           Limber               NaN   48.0      35.0
# Dodrio                        Run Away        Early Bird  110.0       NaN
# Doduo                         Run Away        Early Bird   85.0       NaN
# Donphan                         Sturdy               NaN  120.0       NaN
# Dottler                          Swarm      Compoundeyes   35.0     120.0
# Doublade                      No Guard               NaN  110.0      90.0
# Dracovish                 Water Absorb        Strong Jaw   90.0      45.0
# Dracozolt                  Volt Absorb            Hustle  100.0      45.0
# Dragalge                  Poison Point      Poison Touch   75.0       NaN
# Dragapult                   Clear Body       Infiltrator  120.0      45.0
# Dragonair                    Shed Skin               NaN   84.0       NaN
# Dragonite                  Inner Focus               NaN  134.0       NaN
# Drakloak                    Clear Body       Infiltrator   80.0      45.0
# Drampa                        Berserk        Sap Sipper    60.0      70.0
# Drapion                   Battle Armor            Sniper   90.0      45.0
# Dratini                      Shed Skin               NaN   64.0       NaN
# Drednaw                     Strong Jaw       Shell Armor  115.0      75.0
# Dreepy                      Clear Body       Infiltrator   60.0      45.0
# Drifblim                     Aftermath          Unburden   80.0      60.0
# Drifloon                     Aftermath          Unburden   50.0     125.0
# Drilbur                      Sand Rush        Sand Force   85.0     120.0
# Drizzile                       Torrent               NaN   60.0      45.0
# Drowzee                       Insomnia          Forewarn   48.0       NaN
# Druddigon                   Rough Skin       Sheer Force  120.0       NaN
# Dubwool                         Fluffy         Steadfast   80.0     127.0
# Ducklett                      Keen Eye         Big Pecks   44.0       NaN
# Dugtrio                      Sand Veil        Arena Trap   80.0      50.0
# Dunsparce                 Serene Grace          Run Away   70.0       NaN
# Duosion                       Overcoat       Magic Guard   40.0     100.0
# Duraludon                  Light Metal       Heavy Metal   95.0      45.0
# Durant                           Swarm            Hustle  109.0      90.0
# Dusclops                      Pressure               NaN   70.0      90.0
# Dusknoir                      Pressure               NaN  100.0      45.0
# Duskull                       Levitate               NaN   40.0     190.0
# Dustox                     Shield Dust               NaN   50.0       NaN
# Dwebble                         Sturdy       Shell Armor   65.0     190.0
# Eelektrik                     Levitate               NaN   85.0       NaN
# Eelektross                    Levitate               NaN  115.0       NaN
# Eevee                         Run Away      Adaptability   55.0      45.0
# Eiscue                        Ice Face               NaN   80.0      60.0
# Ekans                       Intimidate         Shed Skin   60.0       NaN
# Eldegoss                   Cotton Down       Regenerator   50.0      75.0
# Electabuzz                      Static               NaN   83.0       NaN
# Electivire                 Motor Drive               NaN  123.0       NaN
# Electrike                       Static      Lightningrod   45.0     120.0
# Electrode                   Soundproof            Static   50.0       NaN
# Elekid                          Static               NaN   63.0       NaN
# Elgyem                       Telepathy       Synchronize   55.0     255.0
# Emboar                           Blaze               NaN  123.0       NaN
# Emolga                          Static               NaN   75.0       NaN
# Empoleon                       Torrent               NaN   86.0       NaN
# Entei                         Pressure               NaN  115.0       NaN
# Escavalier                       Swarm       Shell Armor  135.0      75.0
# Espeon                     Synchronize               NaN   65.0      45.0
# Espurr                        Keen Eye       Infiltrator   48.0     190.0
# Eternatus                     Pressure               NaN   85.0     255.0
# Excadrill                    Sand Rush        Sand Force  135.0      60.0
# Exeggcute                  Chlorophyll               NaN   40.0       NaN
# Exeggutor                  Chlorophyll               NaN   95.0       NaN
# Exploud                     Soundproof               NaN   91.0       NaN
# Falinks                   Battle Armor               NaN  100.0      45.0
# Farfetch'd                    Keen Eye       Inner Focus   65.0       NaN
# Farfetchd                    Steadfast               NaN   95.0      45.0
# Fearow                        Keen Eye               NaN   90.0       NaN
# Feebas                      Swift Swim         Oblivious   15.0     255.0
# Fennekin                         Blaze               NaN   45.0       NaN
# Feraligatr                     Torrent               NaN  105.0       NaN
# Ferroseed                   Iron Barbs               NaN   50.0     255.0
# Ferrothorn                  Iron Barbs               NaN   94.0      90.0
# Finneon                     Swift Swim       Storm Drain   49.0       NaN
# Flaaffy                         Static               NaN   55.0       NaN
# Flabébé                    Flower Veil               NaN   38.0       NaN
# Flapple                          Ripen          Gluttony  110.0      45.0
# Flareon                     Flash Fire               NaN  130.0      45.0
# Fletchinder                 Flame Body               NaN   73.0       NaN
# Fletchling                   Big Pecks               NaN   50.0       NaN
# Floatzel                    Swift Swim               NaN  105.0       NaN
# Floette                    Flower Veil               NaN   45.0       NaN
# Florges                    Flower Veil               NaN   65.0       NaN
# Flygon                        Levitate               NaN  100.0      45.0
# Fomantis                   Leaf Guard           Contrary   55.0       NaN
# Foongus                   Effect Spore               NaN   55.0       NaN
# Forretress                      Sturdy               NaN   90.0       NaN
# Fraxure                        Rivalry      Mold Breaker  117.0      60.0
# Frillish                  Water Absorb       Cursed Body   40.0     190.0
# Froakie                        Torrent               NaN   56.0       NaN
# Frogadier                      Torrent               NaN   63.0       NaN
# Froslass                    Snow Cloak               NaN   80.0      75.0
# Frosmoth                   Shield Dust               NaN   65.0      75.0
# Furfrou                       Fur Coat               NaN   80.0       NaN
# Furret                        Run Away          Keen Eye   76.0       NaN
# Gabite                       Sand Veil               NaN   90.0       NaN
# Gallade                      Steadfast               NaN  125.0      45.0
# Galvantula                Compoundeyes           Unnerve   77.0      75.0
# Garbodor                        Stench        Weak Armor   95.0      60.0
# Garchomp                     Sand Veil               NaN  130.0       NaN
# Gardevoir                  Synchronize             Trace   65.0      45.0
# Gastly                        Levitate               NaN   35.0     190.0
# Gastrodon                  Sticky Hold       Storm Drain   83.0      75.0
# Genesect                      Download               NaN  120.0       NaN
# Gengar                        Levitate               NaN   65.0      45.0
# Geodude                      Rock Head            Sturdy   80.0       NaN
# Gible                        Sand Veil               NaN   70.0       NaN
# Gigalith                        Sturdy       Sand Stream  135.0      45.0
# Girafarig                  Inner Focus        Early Bird   80.0       NaN
# Giratina                      Pressure               NaN  100.0       NaN
# Giratina (O)                  Levitate               NaN  120.0       NaN
# Glaceon                     Snow Cloak               NaN   60.0      45.0
# Glalie                     Inner Focus          Ice Body   80.0      75.0
# Glameow                         Limber         Own Tempo   55.0       NaN
# Gligar                    Hyper Cutter         Sand Veil   75.0       NaN
# Gliscor                   Hyper Cutter         Sand Veil   95.0       NaN
# Gloom                      Chlorophyll               NaN   65.0     120.0
# Gogoat                      Sap Sipper               NaN  100.0       NaN
# Golbat                     Inner Focus               NaN   80.0       NaN
# Goldeen                     Swift Swim        Water Veil   67.0     225.0
# Golduck                           Damp        Cloud Nine   82.0       NaN
# Golem                        Rock Head            Sturdy  110.0       NaN
# Golett                       Iron Fist             Klutz   74.0     190.0
# Golisopod               Emergency Exit               NaN  125.0      45.0
# Golurk                       Iron Fist             Klutz  124.0      90.0
# Goodra                      Sap Sipper         Hydration  100.0      45.0
# Goomy                       Sap Sipper         Hydration   50.0      45.0
# Gorebyss                    Swift Swim               NaN   84.0       NaN
# Gossifleur                 Cotton Down       Regenerator   40.0     190.0
# Gothita                          Frisk       Competitive   30.0     200.0
# Gothitelle                       Frisk       Competitive   55.0      50.0
# Gothorita                        Frisk       Competitive   45.0     100.0
# Gourgeist                       Pickup             Frisk   85.0      60.0
# Granbull                    Intimidate        Quick Feet  120.0       NaN
# Grapploct                       Limber               NaN  118.0      45.0
# Graveler                     Rock Head            Sturdy   95.0       NaN
# Greedent                   Cheek Pouch               NaN   95.0      90.0
# Greninja                       Torrent               NaN   95.0       NaN
# Grimer                          Stench       Sticky Hold   80.0       NaN
# Grimmsnarl                   Prankster             Frisk  120.0      45.0
# Grookey                       Overgrow               NaN   65.0      45.0
# Grotle                        Overgrow               NaN   89.0       NaN
# Groudon                        Drought               NaN  150.0       NaN
# Grovyle                       Overgrow               NaN   65.0       NaN
# Growlithe                   Intimidate        Flash Fire   70.0     190.0
# Grubbin                          Swarm               NaN   62.0     255.0
# Grumpig                      Thick Fat         Own Tempo   45.0       NaN
# Gulpin                     Liquid Ooze       Sticky Hold   43.0       NaN
# Gumshoos                     Stakeout        Strong Jaw   110.0       NaN
# Gurdurr                           Guts       Sheer Force  105.0      90.0
# Guzzlord                   Beast Boost               NaN  101.0       NaN
# Gyarados                    Intimidate               NaN  125.0      45.0
# Hakamo-o                  Bulletproof        Soundproof    75.0       NaN
# Hakamoo                    Bulletproof        Soundproof   75.0      45.0
# Happiny                   Natural Cure      Serene Grace    5.0       NaN
# Hariyama                     Thick Fat              Guts  120.0       NaN
# Hatenna                         Healer      Anticipation   30.0     235.0
# Hatterene                       Healer      Anticipation   90.0      45.0
# Hattrem                         Healer      Anticipation   40.0     120.0
# Haunter                       Levitate               NaN   50.0      90.0
# Hawlucha                      Unburden            Limber   92.0     100.0
# Haxorus                        Rivalry      Mold Breaker  147.0      45.0
# Heatmor                       Gluttony        Flash Fire   97.0      90.0
# Heatran                     Flash Fire               NaN   90.0       NaN
# Heliolisk                     Dry Skin         Sand Veil   55.0      75.0
# Helioptile                    Dry Skin         Sand Veil   38.0     190.0
# Heracross                        Swarm              Guts  125.0       NaN
# Herdier                     Intimidate         Sand Rush   80.0       NaN
# Hippopotas                 Sand Stream               NaN   72.0     140.0
# Hippowdon                  Sand Stream               NaN  112.0      60.0
# Hitmonchan                    Keen Eye         Iron Fist  105.0      45.0
# Hitmonlee                       Limber          Reckless  120.0      45.0
# Hitmontop                   Intimidate        Technician   95.0      45.0
# Ho-oh                         Pressure               NaN  130.0       NaN
# Honchkrow                     Insomnia        Super Luck  125.0       NaN
# Honedge                       No Guard               NaN   80.0     180.0
# Hoopa (C)                     Magician               NaN  110.0       NaN
# Hoopa (U)                     Magician               NaN  160.0       NaN
# Hoothoot                      Insomnia          Keen Eye   30.0     255.0
# Hoppip                     Chlorophyll        Leaf Guard   35.0       NaN
# Horsea                      Swift Swim            Sniper   40.0       NaN
# Houndoom                    Early Bird        Flash Fire   90.0       NaN
# Houndour                    Early Bird        Flash Fire   60.0       NaN
# Huntail                     Swift Swim               NaN  104.0       NaN
# Hydreigon                     Levitate               NaN  105.0      45.0
# Hypno                         Insomnia          Forewarn   73.0       NaN
# Igglybuff                   Cute Charm               NaN   30.0       NaN
# Illumise                     Oblivious       Tinted Lens   47.0       NaN
# Impidimp                     Prankster             Frisk   45.0     255.0
# Incineroar                      Blaze         Intimidate  115.0       NaN
# Indeedee                   Inner Focus       Synchronize   65.0      30.0
# Infernape                        Blaze               NaN  104.0       NaN
# Inkay                     Suction Cups          Contrary   54.0     190.0
# Inteleon                       Torrent               NaN   85.0      45.0
# Ivysaur                       Overgrow               NaN   62.0       NaN
# Jangmo-o                  Bulletproof        Soundproof    55.0       NaN
# Jangmoo                    Bulletproof        Soundproof   55.0      45.0
# Jellicent                 Water Absorb       Cursed Body   60.0      60.0
# Jigglypuff                  Cute Charm               NaN   45.0       NaN
# Jirachi                   Serene Grace               NaN  100.0       NaN
# Jolteon                    Volt Absorb               NaN   65.0      45.0
# Joltik                    Compoundeyes           Unnerve   47.0     190.0
# Jumpluff                   Chlorophyll        Leaf Guard   55.0       NaN
# Jynx                         Oblivious          Forewarn   50.0       NaN
# Kabuto                      Swift Swim      Battle Armor   80.0       NaN
# Kabutops                    Swift Swim      Battle Armor  115.0       NaN
# Kadabra                    Synchronize       Inner Focus   35.0       NaN
# Kakuna                       Shed Skin               NaN   25.0       NaN
# Kangaskhan                  Early Bird           Scrappy   95.0       NaN
# Karrablast                       Swarm         Shed Skin   75.0     200.0
# Kartana                    Beast Boost               NaN  181.0       NaN
# Kecleon                   Color Change               NaN   90.0       NaN
# Keldeo                       Justified               NaN   72.0       NaN
# Kingdra                     Swift Swim            Sniper   95.0       NaN
# Kingler                   Hyper Cutter       Shell Armor  130.0      60.0
# Kirlia                     Synchronize             Trace   35.0     120.0
# Klang                             Plus             Minus   80.0      60.0
# Klefki                       Prankster               NaN   80.0       NaN
# Klink                             Plus             Minus   55.0     130.0
# Klinklang                         Plus             Minus  100.0      30.0
# Koffing                       Levitate  Neutralizing Gas   65.0     190.0
# Komala                        Comatose               NaN  115.0       NaN
# Kommo-o                   Bulletproof        Soundproof   110.0       NaN
# Kommoo                     Bulletproof        Soundproof  110.0      45.0
# Krabby                    Hyper Cutter       Shell Armor  105.0     225.0
# Kricketot                    Shed Skin               NaN   25.0       NaN
# Kricketune                       Swarm               NaN   85.0       NaN
# Krokorok                    Intimidate             Moxie   82.0       NaN
# Krookodile                  Intimidate             Moxie  117.0       NaN
# Kyogre                         Drizzle               NaN  100.0       NaN
# Kyurem                        Pressure               NaN  130.0       NaN
# Lairon                          Sturdy         Rock Head   90.0       NaN
# Lampent                     Flash Fire        Flame Body   40.0      90.0
# Landorus                    Sand Force               NaN  125.0       NaN
# Lanturn                    Volt Absorb        Illuminate   58.0      75.0
# Lapras                    Water Absorb       Shell Armor   85.0      45.0
# Larvesta                    Flame Body               NaN   85.0       NaN
# Larvitar                          Guts               NaN   64.0      45.0
# Latias                        Levitate               NaN   80.0       NaN
# Latios                        Levitate               NaN   90.0       NaN
# Leafeon                     Leaf Guard               NaN  110.0      45.0
# Leavanny                         Swarm       Chlorophyll  103.0       NaN
# Ledian                           Swarm        Early Bird   35.0       NaN
# Ledyba                           Swarm        Early Bird   20.0       NaN
# Lickilicky                   Own Tempo         Oblivious   85.0       NaN
# Lickitung                    Own Tempo         Oblivious   55.0       NaN
# Liepard                         Limber          Unburden   88.0      90.0
# Lileep                    Suction Cups               NaN   41.0       NaN
# Lilligant                  Chlorophyll         Own Tempo   60.0       NaN
# Lillipup                  Vital Spirit            Pickup   60.0       NaN
# Linoone                         Pickup          Gluttony   70.0      90.0
# Litleo                         Rivalry           Unnerve   50.0       NaN
# Litten                          Blaze         Intimidate   65.0       NaN
# Litwick                     Flash Fire        Flame Body   30.0     190.0
# Lombre                      Swift Swim         Rain Dish   50.0     120.0
# Lopunny                     Cute Charm             Klutz   76.0       NaN
# Lotad                       Swift Swim         Rain Dish   30.0     255.0
# Loudred                     Soundproof               NaN   71.0       NaN
# Lucario                      Steadfast       Inner Focus  110.0      45.0
# Ludicolo                    Swift Swim         Rain Dish   70.0      45.0
# Lugia                         Pressure               NaN   90.0       NaN
# Lumineon                    Swift Swim       Storm Drain   69.0       NaN
# Lunala                   Shadow Shield               NaN  113.0       NaN
# Lunatone                      Levitate               NaN   55.0      45.0
# Lurantis                   Leaf Guard           Contrary  105.0       NaN
# Luvdisc                     Swift Swim               NaN   30.0       NaN
# Luxio                          Rivalry        Intimidate   85.0       NaN
# Luxray                         Rivalry        Intimidate  120.0       NaN
# Lycanroc (midday)            Keen Eye         Sand Rush   115.0       NaN
# Lycanroc (midnight)           Keen Eye     Vital Spirit   115.0       NaN
# Machamp                           Guts          No Guard  130.0      45.0
# Machoke                           Guts          No Guard  100.0      90.0
# Machop                            Guts          No Guard   80.0     180.0
# Magby                       Flame Body               NaN   75.0       NaN
# Magcargo                   Magma Armor        Flame Body   50.0       NaN
# Magearna                    Soul-Heart               NaN   95.0       NaN
# Magikarp                    Swift Swim               NaN   10.0     255.0
# Magmar                      Flame Body               NaN   95.0       NaN
# Magmortar                   Flame Body               NaN   95.0       NaN
# Magnemite                  Magnet Pull            Sturdy   35.0       NaN
# Magneton                   Magnet Pull            Sturdy   60.0       NaN
# Magnezone                  Magnet Pull            Sturdy   70.0       NaN
# Makuhita                     Thick Fat              Guts   60.0       NaN
# Malamar                   Suction Cups          Contrary   92.0      80.0
# Mamoswine                    Oblivious        Snow Cloak  130.0      50.0
# Manaphy                      Hydration               NaN  100.0       NaN
# Mandibuzz                    Big Pecks          Overcoat   65.0      60.0
# Manectric                       Static      Lightningrod   75.0      45.0
# Mankey                    Vital Spirit       Anger Point   80.0       NaN
# Mantine                     Swift Swim      Water Absorb   40.0      25.0
# Mantyke                     Swift Swim      Water Absorb   20.0      25.0
# Maractus                  Water Absorb       Chlorophyll   86.0     255.0
# Mareanie                    Merciless            Limber    53.0     190.0
# Mareep                          Static               NaN   40.0       NaN
# Marill                       Thick Fat        Huge Power   20.0       NaN
# Marowak                      Rock Head      Lightningrod   80.0       NaN
# Marshadow                   Technician               NaN  125.0       NaN
# Marshtomp                      Torrent               NaN   85.0       NaN
# Masquerain                  Intimidate               NaN   60.0       NaN
# Mawile                    Hyper Cutter        Intimidate   85.0      45.0
# Medicham                    Pure Power               NaN   60.0       NaN
# Meditite                    Pure Power               NaN   40.0       NaN
# Meganium                      Overgrow               NaN   82.0       NaN
# Meloetta (A)              Serene Grace               NaN   77.0       NaN
# Meloetta (P)              Serene Grace               NaN  128.0       NaN
# Meowstic                      Keen Eye       Infiltrator   48.0      75.0
# Meowth                          Pickup        Technician   45.0     255.0
# Mesprit                       Levitate               NaN  105.0       NaN
# Metagross                   Clear Body               NaN  135.0       NaN
# Metang                      Clear Body               NaN   75.0       NaN
# Metapod                      Shed Skin               NaN   20.0     120.0
# Mew                        Synchronize               NaN  100.0       NaN
# Mewtwo                        Pressure               NaN  110.0       NaN
# Mienfoo                    Inner Focus       Regenerator   85.0       NaN
# Mienshao                   Inner Focus       Regenerator  125.0       NaN
# Mightyena                   Intimidate        Quick Feet   90.0       NaN
# Milcery                     Sweet Veil               NaN   40.0     200.0
# Milotic                   Marvel Scale       Competitive   60.0      60.0
# Miltank                      Thick Fat           Scrappy   80.0       NaN
# Mime Jr.                    Soundproof            Filter   25.0       NaN
# MimeJr                      Soundproof            Filter   25.0     145.0
# Mimikyu                       Disguise               NaN   90.0      45.0
# Minccino                    Cute Charm        Technician   50.0     255.0
# Minior (core)             Shields Down               NaN  100.0       NaN
# Minior (meteor)           Shields Down               NaN   60.0       NaN
# Minun                            Minus               NaN   40.0       NaN
# Misdreavus                    Levitate               NaN   60.0       NaN
# Mismagius                     Levitate               NaN   60.0       NaN
# Moltres                       Pressure               NaN  100.0       NaN
# Monferno                         Blaze               NaN   78.0       NaN
# Morelull                   Illuminate       Effect Spore   35.0     190.0
# Morgrem                      Prankster             Frisk   60.0     120.0
# Morpeko                  Hunger Switch               NaN   95.0     180.0
# Mothim                           Swarm               NaN   94.0       NaN
# Mr. Mime                    Soundproof            Filter   45.0       NaN
# MrMime                    Vital Spirit    Screen Cleaner   65.0      45.0
# MrRime                    Tangled Feet    Screen Cleaner   85.0      45.0
# Mudbray                      Own Tempo          Stamina   100.0     190.0
# Mudkip                         Torrent               NaN   70.0       NaN
# Mudsdale                     Own Tempo          Stamina   125.0      60.0
# Muk                             Stench       Sticky Hold  105.0       NaN
# Munchlax                        Pickup         Thick Fat   85.0      50.0
# Munna                         Forewarn       Synchronize   25.0     190.0
# Murkrow                       Insomnia        Super Luck   85.0       NaN
# Musharna                      Forewarn       Synchronize   55.0      75.0
# Natu                       Synchronize        Early Bird   50.0     190.0
# Necrozma                   Prism Armor               NaN  107.0       NaN
# Nickit                        Run Away          Unburden   28.0     255.0
# Nidoking                  Poison Point           Rivalry   92.0       NaN
# Nidoqueen                 Poison Point           Rivalry   82.0       NaN
# Nidoran♀                  Poison Point           Rivalry   47.0       NaN
# Nidoran♂                  Poison Point           Rivalry   57.0       NaN
# Nidorina                  Poison Point           Rivalry   62.0       NaN
# Nidorino                  Poison Point           Rivalry   72.0       NaN
# Nihilego                   Beast Boost               NaN   53.0       NaN
# Nincada                   Compoundeyes               NaN   45.0     255.0
# Ninetales                   Flash Fire               NaN   76.0      75.0
# Ninjask                    Speed Boost               NaN   90.0     120.0
# Noctowl                       Insomnia          Keen Eye   50.0      90.0
# Noibat                           Frisk       Infiltrator   30.0     190.0
# Noivern                          Frisk       Infiltrator   70.0      45.0
# Nosepass                        Sturdy       Magnet Pull   45.0       NaN
# Numel                        Oblivious            Simple   60.0       NaN
# Nuzleaf                    Chlorophyll        Early Bird   70.0     120.0
# Obstagoon                     Reckless              Guts   90.0      45.0
# Octillery                 Suction Cups            Sniper  105.0      75.0
# Oddish                     Chlorophyll               NaN   50.0     255.0
# Omanyte                     Swift Swim       Shell Armor   40.0       NaN
# Omastar                     Swift Swim       Shell Armor   60.0       NaN
# Onix                         Rock Head            Sturdy   45.0      45.0
# Oranguru                  Inner Focus         Telepathy    60.0      45.0
# Orbeetle                         Swarm             Frisk   45.0      45.0
# Oricorio                        Dancer               NaN   70.0       NaN
# Oshawott                       Torrent               NaN   55.0       NaN
# Pachirisu                     Run Away            Pickup   45.0       NaN
# Palkia                        Pressure               NaN  120.0       NaN
# Palossand            Water Compaction          Sand Veil   75.0       NaN
# Palpitoad                   Swift Swim         Hydration   65.0     120.0
# Pancham                      Iron Fist      Mold Breaker   82.0     220.0
# Pangoro                      Iron Fist      Mold Breaker  124.0      65.0
# Panpour                       Gluttony               NaN   53.0       NaN
# Pansage                       Gluttony               NaN   53.0       NaN
# Pansear                       Gluttony               NaN   53.0       NaN
# Paras                     Effect Spore          Dry Skin   70.0       NaN
# Parasect                  Effect Spore          Dry Skin   95.0       NaN
# Passimian                    Receiver            Defiant  120.0      45.0
# Patrat                        Run Away          Keen Eye   55.0       NaN
# Pawniard                       Defiant       Inner Focus   85.0     120.0
# Pelipper                      Keen Eye           Drizzle   50.0      45.0
# Perrserker                Battle Armor       Tough Claws  110.0      90.0
# Persian                         Limber        Technician   70.0      90.0
# Petilil                    Chlorophyll         Own Tempo   35.0       NaN
# Phanpy                          Pickup               NaN   60.0       NaN
# Phantump                  Natural Cure             Frisk   70.0     120.0
# Pheromosa                  Beast Boost               NaN  137.0       NaN
# Phione                       Hydration               NaN   80.0       NaN
# Pichu                           Static               NaN   40.0     190.0
# Pidgeot                       Keen Eye      Tangled Feet   80.0       NaN
# Pidgeotto                     Keen Eye      Tangled Feet   60.0       NaN
# Pidgey                        Keen Eye      Tangled Feet   45.0       NaN
# Pidove                       Big Pecks        Super Luck   55.0     255.0
# Pignite                          Blaze               NaN   93.0       NaN
# Pikachu                         Static               NaN   55.0     190.0
# Pikipek                      Keen Eye        Skill Link    75.0       NaN
# Piloswine                    Oblivious        Snow Cloak  100.0      75.0
# Pincurchin               Lightning Rod               NaN  101.0      75.0
# Pineco                          Sturdy               NaN   65.0       NaN
# Pinsir                    Hyper Cutter      Mold Breaker  125.0       NaN
# Piplup                         Torrent               NaN   51.0       NaN
# Plusle                            Plus               NaN   50.0       NaN
# Politoed                  Water Absorb              Damp   75.0       NaN
# Poliwag                   Water Absorb              Damp   50.0       NaN
# Poliwhirl                 Water Absorb              Damp   65.0       NaN
# Poliwrath                 Water Absorb              Damp   85.0       NaN
# Polteageist                 Weak Armor               NaN   65.0      60.0
# Ponyta                        Run Away        Flash Fire   85.0     190.0
# Poochyena                     Run Away        Quick Feet   55.0       NaN
# Popplio                       Torrent       Liquid Voice   54.0       NaN
# Porygon                          Trace          Download   60.0       NaN
# Porygon-Z                 Adaptability          Download   80.0       NaN
# Porygon2                         Trace          Download   80.0       NaN
# Primarina                     Torrent       Liquid Voice   74.0       NaN
# Primeape                  Vital Spirit       Anger Point  105.0       NaN
# Prinplup                       Torrent               NaN   66.0       NaN
# Probopass                       Sturdy       Magnet Pull   55.0       NaN
# Psyduck                           Damp        Cloud Nine   52.0       NaN
# Pumpkaboo                       Pickup             Frisk   66.0     120.0
# Pupitar                      Shed Skin               NaN   84.0      45.0
# Purrloin                        Limber          Unburden   50.0     255.0
# Purugly                      Thick Fat         Own Tempo   82.0       NaN
# Pyroar                         Rivalry           Unnerve   68.0       NaN
# Pyukumuku                  Innards Out           Unaware   60.0      60.0
# Quagsire                          Damp      Water Absorb   85.0      90.0
# Quilava                          Blaze               NaN   64.0       NaN
# Quilladin                     Overgrow               NaN   78.0       NaN
# Qwilfish                  Poison Point        Swift Swim   95.0      45.0
# Raboot                           Blaze               NaN   86.0      45.0
# Raichu                          Static               NaN   90.0      75.0
# Raikou                        Pressure               NaN   85.0       NaN
# ...
# Simisage                   NaN         NaN    NaN  1.555556         1.555556
# Simisear                   NaN         NaN    NaN  1.555556         1.555556
# Sinistea                   0.2         0.4  334.0  1.370370         1.370370
# Sirfetchd                117.0       257.9  218.0  0.829268         0.829268
# Sizzlipede                 1.0         2.2  158.0  1.000000         1.000000
# Skarmory                   NaN         NaN    NaN  0.571429         0.571429
# Weezing                    9.5        20.9  250.0  1.214286         1.214286
# Whimsicott                 6.6        14.6  262.0  1.026667         1.026667
# Whirlipede                 NaN         NaN    NaN  0.506329         0.506329
# Whiscash                  23.6        52.0  228.0  1.070423         1.070423
# Whismur                    NaN         NaN    NaN  2.217391         2.217391
# Wigglytuff                 NaN         NaN    NaN  1.500000         1.500000
# Wimpod                    12.0        26.5  231.0  0.666667         0.666667
# Wingull                    9.5        20.9   61.0  1.833333         1.833333
# Wishiwashi                 0.3         0.7  154.0  1.000000         1.000000
# Wishiwashi (school)        NaN         NaN    NaN  1.037037         1.037037
# Wishiwashi (solo)          NaN         NaN    NaN  1.000000         1.000000
# Wobbuffet                 28.5        62.8  216.0  0.568966         0.568966
# Woobat                     2.1         4.6  173.0  1.279070         1.279070
# Wooloo                     6.0        13.2   33.0  0.888889         0.888889
# Wooper                     8.5        18.7   99.0  1.000000         1.000000
# Wormadam (P)               NaN         NaN    NaN  0.752381         0.752381
# Wormadam (S)               NaN         NaN    NaN  0.694118         0.694118
# Wormadam (T)               NaN         NaN    NaN  0.726316         0.726316
# Wurmple                    NaN         NaN    NaN  0.666667         0.666667
# Wynaut                    14.0        30.9  215.0  0.479167         0.479167
# Xatu                      15.0        33.1   92.0  1.357143         1.357143
# Xerneas                    NaN         NaN    NaN  1.336735         1.336735
# Xurkitree                  NaN         NaN    NaN  2.436620         2.436620
# Yamask                     1.5         3.3  326.0  0.846154         0.846154
# Yamper                    13.5        29.8   45.0  0.800000         0.800000
# Yanma                      NaN         NaN    NaN  1.666667         1.666667
# Yanmega                    NaN         NaN    NaN  2.071429         2.071429
# Yungoos                    NaN         NaN    NaN  1.000000         1.000000
# Yveltal                    NaN         NaN    NaN  1.336735         1.336735
# Zacian                   110.0       242.5  397.0  0.695652         0.695652
# Zamazenta                210.0       463.0  398.0  0.695652         0.695652
# Zangoose                   NaN         NaN    NaN  1.000000         1.000000
# Zapdos                     NaN         NaN    NaN  1.388889         1.388889
# Zebstrika                  NaN         NaN    NaN  1.269841         1.269841
# Zekrom                     NaN         NaN    NaN  1.200000         1.200000
# Zigzagoon                 17.5        38.6   30.0  0.731707         0.731707
# Zoroark                    NaN         NaN    NaN  2.000000         2.000000
# Zorua                      NaN         NaN    NaN  2.000000         2.000000
# Zubat                      NaN         NaN    NaN  0.750000         0.750000
# Zweilous                  50.0       110.2  386.0  0.928571         0.928571
# Zygarde                    NaN         NaN    NaN  0.852632         0.852632

# %%
print(combined_pokedex_df)
# Out:
#                              Ability I        Ability II    Atk  Cap_Rate  \
# Pokemon
# Abomasnow                 Snow Warning               NaN   92.0      60.0
# Abra                       Synchronize       Inner Focus   20.0       NaN
# Absol                         Pressure        Super Luck  130.0       NaN
# Accelgor                     Hydration       Sticky Hold   70.0      75.0
# Aegislash                Stance Change               NaN   50.0      45.0
# Aerodactyl                   Rock Head          Pressure  105.0       NaN
# Aggron                          Sturdy         Rock Head  110.0       NaN
# Aipom                         Run Away            Pickup   70.0       NaN
# Alakazam                   Synchronize       Inner Focus   50.0       NaN
# Alcremie                    Sweet Veil               NaN   60.0     100.0
# Alomomola                       Healer         Hydration   75.0       NaN
# Altaria                   Natural Cure               NaN   70.0       NaN
# Amaura                     Refrigerate               NaN   59.0       NaN
# Ambipom                     Technician            Pickup  100.0       NaN
# Amoonguss                 Effect Spore               NaN   85.0       NaN
# Ampharos                        Static               NaN   75.0       NaN
# Anorith                   Battle Armor               NaN   95.0       NaN
# Appletun                         Ripen          Gluttony   85.0      45.0
# Applin                           Ripen          Gluttony   40.0     255.0
# Araquanid                Water Bubble       Water Absorb   70.0     100.0
# Arbok                       Intimidate         Shed Skin   85.0       NaN
# Arcanine                    Intimidate        Flash Fire  110.0      75.0
# Arceus                       Multitype               NaN  120.0       NaN
# Archen                       Defeatist               NaN  112.0       NaN
# Archeops                     Defeatist               NaN  140.0       NaN
# Arctovish                 Water Absorb          Ice Body   90.0      45.0
# Arctozolt                  Volt Absorb            Static  100.0      45.0
# Ariados                          Swarm          Insomnia   90.0       NaN
# Armaldo                   Battle Armor               NaN  125.0       NaN
# Aromatisse                      Healer               NaN   72.0     140.0
# Aron                            Sturdy         Rock Head   70.0       NaN
# Arrokuda                    Swift Swim               NaN   63.0     255.0
# Articuno                      Pressure               NaN   85.0       NaN
# Audino                          Healer       Regenerator   60.0       NaN
# Aurorus                    Refrigerate               NaN   77.0       NaN
# Avalugg                      Own Tempo          Ice Body  117.0      55.0
# Axew                           Rivalry      Mold Breaker   87.0      75.0
# Azelf                         Levitate               NaN  125.0       NaN
# Azumarill                    Thick Fat        Huge Power   50.0       NaN
# Azurill                      Thick Fat        Huge Power   20.0       NaN
# Bagon                        Rock Head               NaN   75.0       NaN
# Baltoy                        Levitate               NaN   40.0     255.0
# Banette                       Insomnia             Frisk  115.0       NaN
# Barbaracle                      Sniper       Tough Claws  105.0      45.0
# Barboach                     Oblivious        Anticipate   48.0     190.0
# Barraskewda                 Swift Swim               NaN  123.0      60.0
# Basculin                      Reckless      Adaptability   92.0      25.0
# Bastiodon                       Sturdy               NaN   52.0       NaN
# Bayleef                       Overgrow               NaN   62.0       NaN
# Beartic                     Snow Cloak        Slush Rush  110.0      60.0
# Beautifly                        Swarm               NaN   70.0       NaN
# Beedrill                         Swarm               NaN   80.0       NaN
# Beheeyem                     Telepathy       Synchronize   75.0      90.0
# Beldum                      Clear Body               NaN   55.0       NaN
# Bellossom                  Chlorophyll               NaN   80.0      45.0
# Bellsprout                 Chlorophyll               NaN   75.0       NaN
# Bergmite                     Own Tempo          Ice Body   69.0     190.0
# Bewear                         Fluffy             Klutz   125.0      70.0
# Bibarel                         Simple           Unaware   85.0       NaN
# Bidoof                          Simple           Unaware   45.0       NaN
# Binacle                         Sniper       Tough Claws   52.0     120.0
# Bisharp                        Defiant       Inner Focus  125.0      45.0
# Blastoise                      Torrent               NaN   83.0       NaN
# Blaziken                         Blaze               NaN  120.0       NaN
# Blipbug                          Swarm      Compoundeyes   20.0     255.0
# Blissey                   Natural Cure      Serene Grace   10.0       NaN
# Blitzle                   Lightningrod       Motor Drive   60.0       NaN
# Boldore                         Sturdy        Weak Armor  105.0     120.0
# Boltund                     Strong Jaw               NaN   90.0      45.0
# Bonsly                          Sturdy         Rock Head   80.0     255.0
# Bouffalant                    Reckless        Sap Sipper  110.0       NaN
# Bounsweet                  Leaf Guard         Oblivious    30.0     235.0
# Braixen                          Blaze               NaN   59.0       NaN
# Braviary                      Keen Eye       Sheer Force  123.0      60.0
# Breloom                   Effect Spore       Poison Heal  130.0       NaN
# Brionne                       Torrent       Liquid Voice   69.0       NaN
# Bronzong                      Levitate         Heatproof   89.0      90.0
# Bronzor                       Levitate         Heatproof   24.0     255.0
# Bruxish                      Dazzling        Strong Jaw   105.0       NaN
# Budew                     Natural Cure      Poison Point   30.0     255.0
# Buizel                      Swift Swim               NaN   65.0       NaN
# Bulbasaur                     Overgrow               NaN   49.0       NaN
# Buneary                       Run Away             Klutz   66.0       NaN
# Bunnelby                        Pickup       Cheek Pouch   36.0     255.0
# Burmy                        Shed Skin               NaN   29.0       NaN
# Butterfree                Compoundeyes               NaN   45.0      45.0
# Buzzwole                   Beast Boost               NaN  139.0       NaN
# Cacnea                       Sand Veil               NaN   85.0       NaN
# Cacturne                     Sand Veil               NaN  115.0       NaN
# Camerupt                   Magma Armor        Solid Rock  100.0       NaN
# Carbink                     Clear Body               NaN   50.0       NaN
# Carkol                    Steam Engine        Flame Body   60.0     120.0
# Carnivine                     Levitate               NaN  100.0       NaN
# Carracosta                  Solid Rock            Sturdy  108.0       NaN
# Carvanha                    Rough Skin               NaN   90.0       NaN
# Cascoon                      Shed Skin               NaN   35.0       NaN
# Castform                      Forecast               NaN   70.0       NaN
# Caterpie                   Shield Dust               NaN   30.0     255.0
# Celebi                    Natural Cure               NaN  100.0       NaN
# Celesteela                 Beast Boost               NaN  101.0       NaN
# Centiskorch                 Flash Fire       White Smoke  115.0      75.0
# Chandelure                  Flash Fire        Flame Body   55.0      45.0
# Chansey                   Natural Cure      Serene Grace    5.0       NaN
# Charizard                        Blaze               NaN   84.0      45.0
# Charjabug                      Battery               NaN   82.0     120.0
# Charmander                       Blaze               NaN   52.0      45.0
# Charmeleon                       Blaze               NaN   64.0      45.0
# Chatot                        Keen Eye      Tangled Feet   65.0       NaN
# Cherrim                    Flower Gift               NaN   60.0      75.0
# Cherubi                    Chlorophyll               NaN   35.0     190.0
# Chesnaught                    Overgrow               NaN  107.0       NaN
# Chespin                       Overgrow               NaN   61.0       NaN
# Chewtle                     Strong Jaw       Shell Armor   64.0     255.0
# Chikorita                     Overgrow               NaN   49.0       NaN
# Chimchar                         Blaze               NaN   58.0       NaN
# Chimecho                      Levitate               NaN   50.0       NaN
# Chinchou                   Volt Absorb        Illuminate   38.0     190.0
# Chingling                     Levitate               NaN   30.0       NaN
# Cinccino                    Cute Charm        Technician   95.0      60.0
# Cinderace                        Blaze               NaN  116.0      45.0
# Clamperl                   Shell Armor               NaN   64.0       NaN
# Clauncher                Mega Launcher               NaN   53.0       NaN
# Clawitzer                Mega Launcher               NaN   73.0       NaN
# Claydol                       Levitate               NaN   70.0      90.0
# Clefable                    Cute Charm       Magic Guard   70.0      25.0
# Clefairy                    Cute Charm       Magic Guard   45.0     150.0
# Cleffa                      Cute Charm       Magic Guard   25.0     150.0
# Clobbopus                       Limber               NaN   68.0     180.0
# Cloyster                   Shell Armor        Skill Link   90.0      60.0
# Coalossal                 Steam Engine        Flame Body   80.0      45.0
# Cobalion                     Justified               NaN   90.0       NaN
# Cofagrigus                       Mummy               NaN   50.0      90.0
# Combee                    Honey Gather               NaN   30.0     120.0
# Combusken                        Blaze               NaN   85.0       NaN
# Comfey                    Flower Veil            Triage    52.0       NaN
# Conkeldurr                        Guts       Sheer Force  140.0      45.0
# Copperajah                 Sheer Force               NaN  130.0      90.0
# Corphish                  Hyper Cutter       Shell Armor   80.0     205.0
# Corsola                         Hustle      Natural Cure   55.0      60.0
# Corviknight                   Pressure           Unnerve   87.0      45.0
# Corvisquire                   Keen Eye           Unnerve   67.0     120.0
# Cosmoem                         Sturdy               NaN   29.0       NaN
# Cosmog                         Unaware               NaN   29.0       NaN
# Cottonee                     Prankster       Infiltrator   27.0     190.0
# Crabominable             Hyper Cutter         Iron Fist   132.0       NaN
# Crabrawler               Hyper Cutter         Iron Fist    82.0       NaN
# Cradily                   Suction Cups               NaN   81.0       NaN
# Cramorant                 Gulp Missile               NaN   85.0      45.0
# Cranidos                  Mold Breaker               NaN  125.0       NaN
# Crawdaunt                 Hyper Cutter       Shell Armor  120.0     155.0
# Cresselia                     Levitate               NaN   70.0       NaN
# Croagunk                    Anticipate          Dry Skin   61.0     140.0
# Crobat                     Inner Focus               NaN   90.0       NaN
# Croconaw                       Torrent               NaN   80.0       NaN
# Crustle                         Sturdy       Shell Armor   95.0      75.0
# Cryogonal                     Levitate               NaN   50.0       NaN
# Cubchoo                     Snow Cloak        Slush Rush   70.0     120.0
# Cubone                       Rock Head      Lightningrod   50.0       NaN
# Cufant                     Sheer Force               NaN   80.0     190.0
# Cursola                     Weak Armor               NaN   95.0      30.0
# Cutiefly                 Honey Gather       Shield Dust    45.0     190.0
# Cyndaquil                        Blaze               NaN   52.0       NaN
# Darkrai                     Bad Dreams               NaN   90.0       NaN
# Darmanitan                 Sheer Force               NaN  140.0      60.0
# Darmanitan (Z)                     NaN               NaN   30.0       NaN
# Dartrix                      Overgrow         Long Reach   75.0       NaN
# Darumaka                        Hustle               NaN   90.0     120.0
# Decidueye                    Overgrow         Long Reach  107.0       NaN
# Dedenne                    Cheek Pouch            Pickup   58.0       NaN
# Deerling                   Chlorophyll        Sap Sipper   60.0       NaN
# Deino                           Hustle               NaN   65.0      45.0
# Delcatty                    Cute Charm         Normalize   65.0       NaN
# Delibird                  Vital Spirit            Hustle   55.0      45.0
# Delphox                          Blaze               NaN   69.0       NaN
# Deoxys (A)                    Pressure               NaN  180.0       NaN
# Deoxys (D)                    Pressure               NaN   70.0       NaN
# Deoxys (N)                    Pressure               NaN  150.0       NaN
# Deoxys (S)                    Pressure               NaN   95.0       NaN
# Dewgong                      Thick Fat         Hydration   70.0       NaN
# Dewott                         Torrent               NaN   75.0       NaN
# Dewpider                 Water Bubble       Water Absorb   40.0     200.0
# Dhelmise                   Steelworker               NaN  131.0      25.0
# Dialga                        Pressure               NaN  120.0       NaN
# Diancie                     Clear Body               NaN  100.0       NaN
# Diggersby                       Pickup       Cheek Pouch   56.0     127.0
# Diglett                      Sand Veil        Arena Trap   55.0     255.0
# Ditto                           Limber               NaN   48.0      35.0
# Dodrio                        Run Away        Early Bird  110.0       NaN
# Doduo                         Run Away        Early Bird   85.0       NaN
# Donphan                         Sturdy               NaN  120.0       NaN
# Dottler                          Swarm      Compoundeyes   35.0     120.0
# Doublade                      No Guard               NaN  110.0      90.0
# Dracovish                 Water Absorb        Strong Jaw   90.0      45.0
# Dracozolt                  Volt Absorb            Hustle  100.0      45.0
# Dragalge                  Poison Point      Poison Touch   75.0       NaN
# Dragapult                   Clear Body       Infiltrator  120.0      45.0
# Dragonair                    Shed Skin               NaN   84.0       NaN
# Dragonite                  Inner Focus               NaN  134.0       NaN
# Drakloak                    Clear Body       Infiltrator   80.0      45.0
# Drampa                        Berserk        Sap Sipper    60.0      70.0
# Drapion                   Battle Armor            Sniper   90.0      45.0
# Dratini                      Shed Skin               NaN   64.0       NaN
# Drednaw                     Strong Jaw       Shell Armor  115.0      75.0
# Dreepy                      Clear Body       Infiltrator   60.0      45.0
# Drifblim                     Aftermath          Unburden   80.0      60.0
# Drifloon                     Aftermath          Unburden   50.0     125.0
# Drilbur                      Sand Rush        Sand Force   85.0     120.0
# Drizzile                       Torrent               NaN   60.0      45.0
# Drowzee                       Insomnia          Forewarn   48.0       NaN
# Druddigon                   Rough Skin       Sheer Force  120.0       NaN
# Dubwool                         Fluffy         Steadfast   80.0     127.0
# Ducklett                      Keen Eye         Big Pecks   44.0       NaN
# Dugtrio                      Sand Veil        Arena Trap   80.0      50.0
# Dunsparce                 Serene Grace          Run Away   70.0       NaN
# Duosion                       Overcoat       Magic Guard   40.0     100.0
# Duraludon                  Light Metal       Heavy Metal   95.0      45.0
# Durant                           Swarm            Hustle  109.0      90.0
# Dusclops                      Pressure               NaN   70.0      90.0
# Dusknoir                      Pressure               NaN  100.0      45.0
# Duskull                       Levitate               NaN   40.0     190.0
# Dustox                     Shield Dust               NaN   50.0       NaN
# Dwebble                         Sturdy       Shell Armor   65.0     190.0
# Eelektrik                     Levitate               NaN   85.0       NaN
# Eelektross                    Levitate               NaN  115.0       NaN
# Eevee                         Run Away      Adaptability   55.0      45.0
# Eiscue                        Ice Face               NaN   80.0      60.0
# Ekans                       Intimidate         Shed Skin   60.0       NaN
# Eldegoss                   Cotton Down       Regenerator   50.0      75.0
# Electabuzz                      Static               NaN   83.0       NaN
# Electivire                 Motor Drive               NaN  123.0       NaN
# Electrike                       Static      Lightningrod   45.0     120.0
# Electrode                   Soundproof            Static   50.0       NaN
# Elekid                          Static               NaN   63.0       NaN
# Elgyem                       Telepathy       Synchronize   55.0     255.0
# Emboar                           Blaze               NaN  123.0       NaN
# Emolga                          Static               NaN   75.0       NaN
# Empoleon                       Torrent               NaN   86.0       NaN
# Entei                         Pressure               NaN  115.0       NaN
# Escavalier                       Swarm       Shell Armor  135.0      75.0
# Espeon                     Synchronize               NaN   65.0      45.0
# Espurr                        Keen Eye       Infiltrator   48.0     190.0
# Eternatus                     Pressure               NaN   85.0     255.0
# Excadrill                    Sand Rush        Sand Force  135.0      60.0
# Exeggcute                  Chlorophyll               NaN   40.0       NaN
# Exeggutor                  Chlorophyll               NaN   95.0       NaN
# Exploud                     Soundproof               NaN   91.0       NaN
# Falinks                   Battle Armor               NaN  100.0      45.0
# Farfetch'd                    Keen Eye       Inner Focus   65.0       NaN
# Farfetchd                    Steadfast               NaN   95.0      45.0
# Fearow                        Keen Eye               NaN   90.0       NaN
# Feebas                      Swift Swim         Oblivious   15.0     255.0
# Fennekin                         Blaze               NaN   45.0       NaN
# Feraligatr                     Torrent               NaN  105.0       NaN
# Ferroseed                   Iron Barbs               NaN   50.0     255.0
# Ferrothorn                  Iron Barbs               NaN   94.0      90.0
# Finneon                     Swift Swim       Storm Drain   49.0       NaN
# Flaaffy                         Static               NaN   55.0       NaN
# Flabébé                    Flower Veil               NaN   38.0       NaN
# Flapple                          Ripen          Gluttony  110.0      45.0
# Flareon                     Flash Fire               NaN  130.0      45.0
# Fletchinder                 Flame Body               NaN   73.0       NaN
# Fletchling                   Big Pecks               NaN   50.0       NaN
# Floatzel                    Swift Swim               NaN  105.0       NaN
# Floette                    Flower Veil               NaN   45.0       NaN
# Florges                    Flower Veil               NaN   65.0       NaN
# Flygon                        Levitate               NaN  100.0      45.0
# Fomantis                   Leaf Guard           Contrary   55.0       NaN
# Foongus                   Effect Spore               NaN   55.0       NaN
# Forretress                      Sturdy               NaN   90.0       NaN
# Fraxure                        Rivalry      Mold Breaker  117.0      60.0
# Frillish                  Water Absorb       Cursed Body   40.0     190.0
# Froakie                        Torrent               NaN   56.0       NaN
# Frogadier                      Torrent               NaN   63.0       NaN
# Froslass                    Snow Cloak               NaN   80.0      75.0
# Frosmoth                   Shield Dust               NaN   65.0      75.0
# Furfrou                       Fur Coat               NaN   80.0       NaN
# Furret                        Run Away          Keen Eye   76.0       NaN
# Gabite                       Sand Veil               NaN   90.0       NaN
# Gallade                      Steadfast               NaN  125.0      45.0
# Galvantula                Compoundeyes           Unnerve   77.0      75.0
# Garbodor                        Stench        Weak Armor   95.0      60.0
# Garchomp                     Sand Veil               NaN  130.0       NaN
# Gardevoir                  Synchronize             Trace   65.0      45.0
# Gastly                        Levitate               NaN   35.0     190.0
# Gastrodon                  Sticky Hold       Storm Drain   83.0      75.0
# Genesect                      Download               NaN  120.0       NaN
# Gengar                        Levitate               NaN   65.0      45.0
# Geodude                      Rock Head            Sturdy   80.0       NaN
# Gible                        Sand Veil               NaN   70.0       NaN
# Gigalith                        Sturdy       Sand Stream  135.0      45.0
# Girafarig                  Inner Focus        Early Bird   80.0       NaN
# Giratina                      Pressure               NaN  100.0       NaN
# Giratina (O)                  Levitate               NaN  120.0       NaN
# Glaceon                     Snow Cloak               NaN   60.0      45.0
# Glalie                     Inner Focus          Ice Body   80.0      75.0
# Glameow                         Limber         Own Tempo   55.0       NaN
# Gligar                    Hyper Cutter         Sand Veil   75.0       NaN
# Gliscor                   Hyper Cutter         Sand Veil   95.0       NaN
# Gloom                      Chlorophyll               NaN   65.0     120.0
# Gogoat                      Sap Sipper               NaN  100.0       NaN
# Golbat                     Inner Focus               NaN   80.0       NaN
# Goldeen                     Swift Swim        Water Veil   67.0     225.0
# Golduck                           Damp        Cloud Nine   82.0       NaN
# Golem                        Rock Head            Sturdy  110.0       NaN
# Golett                       Iron Fist             Klutz   74.0     190.0
# Golisopod               Emergency Exit               NaN  125.0      45.0
# Golurk                       Iron Fist             Klutz  124.0      90.0
# Goodra                      Sap Sipper         Hydration  100.0      45.0
# Goomy                       Sap Sipper         Hydration   50.0      45.0
# Gorebyss                    Swift Swim               NaN   84.0       NaN
# Gossifleur                 Cotton Down       Regenerator   40.0     190.0
# Gothita                          Frisk       Competitive   30.0     200.0
# Gothitelle                       Frisk       Competitive   55.0      50.0
# Gothorita                        Frisk       Competitive   45.0     100.0
# Gourgeist                       Pickup             Frisk   85.0      60.0
# Granbull                    Intimidate        Quick Feet  120.0       NaN
# Grapploct                       Limber               NaN  118.0      45.0
# Graveler                     Rock Head            Sturdy   95.0       NaN
# Greedent                   Cheek Pouch               NaN   95.0      90.0
# Greninja                       Torrent               NaN   95.0       NaN
# Grimer                          Stench       Sticky Hold   80.0       NaN
# Grimmsnarl                   Prankster             Frisk  120.0      45.0
# Grookey                       Overgrow               NaN   65.0      45.0
# Grotle                        Overgrow               NaN   89.0       NaN
# Groudon                        Drought               NaN  150.0       NaN
# Grovyle                       Overgrow               NaN   65.0       NaN
# Growlithe                   Intimidate        Flash Fire   70.0     190.0
# Grubbin                          Swarm               NaN   62.0     255.0
# Grumpig                      Thick Fat         Own Tempo   45.0       NaN
# Gulpin                     Liquid Ooze       Sticky Hold   43.0       NaN
# Gumshoos                     Stakeout        Strong Jaw   110.0       NaN
# Gurdurr                           Guts       Sheer Force  105.0      90.0
# Guzzlord                   Beast Boost               NaN  101.0       NaN
# Gyarados                    Intimidate               NaN  125.0      45.0
# Hakamo-o                  Bulletproof        Soundproof    75.0       NaN
# Hakamoo                    Bulletproof        Soundproof   75.0      45.0
# Happiny                   Natural Cure      Serene Grace    5.0       NaN
# Hariyama                     Thick Fat              Guts  120.0       NaN
# Hatenna                         Healer      Anticipation   30.0     235.0
# Hatterene                       Healer      Anticipation   90.0      45.0
# Hattrem                         Healer      Anticipation   40.0     120.0
# Haunter                       Levitate               NaN   50.0      90.0
# Hawlucha                      Unburden            Limber   92.0     100.0
# Haxorus                        Rivalry      Mold Breaker  147.0      45.0
# Heatmor                       Gluttony        Flash Fire   97.0      90.0
# Heatran                     Flash Fire               NaN   90.0       NaN
# Heliolisk                     Dry Skin         Sand Veil   55.0      75.0
# Helioptile                    Dry Skin         Sand Veil   38.0     190.0
# Heracross                        Swarm              Guts  125.0       NaN
# Herdier                     Intimidate         Sand Rush   80.0       NaN
# Hippopotas                 Sand Stream               NaN   72.0     140.0
# Hippowdon                  Sand Stream               NaN  112.0      60.0
# Hitmonchan                    Keen Eye         Iron Fist  105.0      45.0
# Hitmonlee                       Limber          Reckless  120.0      45.0
# Hitmontop                   Intimidate        Technician   95.0      45.0
# Ho-oh                         Pressure               NaN  130.0       NaN
# Honchkrow                     Insomnia        Super Luck  125.0       NaN
# Honedge                       No Guard               NaN   80.0     180.0
# Hoopa (C)                     Magician               NaN  110.0       NaN
# Hoopa (U)                     Magician               NaN  160.0       NaN
# Hoothoot                      Insomnia          Keen Eye   30.0     255.0
# Hoppip                     Chlorophyll        Leaf Guard   35.0       NaN
# Horsea                      Swift Swim            Sniper   40.0       NaN
# Houndoom                    Early Bird        Flash Fire   90.0       NaN
# Houndour                    Early Bird        Flash Fire   60.0       NaN
# Huntail                     Swift Swim               NaN  104.0       NaN
# Hydreigon                     Levitate               NaN  105.0      45.0
# Hypno                         Insomnia          Forewarn   73.0       NaN
# Igglybuff                   Cute Charm               NaN   30.0       NaN
# Illumise                     Oblivious       Tinted Lens   47.0       NaN
# Impidimp                     Prankster             Frisk   45.0     255.0
# Incineroar                      Blaze         Intimidate  115.0       NaN
# Indeedee                   Inner Focus       Synchronize   65.0      30.0
# Infernape                        Blaze               NaN  104.0       NaN
# Inkay                     Suction Cups          Contrary   54.0     190.0
# Inteleon                       Torrent               NaN   85.0      45.0
# Ivysaur                       Overgrow               NaN   62.0       NaN
# Jangmo-o                  Bulletproof        Soundproof    55.0       NaN
# Jangmoo                    Bulletproof        Soundproof   55.0      45.0
# Jellicent                 Water Absorb       Cursed Body   60.0      60.0
# Jigglypuff                  Cute Charm               NaN   45.0       NaN
# Jirachi                   Serene Grace               NaN  100.0       NaN
# Jolteon                    Volt Absorb               NaN   65.0      45.0
# Joltik                    Compoundeyes           Unnerve   47.0     190.0
# Jumpluff                   Chlorophyll        Leaf Guard   55.0       NaN
# Jynx                         Oblivious          Forewarn   50.0       NaN
# Kabuto                      Swift Swim      Battle Armor   80.0       NaN
# Kabutops                    Swift Swim      Battle Armor  115.0       NaN
# Kadabra                    Synchronize       Inner Focus   35.0       NaN
# Kakuna                       Shed Skin               NaN   25.0       NaN
# Kangaskhan                  Early Bird           Scrappy   95.0       NaN
# Karrablast                       Swarm         Shed Skin   75.0     200.0
# Kartana                    Beast Boost               NaN  181.0       NaN
# Kecleon                   Color Change               NaN   90.0       NaN
# Keldeo                       Justified               NaN   72.0       NaN
# Kingdra                     Swift Swim            Sniper   95.0       NaN
# Kingler                   Hyper Cutter       Shell Armor  130.0      60.0
# Kirlia                     Synchronize             Trace   35.0     120.0
# Klang                             Plus             Minus   80.0      60.0
# Klefki                       Prankster               NaN   80.0       NaN
# Klink                             Plus             Minus   55.0     130.0
# Klinklang                         Plus             Minus  100.0      30.0
# Koffing                       Levitate  Neutralizing Gas   65.0     190.0
# Komala                        Comatose               NaN  115.0       NaN
# Kommo-o                   Bulletproof        Soundproof   110.0       NaN
# Kommoo                     Bulletproof        Soundproof  110.0      45.0
# Krabby                    Hyper Cutter       Shell Armor  105.0     225.0
# Kricketot                    Shed Skin               NaN   25.0       NaN
# Kricketune                       Swarm               NaN   85.0       NaN
# Krokorok                    Intimidate             Moxie   82.0       NaN
# Krookodile                  Intimidate             Moxie  117.0       NaN
# Kyogre                         Drizzle               NaN  100.0       NaN
# Kyurem                        Pressure               NaN  130.0       NaN
# Lairon                          Sturdy         Rock Head   90.0       NaN
# Lampent                     Flash Fire        Flame Body   40.0      90.0
# Landorus                    Sand Force               NaN  125.0       NaN
# Lanturn                    Volt Absorb        Illuminate   58.0      75.0
# Lapras                    Water Absorb       Shell Armor   85.0      45.0
# Larvesta                    Flame Body               NaN   85.0       NaN
# Larvitar                          Guts               NaN   64.0      45.0
# Latias                        Levitate               NaN   80.0       NaN
# Latios                        Levitate               NaN   90.0       NaN
# Leafeon                     Leaf Guard               NaN  110.0      45.0
# Leavanny                         Swarm       Chlorophyll  103.0       NaN
# Ledian                           Swarm        Early Bird   35.0       NaN
# Ledyba                           Swarm        Early Bird   20.0       NaN
# Lickilicky                   Own Tempo         Oblivious   85.0       NaN
# Lickitung                    Own Tempo         Oblivious   55.0       NaN
# Liepard                         Limber          Unburden   88.0      90.0
# Lileep                    Suction Cups               NaN   41.0       NaN
# Lilligant                  Chlorophyll         Own Tempo   60.0       NaN
# Lillipup                  Vital Spirit            Pickup   60.0       NaN
# Linoone                         Pickup          Gluttony   70.0      90.0
# Litleo                         Rivalry           Unnerve   50.0       NaN
# Litten                          Blaze         Intimidate   65.0       NaN
# Litwick                     Flash Fire        Flame Body   30.0     190.0
# Lombre                      Swift Swim         Rain Dish   50.0     120.0
# Lopunny                     Cute Charm             Klutz   76.0       NaN
# Lotad                       Swift Swim         Rain Dish   30.0     255.0
# Loudred                     Soundproof               NaN   71.0       NaN
# Lucario                      Steadfast       Inner Focus  110.0      45.0
# Ludicolo                    Swift Swim         Rain Dish   70.0      45.0
# Lugia                         Pressure               NaN   90.0       NaN
# Lumineon                    Swift Swim       Storm Drain   69.0       NaN
# Lunala                   Shadow Shield               NaN  113.0       NaN
# Lunatone                      Levitate               NaN   55.0      45.0
# Lurantis                   Leaf Guard           Contrary  105.0       NaN
# Luvdisc                     Swift Swim               NaN   30.0       NaN
# Luxio                          Rivalry        Intimidate   85.0       NaN
# Luxray                         Rivalry        Intimidate  120.0       NaN
# Lycanroc (midday)            Keen Eye         Sand Rush   115.0       NaN
# Lycanroc (midnight)           Keen Eye     Vital Spirit   115.0       NaN
# Machamp                           Guts          No Guard  130.0      45.0
# Machoke                           Guts          No Guard  100.0      90.0
# Machop                            Guts          No Guard   80.0     180.0
# Magby                       Flame Body               NaN   75.0       NaN
# Magcargo                   Magma Armor        Flame Body   50.0       NaN
# Magearna                    Soul-Heart               NaN   95.0       NaN
# Magikarp                    Swift Swim               NaN   10.0     255.0
# Magmar                      Flame Body               NaN   95.0       NaN
# Magmortar                   Flame Body               NaN   95.0       NaN
# Magnemite                  Magnet Pull            Sturdy   35.0       NaN
# Magneton                   Magnet Pull            Sturdy   60.0       NaN
# Magnezone                  Magnet Pull            Sturdy   70.0       NaN
# Makuhita                     Thick Fat              Guts   60.0       NaN
# Malamar                   Suction Cups          Contrary   92.0      80.0
# Mamoswine                    Oblivious        Snow Cloak  130.0      50.0
# Manaphy                      Hydration               NaN  100.0       NaN
# Mandibuzz                    Big Pecks          Overcoat   65.0      60.0
# Manectric                       Static      Lightningrod   75.0      45.0
# Mankey                    Vital Spirit       Anger Point   80.0       NaN
# Mantine                     Swift Swim      Water Absorb   40.0      25.0
# Mantyke                     Swift Swim      Water Absorb   20.0      25.0
# Maractus                  Water Absorb       Chlorophyll   86.0     255.0
# Mareanie                    Merciless            Limber    53.0     190.0
# Mareep                          Static               NaN   40.0       NaN
# Marill                       Thick Fat        Huge Power   20.0       NaN
# Marowak                      Rock Head      Lightningrod   80.0       NaN
# Marshadow                   Technician               NaN  125.0       NaN
# Marshtomp                      Torrent               NaN   85.0       NaN
# Masquerain                  Intimidate               NaN   60.0       NaN
# Mawile                    Hyper Cutter        Intimidate   85.0      45.0
# Medicham                    Pure Power               NaN   60.0       NaN
# Meditite                    Pure Power               NaN   40.0       NaN
# Meganium                      Overgrow               NaN   82.0       NaN
# Meloetta (A)              Serene Grace               NaN   77.0       NaN
# Meloetta (P)              Serene Grace               NaN  128.0       NaN
# Meowstic                      Keen Eye       Infiltrator   48.0      75.0
# Meowth                          Pickup        Technician   45.0     255.0
# Mesprit                       Levitate               NaN  105.0       NaN
# Metagross                   Clear Body               NaN  135.0       NaN
# Metang                      Clear Body               NaN   75.0       NaN
# Metapod                      Shed Skin               NaN   20.0     120.0
# Mew                        Synchronize               NaN  100.0       NaN
# Mewtwo                        Pressure               NaN  110.0       NaN
# Mienfoo                    Inner Focus       Regenerator   85.0       NaN
# Mienshao                   Inner Focus       Regenerator  125.0       NaN
# Mightyena                   Intimidate        Quick Feet   90.0       NaN
# Milcery                     Sweet Veil               NaN   40.0     200.0
# Milotic                   Marvel Scale       Competitive   60.0      60.0
# Miltank                      Thick Fat           Scrappy   80.0       NaN
# Mime Jr.                    Soundproof            Filter   25.0       NaN
# MimeJr                      Soundproof            Filter   25.0     145.0
# Mimikyu                       Disguise               NaN   90.0      45.0
# Minccino                    Cute Charm        Technician   50.0     255.0
# Minior (core)             Shields Down               NaN  100.0       NaN
# Minior (meteor)           Shields Down               NaN   60.0       NaN
# Minun                            Minus               NaN   40.0       NaN
# Misdreavus                    Levitate               NaN   60.0       NaN
# Mismagius                     Levitate               NaN   60.0       NaN
# Moltres                       Pressure               NaN  100.0       NaN
# Monferno                         Blaze               NaN   78.0       NaN
# Morelull                   Illuminate       Effect Spore   35.0     190.0
# Morgrem                      Prankster             Frisk   60.0     120.0
# Morpeko                  Hunger Switch               NaN   95.0     180.0
# Mothim                           Swarm               NaN   94.0       NaN
# Mr. Mime                    Soundproof            Filter   45.0       NaN
# MrMime                    Vital Spirit    Screen Cleaner   65.0      45.0
# MrRime                    Tangled Feet    Screen Cleaner   85.0      45.0
# Mudbray                      Own Tempo          Stamina   100.0     190.0
# Mudkip                         Torrent               NaN   70.0       NaN
# Mudsdale                     Own Tempo          Stamina   125.0      60.0
# Muk                             Stench       Sticky Hold  105.0       NaN
# Munchlax                        Pickup         Thick Fat   85.0      50.0
# Munna                         Forewarn       Synchronize   25.0     190.0
# Murkrow                       Insomnia        Super Luck   85.0       NaN
# Musharna                      Forewarn       Synchronize   55.0      75.0
# Natu                       Synchronize        Early Bird   50.0     190.0
# Necrozma                   Prism Armor               NaN  107.0       NaN
# Nickit                        Run Away          Unburden   28.0     255.0
# Nidoking                  Poison Point           Rivalry   92.0       NaN
# Nidoqueen                 Poison Point           Rivalry   82.0       NaN
# Nidoran♀                  Poison Point           Rivalry   47.0       NaN
# Nidoran♂                  Poison Point           Rivalry   57.0       NaN
# Nidorina                  Poison Point           Rivalry   62.0       NaN
# Nidorino                  Poison Point           Rivalry   72.0       NaN
# Nihilego                   Beast Boost               NaN   53.0       NaN
# Nincada                   Compoundeyes               NaN   45.0     255.0
# Ninetales                   Flash Fire               NaN   76.0      75.0
# Ninjask                    Speed Boost               NaN   90.0     120.0
# Noctowl                       Insomnia          Keen Eye   50.0      90.0
# Noibat                           Frisk       Infiltrator   30.0     190.0
# Noivern                          Frisk       Infiltrator   70.0      45.0
# Nosepass                        Sturdy       Magnet Pull   45.0       NaN
# Numel                        Oblivious            Simple   60.0       NaN
# Nuzleaf                    Chlorophyll        Early Bird   70.0     120.0
# Obstagoon                     Reckless              Guts   90.0      45.0
# Octillery                 Suction Cups            Sniper  105.0      75.0
# Oddish                     Chlorophyll               NaN   50.0     255.0
# Omanyte                     Swift Swim       Shell Armor   40.0       NaN
# Omastar                     Swift Swim       Shell Armor   60.0       NaN
# Onix                         Rock Head            Sturdy   45.0      45.0
# Oranguru                  Inner Focus         Telepathy    60.0      45.0
# Orbeetle                         Swarm             Frisk   45.0      45.0
# Oricorio                        Dancer               NaN   70.0       NaN
# Oshawott                       Torrent               NaN   55.0       NaN
# Pachirisu                     Run Away            Pickup   45.0       NaN
# Palkia                        Pressure               NaN  120.0       NaN
# Palossand            Water Compaction          Sand Veil   75.0       NaN
# Palpitoad                   Swift Swim         Hydration   65.0     120.0
# Pancham                      Iron Fist      Mold Breaker   82.0     220.0
# Pangoro                      Iron Fist      Mold Breaker  124.0      65.0
# Panpour                       Gluttony               NaN   53.0       NaN
# Pansage                       Gluttony               NaN   53.0       NaN
# Pansear                       Gluttony               NaN   53.0       NaN
# Paras                     Effect Spore          Dry Skin   70.0       NaN
# Parasect                  Effect Spore          Dry Skin   95.0       NaN
# Passimian                    Receiver            Defiant  120.0      45.0
# Patrat                        Run Away          Keen Eye   55.0       NaN
# Pawniard                       Defiant       Inner Focus   85.0     120.0
# Pelipper                      Keen Eye           Drizzle   50.0      45.0
# Perrserker                Battle Armor       Tough Claws  110.0      90.0
# Persian                         Limber        Technician   70.0      90.0
# Petilil                    Chlorophyll         Own Tempo   35.0       NaN
# Phanpy                          Pickup               NaN   60.0       NaN
# Phantump                  Natural Cure             Frisk   70.0     120.0
# Pheromosa                  Beast Boost               NaN  137.0       NaN
# Phione                       Hydration               NaN   80.0       NaN
# Pichu                           Static               NaN   40.0     190.0
# Pidgeot                       Keen Eye      Tangled Feet   80.0       NaN
# Pidgeotto                     Keen Eye      Tangled Feet   60.0       NaN
# Pidgey                        Keen Eye      Tangled Feet   45.0       NaN
# Pidove                       Big Pecks        Super Luck   55.0     255.0
# Pignite                          Blaze               NaN   93.0       NaN
# Pikachu                         Static               NaN   55.0     190.0
# Pikipek                      Keen Eye        Skill Link    75.0       NaN
# Piloswine                    Oblivious        Snow Cloak  100.0      75.0
# Pincurchin               Lightning Rod               NaN  101.0      75.0
# Pineco                          Sturdy               NaN   65.0       NaN
# Pinsir                    Hyper Cutter      Mold Breaker  125.0       NaN
# Piplup                         Torrent               NaN   51.0       NaN
# Plusle                            Plus               NaN   50.0       NaN
# Politoed                  Water Absorb              Damp   75.0       NaN
# Poliwag                   Water Absorb              Damp   50.0       NaN
# Poliwhirl                 Water Absorb              Damp   65.0       NaN
# Poliwrath                 Water Absorb              Damp   85.0       NaN
# Polteageist                 Weak Armor               NaN   65.0      60.0
# Ponyta                        Run Away        Flash Fire   85.0     190.0
# Poochyena                     Run Away        Quick Feet   55.0       NaN
# Popplio                       Torrent       Liquid Voice   54.0       NaN
# Porygon                          Trace          Download   60.0       NaN
# Porygon-Z                 Adaptability          Download   80.0       NaN
# Porygon2                         Trace          Download   80.0       NaN
# Primarina                     Torrent       Liquid Voice   74.0       NaN
# Primeape                  Vital Spirit       Anger Point  105.0       NaN
# Prinplup                       Torrent               NaN   66.0       NaN
# Probopass                       Sturdy       Magnet Pull   55.0       NaN
# Psyduck                           Damp        Cloud Nine   52.0       NaN
# Pumpkaboo                       Pickup             Frisk   66.0     120.0
# Pupitar                      Shed Skin               NaN   84.0      45.0
# Purrloin                        Limber          Unburden   50.0     255.0
# Purugly                      Thick Fat         Own Tempo   82.0       NaN
# Pyroar                         Rivalry           Unnerve   68.0       NaN
# Pyukumuku                  Innards Out           Unaware   60.0      60.0
# Quagsire                          Damp      Water Absorb   85.0      90.0
# Quilava                          Blaze               NaN   64.0       NaN
# Quilladin                     Overgrow               NaN   78.0       NaN
# Qwilfish                  Poison Point        Swift Swim   95.0      45.0
# Raboot                           Blaze               NaN   86.0      45.0
# Raichu                          Static               NaN   90.0      75.0
# Raikou                        Pressure               NaN   85.0       NaN
# ...
# Rotom (Spin)               NaN         NaN    NaN  0.981308
# Rotom (Wash)               NaN         NaN    NaN  0.981308
# Rowlet                     NaN         NaN    NaN  1.000000
# Rufflet                   10.5        23.1  280.0  0.740000
# Runerigus                 66.6       146.8  327.0  0.476190
# Sableye                   11.0        24.3  293.0  1.000000
# Salamence                  NaN         NaN    NaN  1.375000
# Salandit                   4.8        10.6  243.0  1.775000
# Salazzle                  22.2        48.9  244.0  1.850000
# Samurott                   NaN         NaN    NaN  1.542857
# Sandaconda                65.5       144.4  312.0  0.928571
# Sandile                    NaN         NaN    NaN  1.000000
# Slowpoke                   NaN         NaN    NaN  1.000000
# Slugma                     NaN         NaN    NaN  1.750000
# Slurpuff                   5.0        11.0  210.0  1.133333
# Smeargle                   NaN         NaN    NaN  0.444444
# Smoochum                   NaN         NaN    NaN  1.307692
# Sneasel                   28.0        61.7  291.0  0.466667
# Snivy                      NaN         NaN    NaN  0.818182
# Snom                       3.8         8.4  348.0  1.500000
# Snorlax                  460.0      1014.1  260.0  0.590909
# Snorunt                   16.8        37.0   78.0  1.000000
# Snover                    50.5       111.3   95.0  1.033333
# Snubbull                   NaN         NaN    NaN  1.000000
# Sobble                     4.0         8.8    6.0  1.750000
# Solgaleo                   NaN         NaN    NaN  1.269663
# Solosis                    1.0         2.2  269.0  2.100000
# Solrock                  154.0       339.5  362.0  0.846154
# Spearow                    NaN         NaN    NaN  1.000000
# Spewpa                     NaN         NaN    NaN  0.900000
# Spheal                     NaN         NaN    NaN  1.100000
# Spinarak                   NaN         NaN    NaN  1.000000
# Spinda                     NaN         NaN    NaN  1.000000
# Spiritomb                  NaN         NaN    NaN  0.851852
# Spoink                     NaN         NaN    NaN  0.875000
# Spritzee                   0.5         1.1  211.0  0.969231
# Squirtle                   NaN         NaN    NaN  1.111111
# Stantler                   NaN         NaN    NaN  1.307692
# Staraptor                  NaN         NaN    NaN  1.000000
# Staravia                   NaN         NaN    NaN  1.000000
# Starly                     NaN         NaN    NaN  1.000000
# Starmie                    NaN         NaN    NaN  1.176471
# Staryu                     NaN         NaN    NaN  1.272727
# Steelix                  400.0       881.8  178.0  0.846154
# Steenee                    8.2        18.1   52.0  0.833333
# Stonjourner              520.0      1146.4  368.0  1.000000
# Stoutland                  NaN         NaN    NaN  0.500000
# Stufful                    6.8        15.0   93.0  0.900000
# Stunfisk                  11.0        24.3  225.0  0.818182
# Stunky                    19.2        42.3  129.0  1.000000
# Sudowoodo                 38.0        83.8  252.0  0.461538
# Suicune                    NaN         NaN    NaN  0.782609
# Sunflora                   NaN         NaN    NaN  1.235294
# Sunkern                    NaN         NaN    NaN  1.000000
# Surskit                    NaN         NaN    NaN  0.961538
# Swablu                     NaN         NaN    NaN  0.533333
# Swadloon                   NaN         NaN    NaN  0.625000
# Swalot                     NaN         NaN    NaN  0.879518
# Swampert                   NaN         NaN    NaN  0.944444
# Swanna                     NaN         NaN    NaN  1.380952
# Swellow                    NaN         NaN    NaN  1.000000
# Swinub                     6.5        14.3   74.0  1.000000
# Swirlix                    3.5         7.7  209.0  1.035088
# Swoobat                   10.5        23.1  174.0  1.400000
# Sylveon                   23.5        51.8  203.0  0.846154
# Taillow                    NaN         NaN    NaN  1.000000
# Talonflame                 NaN         NaN    NaN  1.072464
# Tangela                    NaN         NaN    NaN  2.500000
# Tangrowth                  NaN         NaN    NaN  2.200000
# Tapu Bulu                  NaN         NaN    NaN  0.894737
# Tapu Fini                  NaN         NaN    NaN  0.730769
# Tapu Koko                  NaN         NaN    NaN  1.266667
# Tapu Lele                  NaN         NaN    NaN  1.130435
# Tauros                     NaN         NaN    NaN  0.571429
# Teddiursa                  NaN         NaN    NaN  1.000000
# Tentacool                  NaN         NaN    NaN  0.500000
# Tentacruel                 NaN         NaN    NaN  0.666667
# Tepig                      NaN         NaN    NaN  1.000000
# Terrakion                  NaN         NaN    NaN  0.800000
# Thievul                   19.9        43.9   29.0  0.945652
# Throh                     55.5       122.4  247.0  0.352941
# Thundurus                  NaN         NaN    NaN  1.562500
# Thwackey                  14.0        30.9    1.0  0.916667
# Timburr                   12.5        27.6  170.0  0.714286
# Tirtouga                   NaN         NaN    NaN  1.177778
# Togedemaru                 3.3         7.3  347.0  0.547945
# Togekiss                  38.0        83.8  258.0  1.043478
# Togepi                     1.5         3.3  256.0  0.615385
# Togetic                    3.2         7.1  257.0  0.761905
# Torchic                    NaN         NaN    NaN  1.400000
# Torkoal                   80.4       177.2  299.0  1.214286
# Tornadus                   NaN         NaN    NaN  1.562500
# Torracat                   NaN         NaN    NaN  1.600000
# Torterra                   NaN         NaN    NaN  0.882353
# Totodile                   NaN         NaN    NaN  0.916667
# Toucannon                  NaN         NaN    NaN  1.000000
# Toxapex                   14.5        32.0  307.0  0.373239
# Toxel                     11.0        24.3  309.0  1.542857
# Toxicroak                 44.4        97.9  222.0  1.323077
# Toxtricity                40.0        88.2  310.0  1.628571
# Tranquill                 15.0        33.1   26.0  1.190476
# Trapinch                  15.0        33.1  320.0  1.000000
# Treecko                    NaN         NaN    NaN  1.181818
# Trevenant                 71.0       156.5  338.0  0.792683
# Tropius                    NaN         NaN    NaN  0.827586
# Trubbish                  31.0        68.3  156.0  0.645161
# Trumbeak                   NaN         NaN    NaN  0.800000
# Tsareena                  21.4        47.2   53.0  0.510204
# Turtonator               212.0       467.4  346.0  1.070588
# Turtwig                    NaN         NaN    NaN  0.818182
# Tympole                    4.5         9.9  131.0  1.250000
# Tynamo                     NaN         NaN    NaN  1.125000
# Type: Null                 NaN         NaN    NaN  1.000000
# TypeNull                 120.5       265.7  380.0  1.000000
# Typhlosion                 NaN         NaN    NaN  1.282353
# Tyranitar                202.0       445.3  384.0  0.950000
# Tyrantrum                  NaN         NaN    NaN  1.169492
# Tyrogue                   21.0        46.3  106.0  1.000000
# Tyrunt                     NaN         NaN    NaN  1.000000
# Umbreon                   27.0        59.5  200.0  0.461538
# Unfezant                  29.0        63.9   27.0  1.181818
# Unown                      NaN         NaN    NaN  1.500000
# Ursaring                   NaN         NaN    NaN  1.000000
# Uxie                       NaN         NaN    NaN  0.576923
# Vanillish                 41.0        90.4   72.0  1.066667
# Vanillite                  5.7        12.6   71.0  1.083333
# Vanilluxe                 57.5       126.8   73.0  1.157895
# Vaporeon                  29.0        63.9  196.0  1.157895
# Venipede                   NaN         NaN    NaN  0.769231
# Venomoth                   NaN         NaN    NaN  1.200000
# Venonat                    NaN         NaN    NaN  0.727273
# Venusaur                   NaN         NaN    NaN  1.000000
# Vespiquen                 38.5        84.9  116.0  0.784314
# Vibrava                   15.3        33.7  321.0  1.000000
# Victini                    NaN         NaN    NaN  1.000000
# Victreebel                 NaN         NaN    NaN  1.666667
# Vigoroth                   NaN         NaN    NaN  1.000000
# Vikavolt                  45.0        99.2   17.0  1.933333
# Vileplume                 18.6        41.0   56.0  1.111111
# Virizion                   NaN         NaN    NaN  0.697674
# Vivillon                   NaN         NaN    NaN  1.800000
# Volbeat                    NaN         NaN    NaN  0.626667
# Volcanion                  NaN         NaN    NaN  1.444444
# Volcarona                  NaN         NaN    NaN  1.285714
# Voltorb                    NaN         NaN    NaN  1.000000
# Vullaby                    9.0        19.8  282.0  0.692308
# Vulpix                     9.9        21.8   67.0  0.769231
# Wailmer                  130.0       286.6  355.0  2.000000
# Wailord                  398.0       877.4  356.0  2.000000
# Walrein                    NaN         NaN    NaN  1.055556
# Wartortle                  NaN         NaN    NaN  0.812500
# Watchog                    NaN         NaN    NaN  0.869565
# Weavile                   34.0        75.0  292.0  0.529412
# Weedle                     NaN         NaN    NaN  1.000000
# Weepinbell                 NaN         NaN    NaN  1.888889
# Weezing                    9.5        20.9  250.0  1.214286
# Whimsicott                 6.6        14.6  262.0  1.026667
# Whirlipede                 NaN         NaN    NaN  0.506329
# Whiscash                  23.6        52.0  228.0  1.070423
# Whismur                    NaN         NaN    NaN  2.217391
# Wigglytuff                 NaN         NaN    NaN  1.500000
# Wimpod                    12.0        26.5  231.0  0.666667
# Wingull                    9.5        20.9   61.0  1.833333
# Wishiwashi                 0.3         0.7  154.0  1.000000
# Wishiwashi (school)        NaN         NaN    NaN  1.037037
# Wishiwashi (solo)          NaN         NaN    NaN  1.000000
# Wobbuffet                 28.5        62.8  216.0  0.568966
# Woobat                     2.1         4.6  173.0  1.279070
# Wooloo                     6.0        13.2   33.0  0.888889
# Wooper                     8.5        18.7   99.0  1.000000
# Wormadam (P)               NaN         NaN    NaN  0.752381
# Wormadam (S)               NaN         NaN    NaN  0.694118
# Wormadam (T)               NaN         NaN    NaN  0.726316
# Wurmple                    NaN         NaN    NaN  0.666667
# Wynaut                    14.0        30.9  215.0  0.479167
# Xatu                      15.0        33.1   92.0  1.357143
# Xerneas                    NaN         NaN    NaN  1.336735
# Xurkitree                  NaN         NaN    NaN  2.436620
# Yamask                     1.5         3.3  326.0  0.846154
# Yamper                    13.5        29.8   45.0  0.800000
# Yanma                      NaN         NaN    NaN  1.666667
# Yanmega                    NaN         NaN    NaN  2.071429
# Yungoos                    NaN         NaN    NaN  1.000000
# Yveltal                    NaN         NaN    NaN  1.336735
# Zacian                   110.0       242.5  397.0  0.695652
# Zamazenta                210.0       463.0  398.0  0.695652
# Zangoose                   NaN         NaN    NaN  1.000000
# Zapdos                     NaN         NaN    NaN  1.388889
# Zebstrika                  NaN         NaN    NaN  1.269841
# Zekrom                     NaN         NaN    NaN  1.200000
# Zigzagoon                 17.5        38.6   30.0  0.731707
# Zoroark                    NaN         NaN    NaN  2.000000
# Zorua                      NaN         NaN    NaN  2.000000
# Zubat                      NaN         NaN    NaN  0.750000
# Zweilous                  50.0       110.2  386.0  0.928571
# Zygarde                    NaN         NaN    NaN  0.852632

# %% [markdown]
# # Multi-level indexing
# In this section, we'll cover some more advanced topics in pandas, including
# *   Multi-indexing
# *   Pivot tables
#
# We'll be introducing some more data to play with, based on state populations over time

# %%
state_populations_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv'
state_abbrevs_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv'
state_areas_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv'

state_areas = pd.read_csv(state_areas_url, index_col='state')
state_areas.head() # just print top 5 rows

# %%
state_abbrevs = pd.read_csv(state_abbrevs_url)
state_abbrevs.head()

# %%
state_populations = pd.read_csv(state_populations_url) 
state_populations.head(10) #print first 10 rows

# %%
state_populations.tail()

# %% [markdown]
# Note that the state populations are just listed by abbreviations. It may be useful to include the state names as a column in a table. We have this information in the `state_abbrevs` table. We'd like to merge it with the population data.
#
# The function `pd.merge()` merges two dataframes using set logic.

# %%
merged = pd.merge(state_populations, state_abbrevs, how='outer',
                 left_on='state/region', right_on='abbreviation')
# The arguments left_on and right_on specify what columns to join on. It looks for matching values in each dataframe
# and fills in the additional columns of the merged dataframe based on the matching data
# The 'how' argument specifies what kind of join. Outer means keep all entries even if one does not show up in the other
# conversely, 'inner' discards rows where a corresponding entry does not exist in the other
merged

# %%
# we can also drop the unnecessary extra abbreviation column now
merged = merged.drop('abbreviation', axis=1) #drop from columns
merged.head()

# %%
# we can check if there were any missing values
merged.isnull().any()

# %%
# let's see where the issue is. What entries are missing population entries?
merged.loc[merged['population'].isnull()]

# %%
# what about where there's no state entry?
merged.loc[merged['state'].isnull(), 'state/region']

# %%
# more concicely, we can use .unique() to only see the unique values
merged.loc[merged['state'].isnull(), 'state/region'].unique()

# %%
# We can fix this easily
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'
merged.loc[merged['state/region'] == 'USA', 'state'] = 'United States'
merged.isnull().any()

# %%
# now let's combine the data with the area data
final = pd.merge(merged, state_areas, on='state', how='left')
final.head()

# %%
# we can use the .query() syntax to search for specific data
data2010 = final.query("year == 2010 & ages == 'total'") # specify column name 
data2010.set_index('state', inplace=True) # equivalent to data2010 = data2010.set_index('state')
data2010.head()

# %%
# Let's compute the density of each state and then sort by density
density = data2010['population'] / data2010['area (sq. mi)']
density.sort_values(ascending=False, inplace=True)
density

# %%
density.tail()

# %% [markdown]
# ### Exercises
# Compute the total population of the entire united states, as well as its population density for each year.
#
# Sort the states by population density.
#
# What year saw the biggest change in population for the US as a whole?
#
# Which states had the biggest percentage change in population in that year?

# %%
state_areas.sum().values

# %%
# total population
final.loc[(final['state/region']!='USA')&(final['ages']=='total')]\
     .groupby('year')['population'].sum()

# %%
final.query("state!='United States' & ages=='total'").groupby('year')['population'].sum()

# %%
final['density'] = final['population']/final['area (sq. mi)']
final.loc[(final['state']=='United States') & (final['ages']=='total')]

# %%
final.loc[final['state']=='United States','area (sq. mi)'] = state_areas.sum().values

# %%
final.loc[(final['state']=='United States') & (final['ages']=='total')]\
          .sort_values('year')['population'].diff()

# %%
idx_max = final.loc[(final['state']=='United States') & (final['ages']=='total')]\
          .sort_values('year')['population'].diff().idxmax()

# %%
year_max = final.loc[idx_max,'year']
year_max

# %%
data_year_max = final.loc[(final['year']==year_max)&(final['ages']=='total')]
data_year_before = final.loc[(final['year']==year_max-1)&(final['ages']=='total')]

# %%
data_year_max = data_year_max.copy() # make a copy so we can change things destructively
data_year_max.loc[:,'percent_change'] = 100*(data_year_max['population'].values  - data_year_before['population'].values)/data_year_before['population'].values

# %%
data_year_max

# %%
data_year_max.loc[data_year_max['percent_change'].abs().idxmax()]

# %% [markdown]
# ## Multiindexing
# You can use multiple columns to define an index, as long as each row has a unique combination of values within those columns. In the following example, we will use the columns "state/region", "year", and "ages" of the population dataframe as an index

# %% [markdown]
# We use the `.set_index(['column_name1', 'column_name2, ...])'` command to create a multiindex from existing columns.
#
# Note that many operations require a multiindex to be sorted, so we also call `.sort_index()` on the dataframe. Also, `.set_index()` and `.sort_index()` return a _copy_ of the dataframe, so we assign the output to itself to update the value.

# %%
# set index to use multiple columns
final = final.set_index(['state/region','year','ages']) # overwrite old version with new version with index set
final = final.sort_index() # replace itself with a version with a sorted index
final.tail(10) #print last 10 entries

# %%
final.loc[('MA',2009,'total'):('WY',2011,'total')]

# %% [markdown]
# ### Stacking and unstacking
# Columns can also have multiple levels. In fact, the columns can be thought of as just another index that runs horizontally. This is most easily illustrated by stacking, unstacking, and transposing.
#
# You can convert a level of the row index to a column level using the `.unstack()` command. Conversely, `.stack()` moves a column level to the index

# %%
unstacked = final.unstack(level='ages') # you can unstack by level name; this moves the 'ages' categories into the column index
unstacked

# %%
restacked = unstacked.stack('ages', dropna=False) # stacks the column level back into the row index
# by default, .stack() omits entries with NaN. If you want to preserve the NaN entries, use the option dropna=False
restacked == final # just like the original state_populations dataframe

# %%
final.unstack(level=0) # you can also unstack using integer levels. Here we unstacked level 0, corresponding to state/region

# %% [markdown]
# You can switch the row and column index using the transpose function `.T`

# %%
final.unstack(level=0).T

# %% [markdown]
# ### Pivoting
# Pivoting is another advanced way to transform data. It creates a new dataframe using the values of columns as `index` and `column` values.
#
# You can then aggregate using `aggfunc` the elements of another column, which becomes the `values` of this new dataframe.

# %%
# let's create a table which lists all pokemon for given type combinations
pokedex_df.pivot_table(values='Pokemon', # line breaks within parentheses automatically continue onto next line
                       index='Type I', # values of Type I become index entries
                       columns='Type II', # likewise Type II become columns
                       aggfunc=lambda x:", ".join(x)).fillna('') # the lambda function here just joins a list of strings using a comma
                      # we also fill nan values with empty string for aesthetics

# %%
# compute the average stats for each type combination
pokedex_df.unstack()
pokedex_df.pivot_table(values='Total',
                       index='Type I', 
                       columns='Type II', 
                       aggfunc=lambda x: np.mean(x)).fillna('')

# %%
# You can compute multiple aggregations on multiple columns by passing a dict
# into the aggfunc argument: aggfunc={'column_name':[list_of_function_names]}
# Note that in this case, the 'value' argument is ignored
pokedex_df.pivot_table(index='Type I', 
                       columns='Type II', 
                       aggfunc={'Total':[lambda x: np.mean(x),lambda x: np.std(x)], 
                                'Atk':[lambda x: np.mean(x),lambda x: np.std(x)]}).fillna('')

# %% [markdown]
# # Exercise
# Using this data (or any other data you're interested in and you find online), put together an analysis using pandas that investigates an interesting question.
#
# It can be serious or silly. Like "Do states with higher population density tend to vote democratic?" (you'd need to pull additional data for this) or "Do pokemon whose names start with the letter D have better stats than those who start with F?"
#
# We'll ask some volunteers to present their analysis at the end
